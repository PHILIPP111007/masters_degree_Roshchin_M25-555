# %% [markdown]
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
# <font face='Liberation serif' size=3>
#
# #### **Привет, Филипп!** 👋
#
# ---
#
#
# Меня зовут Артём Пиляй. Я буду проверять твой проект «*Исследование рынка заведений общественного питания Москвы*» ☕.
#
# ---
#
# В рамках корпоративной этики мы общаемся на «ты». Но если лучше на «Вы», то важно обозначить это сразу.
#
# ---
#
# Комментарии к проекту размещены в отдельных ячейках Markdown. Для удобства они отображаются в меню **Contents** слева.
#
# Я использую четыре типа комментариев:
#
# ---
#
# ✅ Главый комментарий — значит, всё сделано хорошо. А ещё здесь могут быть подсказки, как улучшить проект.
#
# ---
#
# ⚠️ Рекомендуемый к исправлению — лучше внести правки, хотя это не критично для текущего проекта.
#
# ---
#
# ⛔ Обязателен к исправлению — важный комментарий, который нужно доработать, чтобы проект прошёл проверку.
#
# ---
#
# 🚩 Красный флаг — проверку пришлось прервать, так как действие в ячейке выше повлияло на весь дальнейший проект.
#
# <br>
#
# ---
#
# Важно:
#
# - Не перемещать и не удалять мои комментарии. Если они будут удалены, я верну последнюю версию проекта, где они сохранились.
#
# - Если возникнут вопросы, их можно задавать прямо в конце моих комментариев, которые отмечены ⚠️, ⛔ или 🚩 - под чертой. Комментарии, отмеченные ✅, я повторно не смотрю. Например:
#
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ⚠️ **Критерий проверки**
#
# ---
#
# ⚠️ Мой комментарий
#
# ---
#
# **Здесь можно оставить комментарий**
#
#
# </div>
#
# 🏁 [Перейти к итогам ревью](#results)
#
# <a id="start"></a>

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Оформление проекта
#
# ---
#
# Основное задание выполните в Jupyter Notebook, программный код заполните в ячейках типа `code`, текстовые пояснения — в ячейках типа `markdown`. Примените форматирование и заголовки. Презентацию можно выполнить с помощью любого удобного вам инструмента, главное — экспортировать её в PDF-формат. Добавьте ссылку на вашу презентацию комментарием в ячейку Jupyter-тетрадки и отправьте её на проверку ревьюеру.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Структура и оформление проекта (код + пояснения)
#
# ----
#
#
# 🚩 Проект сейчас нельзя проверить по техническому заданию - нарушена структура.
# - Ты объединил несколько шагов (примерно 3.3–3.11) в одну ячейку, при этом часть шагов пропущена, а выводы по задачам отсутствуют.
# - Из-за этого невозможно понять, где заканчивается один шаг и начинается другой, и корректно оценить выполнение требований ТЗ.
#
# Что нужно сделать:
# - Разбей работу на шаги строго как в ТЗ: каждый шаг - отдельная Markdown-ячейка с названием шага (например, “Шаг 3.8 …”), сразу под ней - код этого шага.
# - В конце каждого шага добавь короткий вывод (1–3 предложения): что увидел по данным и к какому ответу пришёл.
# - Если ты пропустил шаги — добавь их и выполни требования из описания.
#
# Пример, как должен быть оформить проект, оставил ниже:
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# ✅ Теперь все хорошо.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 5. Подготовка презентации
#
# ---
#
# - Подготовьте презентацию исследования для инвесторов. Отвечая на вопросы о московском общепите, вы уже построили много диаграмм, и помещать каждую из них в презентацию не нужно. Выберите важные тезисы и наблюдения, которые могут заинтересовать заказчиков.
#
# Для создания презентации используйте любой удобный инструмент, но отправить презентацию нужно обязательно в формате PDF. Приложите ссылку на презентацию в markdown-ячейке в формате: Презентация: <ссылка на облачное хранилище с презентацией>
#
# Следуйте изученным принципам оформления презентации.

# %% [markdown]
# # Проект выполнил: Рощин Филипп
#
# Презентация: <https://github.com/PHILIPP111007/masters_degree_Roshchin_M25-555/blob/main/BI/moscow_places/moscow_places_hw.pdf>

# %% [markdown]
# # ПРОЕКТ: АНАЛИЗ РЫНКА ОБЩЕСТВЕННОГО ПИТАНИЯ МОСКВЫ
# #
# # Для фонда "Shut Up and Take My Money"
#
# НАЗВАНИЕ ПРОЕКТА:
#
# Рынок заведений общественного питания Москвы: аналитическое исследование и рекомендации по открытию нового заведения
#
# БИЗНЕС-ЗАДАЧА:
# Инвесторы из фонда «Shut Up and Take My Money» планируют открыть заведение
# общественного питания в Москве, но не определились с концепцией, локацией
# и ценовой политикой.
#
# ЦЕЛИ ПРОЕКТА:
# 1. Провести комплексный анализ рынка общественного питания Москвы
# 3. Выявить ключевые тенденции и особенности рынка
# 5. Проанализировать конкурентную среду по категориям заведений
# 6. Определить перспективные локации для открытия заведения
# 7. Сформулировать рекомендации по открытию кофейни (частный случай)
#
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ:
# Презентация с выводами и рекомендациями, которая поможет инвесторам принять обоснованное решение об открытии заведения общественного питания в Москве.
#
# # ОПИСАНИЕ ДАННЫХ
#
# ДАТАСЕТ: moscow_places.csv
#
# Источник: Яндекс Карты и Яндекс Бизнес (лето 2022 года)
#
# СТРУКТУРА ДАННЫХ:
#
# 1. name - название заведения
# 2. address - адрес заведения
# 3. category - категория заведения (кафе, ресторан, пиццерия, кофейня и т.д.)
# 4. hours - информация о днях и часах работы
# 5. lat - широта географической точки
# 6. lng - долгота географической точки
# 7. rating - рейтинг заведения по оценкам пользователей Яндекс Карт (макс. 5.0)
# 8. price - категория цен в заведении (средние, ниже среднего, выше среднего)
# 9. avg_bill - строка с описанием средней стоимости заказа
# 10. middle_avg_bill - числовая оценка среднего чека (только для записей,
#     начинающихся с "Средний счёт")
# 11. middle_coffee_cup - числовая оценка стоимости чашки капучино (только для
#     записей, начинающихся с "Цена одной чашки капучино")
# 12. chain - является ли заведение сетевым (0 - нет, 1 - да)
# 13. district - административный район Москвы
# 14. seats - количество посадочных мест
#
# # ПЛАН РАБОТЫ
#
# ## ЭТАП 1: ПОДГОТОВКА ДАННЫХ
#
# 1.1. Загрузка данных
#
# 1.2. Изучение общей информации
#
# 1.3. Предобработка данных
#
# 1.4. Создание новых признаков
#
# ## ЭТАП 2: ОБЩИЙ АНАЛИЗ РЫНКА
#
# 2.1. Распределение заведений по категориям
#
# 2.2. Анализ посадочных мест
#
# 2.3. Исследование сетевых заведений
#
# 2.4. Географический анализ (районы)
#
# 2.5. Анализ рейтингов
#
# 2.6. Исследование ценовой политики
#
# ## ЭТАП 3: УГЛУБЛЕННЫЙ АНАЛИЗ ДЛЯ КОФЕЕН
#
# 3.1. Распределение кофеен по районам
#
# 3.2. Анализ круглосуточных кофеен
#
# 3.3. Исследование рейтингов кофеен
#
# 3.4. Анализ цен на кофе
#
# 3.5. Сравнение сетевых и несетевых кофеен
#
# ## ЭТАП 4: ФОРМИРОВАНИЕ ВЫВОДОВ И РЕКОМЕНДАЦИЙ
#
# 4.1. Общие выводы по рынку
#
# 4.2. Рекомендации для открытия заведения
#
# 4.3. Специфические рекомендации для кофейни
#
# 4.4. Подготовка презентации
#
# ## ЭТАП 5: СОЗДАНИЕ ПРЕЗЕНТАЦИИ
#
# 5.1. Отбор ключевых инсайтов
#
# 5.2. Структурирование информации
#
# 5.3. Создание визуализаций
#
# 5.4. Формирование финального отчета

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Вводная часть
#
# ---
#
# Чтобы проект выглядел законченным и человек, который будет знакомиться с твоим портфолио, понимал суть исследования, рекомендую добавить:
#
# - название проекта.
# - понятная бизнес-задача.
# - описание столбцов датасета.
# - план работы.
#
#
# Это небольшие улучшения, которые сделают проект более презентабельным и понятным для заказчика или проверяющего. 😉
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# ✅ Отличное начало.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import folium
from folium.plugins import MarkerCluster
import json
import re
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Настройка визуализаций
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Python Enhancement Proposal №8.
#
# ---
#
# ✅ Правильно, что разделяешь импорт от основного кода и импортируешь все библиотеки в одной ячейке в начале проекта. Это соответствует стилю PEP 8 и делает код более структурированным и понятным.
#
# Это помогает:
# - Сразу видеть, какое окружение необходимо для запуска проекта.
# - Избежать дублирования импортов в разных частях кода.
# - Облегчить отладку и переносимость проекта.
#
# Подробнее о PEP 8 можно прочитать в статье [*PEP 8 - руководство по написанию кода на Python*](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html).

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Разница окружений
#
# ---
#
# 🚩 Стиль `seaborn-v0_8-darkgrid` не поддерживается на платформе, поэтому код будет падать. Есть два варианта решения проблемы:
#
# 1. Прописать обновление библиотек прямо в коде, тогда нужная версия seaborn подтянется и стиль станет доступен на платформе. То есть у заказчика он будет работать.
# 2. Самый простой. Перед отправкой проекта запусти код полностью, начиная с первой ячейки и далее последовательно. В этом случае мне не придётся перезапускать проект, и ошибка стиля не возникнет.
# 3. Или просто не использовать `seaborn-v0_8-darkgrid` в проекте.
#
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# ✅ Отлично, все работает.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 1.1 Загрузка данных
#
# ---
#
# **Шаг 1.1 Загрузите данные и изучите общую информацию**
#
# - Загрузите данные о заведениях общественного питания Москвы.
# Путь к файлу: `/datasets/moscow_places.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/moscow_places.csv).

# %%
path = "/datasets/moscow_places.csv"
# path = "/Users/phil/GitHub/masters_degree_Roshchin_M25-555/BI/moscow_places/moscow_places.csv"

df = pd.read_csv(path)

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Работоспособность кода
#
# ---
#
# 🚩 К сожалению, не смог ознакомиться с твоим проектом до конца, ошибка в коде 🙁 🚧
#
# Ошибка имени: имя ‘/Users/phil/GitHub/masters_degree_Roshchin_M25-555/BI/moscow_places.csv’ не определено.
#
#
#
# Пожалуйста, перед отправкой на проверку запусти проект в JupyterHub ⏩ и посмотри, что бы он отработал до конца, чтобы тебе не терять время.
#
# Представь, что ты работаешь в крупной фирме, допустим  проект сделан дома, а на совещании у руководства проект не работает. Согласись будет странно звучать если ты будешь объяснять генеральному директору, что дома работает, а здесь нет. Работоспособность проекта – это ответственность того, кто его разрабатывал.
#
#
#
# Жду рабочую версию проекта. 🙂
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# ✅ Можно продолжить.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 1.2 Знакомство с данными
#
# ---
#
# - Изучите общую информацию о датасете.

# %%
df.head()
# Out:
#                    name  category                              address  \
# 0                WoWфли      кафе           Москва, улица Дыбенко, 7/1
# 1        Четыре комнаты  ресторан   Москва, улица Дыбенко, 36, корп. 1
# 2                 Хазри      кафе       Москва, Клязьминская улица, 15
# 3  Dormouse Coffee Shop   кофейня  Москва, улица Маршала Федоренко, 12
# 4             Иль Марко  пиццерия      Москва, Правобережная улица, 1Б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                hours        lat        lng  \
# 0                             ежедневно, 10:00–22:00  55.878494  37.478860
# 1                             ежедневно, 10:00–22:00  55.875801  37.484479
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00...  55.889146  37.525901
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               8406 non-null   object
#  1   category           8406 non-null   object
#  2   address            8406 non-null   object
#  3   district           8406 non-null   object
#  4   hours              7870 non-null   object
#  5   lat                8406 non-null   float64
#  6   lng                8406 non-null   float64
#  7   rating             8406 non-null   float64
#  8   price              3315 non-null   object
#  9   avg_bill           3816 non-null   object
#  10  middle_avg_bill    3149 non-null   float64
#  11  middle_coffee_cup  535 non-null    float64
#  12  chain              8406 non-null   int64
#  13  seats              4795 non-null   float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 919.5+ KB

# %% [markdown]
# # value_counts

# %%
df["name"].value_counts()
# Out:
# name
# Кафе                189
# Шоколадница         120
# Домино'с Пицца       76
# Додо Пицца           74
# One Price Coffee     71
#                    ...
# Сащя                  1
# Мой дом               1
# Stardogs              1
# Bar Park 15           1
# Kebab Time            1
# Name: count, Length: 5614, dtype: int64

# %%
df["category"].value_counts()
# Out:
# category
# кафе               2378
# ресторан           2043
# кофейня            1413
# бар,паб             765
# пиццерия            633
# быстрое питание     603
# столовая            315
# булочная            256
# Name: count, dtype: int64

# %%
df["district"].value_counts()
# Out:
# district
# Центральный административный округ         2242
# Северный административный округ             900
# Южный административный округ                892
# Северо-Восточный административный округ     891
# Западный административный округ             851
# Восточный административный округ            798
# Юго-Восточный административный округ        714
# Юго-Западный административный округ         709
# Северо-Западный административный округ      409
# Name: count, dtype: int64

# %%
df["hours"].value_counts()
# Out:
# hours
# ежедневно, 10:00–22:00                                                  759
# ежедневно, круглосуточно                                                730
# ежедневно, 11:00–23:00                                                  396
# ежедневно, 10:00–23:00                                                  310
# ежедневно, 12:00–00:00                                                  254
#                                                                        ...
# пн-пт 17:00–03:00; сб,вс 17:00–05:00                                      1
# пн,вт 09:00–21:00; ср-пт 09:00–22:00; сб 10:00–22:00; вс 10:00–21:00      1
# пн-пт 12:00–01:00                                                         1
# пн-пт 10:30–21:30; сб,вс 10:30–22:30                                      1
# пн-сб 10:30–21:30                                                         1
# Name: count, Length: 1307, dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# 4.3    1513
# 4.4    1351
# 4.2    1041
# 4.1     785
# 4.5     623
# 4.0     499
# 4.7     440
# 4.6     422
# 3.9     252
# 4.9     243
# 4.8     215
# 3.8     188
# 3.7     147
# 5.0     105
# 3.6      76
# 3.5      72
# 3.4      68
# 3.3      54
# 3.2      41
# 3.1      37
# 2.9      31
# 2.8      30
# 3.0      24
# 2.6      15
# 1.1      14
# 2.3      14
# 2.5      14
# 2.2      13
# 2.4      11
# 1.3      11
# 1.4      11
# 2.7      11
# 1.0      10
# 1.7       6
# 2.0       4
# 2.1       4
# 1.9       4
# 1.5       2
# 1.8       2
# 1.6       2
# 1.2       1
# Name: count, dtype: int64

# %%
df["price"].value_counts()
# Out:
# price
# средние          2117
# выше среднего     564
# высокие           478
# низкие            156
# Name: count, dtype: int64

# %%
df["avg_bill"].value_counts()
# Out:
# avg_bill
# Средний счёт:1000–1500 ₽        241
# Средний счёт:1500–2000 ₽        120
# Средний счёт:300–500 ₽           90
# Средний счёт:500–1000 ₽          78
# Средний счёт:1500–2500 ₽         68
#                                ...
# Цена бокала пива:180–260 ₽        1
# Средний счёт:407 ₽                1
# Средний счёт:170–490 ₽            1
# Цена бокала пива:90–250 ₽         1
# Цена чашки капучино:80–120 ₽      1
# Name: count, Length: 897, dtype: int64

# %%
df["middle_avg_bill"].value_counts()
# Out:
# middle_avg_bill
# 1250.0    247
# 1000.0    175
# 300.0     148
# 1500.0    146
# 400.0     134
#          ...
# 383.0       1
# 255.0       1
# 67.0        1
# 495.0       1
# 107.0       1
# Name: count, Length: 230, dtype: int64

# %%
df["middle_coffee_cup"].value_counts()
# Out:
# middle_coffee_cup
# 256.0    43
# 60.0     33
# 95.0     32
# 150.0    24
# 170.0    18
#          ..
# 137.0     1
# 315.0     1
# 167.0     1
# 169.0     1
# 129.0     1
# Name: count, Length: 96, dtype: int64

# %%
df["chain"].value_counts()
# Out:
# chain
# 0    5201
# 1    3205
# Name: count, dtype: int64

# %%
df["seats"].value_counts()
# Out:
# seats
# 40.0     253
# 100.0    213
# 60.0     175
# 50.0     168
# 80.0     160
#         ...
# 161.0      1
# 430.0      1
# 131.0      1
# 760.0      1
# 305.0      1
# Name: count, Length: 229, dtype: int64

# %% [markdown]
# # describe

# %%
df.describe()
# Out:
#                lat          lng       rating  middle_avg_bill  \
# count  8406.000000  8406.000000  8406.000000      3149.000000
# mean     55.750109    37.608570     4.229895       958.053668
# std       0.069658     0.098597     0.470348      1009.732845
# min      55.573942    37.355651     1.000000         0.000000
# 25%      55.705155    37.538583     4.100000       375.000000
# 50%      55.753425    37.605246     4.300000       750.000000
# 75%      55.795041    37.664792     4.400000      1250.000000
# max      55.928943    37.874466     5.000000     35000.000000
#
#        middle_coffee_cup        chain        seats
# count         535.000000  8406.000000  4795.000000
# mean          174.721495     0.381275   108.421689
# std            88.951103     0.485729   122.833396
# min            60.000000     0.000000     0.000000
# 25%           124.500000     0.000000    40.000000
# 50%           169.000000     0.000000    75.000000
# ...

# %%
df.describe(include=['object'])
# Out:
#         name category                            address  \
# count   8406     8406                               8406
# unique  5614        8                               5753
# top     Кафе     кафе  Москва, проспект Вернадского, 86В
# freq     189     2378                                 28
#
#                                   district                   hours    price  \
# count                                 8406                    7870     3315
# unique                                   9                    1307        4
# top     Центральный административный округ  ежедневно, 10:00–22:00  средние
# freq                                  2242                     759     2117
#
#                         avg_bill
# count                       3816
# unique                       897
# top     Средний счёт:1000–1500 ₽
# freq                         241

# %%
print("\n" + "="*80)
print("ПРОМЕЖУТОЧНЫЙ ВЫВОД: ПЕРВИЧНЫЙ АНАЛИЗ ДАННЫХ")
print("="*80)

print("\n✅ ОТВЕТЫ НА ВОПРОСЫ ЗАКАЗЧИКА:")
print("-" * 60)

print("\n1. СКОЛЬКО ЗАВЕДЕНИЙ ПРЕДСТАВЛЕНО?")
print(f"   • Всего в датасете: {df.shape[0]:,} заведений".replace(',', ' '))
print(f"   • Количество столбцов с информацией: {df.shape[1]}")
print(f"   • Уникальных названий заведений: {df['name'].nunique()}")

print("\n2. ЧТО МОЖНО СКАЗАТЬ О КАЖДОМ СТОЛБЦЕ?")

# Анализируем каждый столбец по отдельности
print("\n   📍 name (название заведения):")
print(f"      • Уникальных названий: {df['name'].nunique()}")
print(f"      • Самое частое название: '{df['name'].value_counts().index[0]}'")
print(f"      • Встречается {df['name'].value_counts().iloc[0]} раз")
print(f"      • Пропусков: {df['name'].isnull().sum()}")

print("\n   📍 category (категория заведения):")
print(f"      • Всего категорий: {df['category'].nunique()}")
print(f"      • Самая популярная категория: '{df['category'].value_counts().index[0]}'")
print(f"      • Занимает {df['category'].value_counts().iloc[0]} записей")
print(f"      • Доля от общего числа: {(df['category'].value_counts().iloc[0]/len(df)*100):.1f}%")
print("      • Все категории: " + ", ".join(sorted(df['category'].unique())))

print("\n   📍 address (адрес):")
print(f"      • Уникальных адресов: {df['address'].nunique()}")
print(f"      • Самый частый адрес: '{df['address'].value_counts().index[0]}'")
print(f"      • Встречается {df['address'].value_counts().iloc[0]} раз")
print(f"      • Пропусков: {df['address'].isnull().sum()}")

print("\n   📍 district (район):")
print(f"      • Всего административных районов: {df['district'].nunique()}")
print(f"      • Самый представленный район: '{df['district'].value_counts().index[0]}'")
print(f"      • Встречается в {df['district'].value_counts().iloc[0]} записях")
print(f"      • Доля: {(df['district'].value_counts().iloc[0]/len(df)*100):.1f}%")

print("\n   📍 hours (часы работы):")
print(f"      • Уникальных форматов записи времени: {df['hours'].nunique()}")
print(f"      • Самый частый график: '{df['hours'].value_counts().index[0]}'")
print(f"      • Встречается {df['hours'].value_counts().iloc[0]} раз")
print(f"      • Пропусков: {df['hours'].isnull().sum()} ({df['hours'].isnull().sum()/len(df)*100:.1f}%)")

print("\n   📍 price (ценовая категория):")
print(f"      • Уникальных категорий цен: {df['price'].nunique()}")
print(f"      • Самая частая категория: '{df['price'].value_counts().index[0]}'")
print(f"      • Встречается {df['price'].value_counts().iloc[0]} раз")
print(f"      • Пропусков: {df['price'].isnull().sum()} ({df['price'].isnull().sum()/len(df)*100:.1f}%)")

print("\n   📍 avg_bill (информация о среднем чеке):")
print(f"      • Уникальных описаний: {df['avg_bill'].nunique()}")
print(f"      • Самый частый формат: '{df['avg_bill'].value_counts().index[0]}'")
print(f"      • Встречается {df['avg_bill'].value_counts().iloc[0]} раз")
print(f"      • Пропусков: {df['avg_bill'].isnull().sum()} ({df['avg_bill'].isnull().sum()/len(df)*100:.1f}%)")

print("\n3. ЗНАЧЕНИЯ КАКОГО ТИПА ОНИ ХРАНЯТ?")
print("   • Текстовые данные (object):")
print("     - name, address, category, hours, price, avg_bill")
print("   • Категориальные данные: category, district, price")
print("   • Географические данные: address (адреса для геокодирования)")
print("   • Временные данные: hours (график работы)")
print("   • Финансовые данные: avg_bill (стоимость в текстовом формате)")
# Out:
# ...
# ПРОМЕЖУТОЧНЫЙ ВЫВОД: ПЕРВИЧНЫЙ АНАЛИЗ ДАННЫХ
# ...
#
# ✅ ОТВЕТЫ НА ВОПРОСЫ ЗАКАЗЧИКА:
# ------------------------------------------------------------
#
# 1. СКОЛЬКО ЗАВЕДЕНИЙ ПРЕДСТАВЛЕНО?
#    • Всего в датасете: 8 406 заведений
#    • Количество столбцов с информацией: 14
#    • Уникальных названий заведений: 5614
#
# 2. ЧТО МОЖНО СКАЗАТЬ О КАЖДОМ СТОЛБЦЕ?
#
#    📍 name (название заведения):
#       • Уникальных названий: 5614
#       • Самое частое название: 'Кафе'
#       • Встречается 189 раз
#       • Пропусков: 0
#
#    📍 category (категория заведения):
#       • Всего категорий: 8
#       • Самая популярная категория: 'кафе'
#       • Занимает 2378 записей
#       • Доля от общего числа: 28.3%
#       • Все категории: бар,паб, булочная, быстрое питание, кафе, кофейня, пиццерия, ресторан, столовая
#
#    📍 address (адрес):
#       • Уникальных адресов: 5753
#       • Самый частый адрес: 'Москва, проспект Вернадского, 86В'
#       • Встречается 28 раз
#       • Пропусков: 0
#
# ...

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 1.3 Вывод
#
# ---
#
# - Сколько заведений представлено?
# - Что можно сказать о каждом столбце?
# - Значения какого типа они хранят?

# %% [markdown]
# ПРОМЕЖУТОЧНЫЙ ВЫВОД: ПЕРВИЧНЫЙ АНАЛИЗ ДАННЫХ
#
# ✅ ОТВЕТЫ НА ВОПРОСЫ ЗАКАЗЧИКА:
#
# 1. СКОЛЬКО ЗАВЕДЕНИЙ ПРЕДСТАВЛЕНО?
#    • Всего в датасете: 8 406 заведений
#    • Количество столбцов с информацией: 14
#    • Уникальных названий заведений: 5614
#
# 2. ЧТО МОЖНО СКАЗАТЬ О КАЖДОМ СТОЛБЦЕ?
#
#    📍 name (название заведения):
#       • Уникальных названий: 5614
#       • Самое частое название: 'Кафе'
#       • Встречается 189 раз
#       • Пропусков: 0
#
#    📍 category (категория заведения):
#       • Всего категорий: 8
#       • Самая популярная категория: 'кафе'
#       • Занимает 2378 записей
#       • Доля от общего числа: 28.3%
#       • Все категории: бар,паб, булочная, быстрое питание, кафе, кофейня, пиццерия, ресторан, столовая
#
#    📍 address (адрес):
#       • Уникальных адресов: 5753
#       • Самый частый адрес: 'Москва, проспект Вернадского, 86В'
#       • Встречается 28 раз
#       • Пропусков: 0
#
#    📍 district (район):
#       • Всего административных районов: 9
#       • Самый представленный район: 'Центральный административный округ'
#       • Встречается в 2242 записях
#       • Доля: 26.7%
#
#    📍 hours (часы работы):
#       • Уникальных форматов записи времени: 1307
#       • Самый частый график: 'ежедневно, 10:00–22:00'
#       • Встречается 759 раз
#       • Пропусков: 536 (6.4%)
#
#    📍 price (ценовая категория):
#       • Уникальных категорий цен: 4
#       • Самая частая категория: 'средние'
#       • Встречается 2117 раз
#       • Пропусков: 5091 (60.6%)
#
#    📍 avg_bill (информация о среднем чеке):
#       • Уникальных описаний: 897
#       • Самый частый формат: 'Средний счёт:1000–1500 ₽'
#       • Встречается 241 раз
#       • Пропусков: 4590 (54.6%)
#
# 3. ЗНАЧЕНИЯ КАКОГО ТИПА ОНИ ХРАНЯТ?
#    • Текстовые данные (object):
#      - name, address, category, hours, price, avg_bill
#    • Категориальные данные: category, district, price
#    • Географические данные: address (адреса для геокодирования)
#    • Временные данные: hours (график работы)
#    • Финансовые данные: avg_bill (стоимость в текстовом формате)

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Аналитическая часть работы
#
# ---
#
# ⛔ Лучше добавить промежуточный вывод после первичного анализа данных. Это поможет лучше структурировать работу и покажет заказчику, что уже было выявлено на ранних этапах исследования.
#
# Такой вывод позволит:
# - Четко показать ключевые наблюдения на этапе знакомства с данными.
# - Заложить основу для дальнейшего анализа и гипотез.
#
# Это хороший способ сделать проект более логичным и последовательным. 😊
#
# В данном случае заказчик задал три вопроса:
#
# - Сколько заведений представлено?
# - Что можно сказать о каждом столбце?
# - Значения какого типа они хранят?
#
# ---
#
# 💬 Здесь можно оставить комментарий.
#
# ---
#
# ✅ Отлично.

# %% [markdown]
# ЭТАП 1.2: ИЗУЧЕНИЕ ОБЩЕЙ ИНФОРМАЦИИ

# %% [markdown]
# Информация о типах данных и пропусках

# %%
df_info = pd.DataFrame({
    'Тип данных': df.dtypes,
    'Уникальных значений': df.nunique(),
    'Пропусков': df.isnull().sum(),
    'Процент пропусков': (df.isnull().sum() / len(df) * 100).round(2)
})

df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, name to seats
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Тип данных           14 non-null     object
#  1   Уникальных значений  14 non-null     int64
#  2   Пропусков            14 non-null     int64
#  3   Процент пропусков    14 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.1+ KB

# %% [markdown]
# БАЗОВАЯ СТАТИСТИКА ПО ЧИСЛОВЫМ СТОЛБЦАМ

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
print(df[numeric_cols].describe().round(2))
# Out:
#            lat      lng   rating  middle_avg_bill  middle_coffee_cup    chain  \
# count  8406.00  8406.00  8406.00          3149.00             535.00  8406.00
# mean     55.75    37.61     4.23           958.05             174.72     0.38
# std       0.07     0.10     0.47          1009.73              88.95     0.49
# min      55.57    37.36     1.00             0.00              60.00     0.00
# 25%      55.71    37.54     4.10           375.00             124.50     0.00
# 50%      55.75    37.61     4.30           750.00             169.00     0.00
# 75%      55.80    37.66     4.40          1250.00             225.00     1.00
# max      55.93    37.87     5.00         35000.00            1568.00     1.00
#
#          seats
# count  4795.00
# mean    108.42
# std     122.83
# min       0.00
# 25%      40.00
# 50%      75.00
# 75%     140.00
# max    1288.00

# %% [markdown]
# БАЗОВАЯ СТАТИСТИКА ПО КАТЕГОРИАЛЬНЫМ СТОЛБЦАМ

# %%
categorical_cols = ['category', 'price', 'district']
for col in categorical_cols:
    if col in df.columns:
        print(f"\n{col}:")
        print(f"  Уникальных значений: {df[col].nunique()}")
        print(f"  Топ-5 значений:")
        print(df[col].value_counts().head())
# Out:
# category:
#   Уникальных значений: 8
#   Топ-5 значений:
# category
# кафе        2378
# ресторан    2043
# кофейня     1413
# бар,паб      765
# пиццерия     633
# Name: count, dtype: int64
#
# price:
#   Уникальных значений: 4
#   Топ-5 значений:
# price
# средние          2117
# выше среднего     564
# высокие           478
# низкие            156
# Name: count, dtype: int64
#
# district:
#   Уникальных значений: 9
#   Топ-5 значений:
# district
# Центральный административный округ         2242
# Северный административный округ             900
# Южный административный округ                892
# Северо-Восточный административный округ     891
# Западный административный округ             851
# Name: count, dtype: int64

# %% [markdown]
# 1. СКОЛЬКО ЗАВЕДЕНИЙ ПРЕДСТАВЛЕНО?

# %%
df.shape[0]
# Out:
# 8406

# %% [markdown]
# ================================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД: КАТЕГОРИАЛЬНЫЕ ДАННЫЕ
# ================================================================================
#
# 🔍 АНАЛИЗ РАСПРЕДЕЛЕНИЯ КАТЕГОРИЙ ЗАВЕДЕНИЙ:
# ------------------------------------------------------------
#
# 1. ОБЩАЯ СТРУКТУРА РЫНКА:
#    • Всего категорий: 8
#    • Общее количество заведений: 8 406
#
# 2. ДОМИНИРУЮЩИЕ КАТЕГОРИИ:
#    1. КАФЕ:
#       • Количество: 2 378
#       • Доля на рынке: 28.3%
#       • Каждое 3-е заведение - это кафе
#    2. РЕСТОРАН:
#       • Количество: 2 043
#       • Доля на рынке: 24.3%
#       • Каждое 4-е заведение - это ресторан
#    3. КОФЕЙНЯ:
#       • Количество: 1 413
#       • Доля на рынке: 16.8%
#       • Каждое 5-е заведение - это кофейня
#
# 3. СРЕДНИЕ КАТЕГОРИИ:
#    4. бар паб: 765 (9.1%)
#    5. пиццерия: 633 (7.5%)
#    6. быстрое питание: 603 (7.2%)
#
# 4. МАЛОПРЕДСТАВЛЕННЫЕ КАТЕГОРИИ:
#    6. быстрое питание: 603 (7.2%)
#    7. столовая: 315 (3.7%)
#    8. булочная: 256 (3.0%)
#
# 💡 КЛЮЧЕВЫЕ ИНСАЙТЫ ПО КАТЕГОРИЯМ:
# ----------------------------------------
#
# • Доминирование кафе и ресторанов (более 50% рынка вместе):
#   Это свидетельствует о том, что московский рынок общепита
#   ориентирован на полноценные заведения для обедов и ужинов,
#   а не на узкоспециализированные форматы.
#
# • Значительная доля кофеен (16.8%):
#   Москва явно является "кофейным" городом с развитой
#   кофейной культурой и высокой конкуренцией в этом сегменте.
#
# • Бары и пабы занимают заметную нишу (9.1%):
#   Указывает на развитую ночную жизнь и культуру посиделок
#   в барах среди москвичей.
#
# • Пиццерии - стабильный, но не доминирующий сегмент (7.5%):
#   Это популярный, но уже насыщенный сегмент с высокой
#   конкуренцией, особенно со стороны сетевых игроков.
#
#
# 💰 АНАЛИЗ ЦЕНОВЫХ КАТЕГОРИЙ:
# ----------------------------------------
# 1. ДОСТУПНОСТЬ ДАННЫХ:
#    • Записей с указанием цены: 3 315 (39.4%)
#    • Пропущенных значений: 5 091 (60.6%)
#
# 2. РАСПРЕДЕЛЕНИЕ ЦЕНОВЫХ СЕГМЕНТОВ:
#    • средние: 2 117 заведений (63.9%)
#    • выше среднего: 564 заведений (17.0%)
#    • высокие: 478 заведений (14.4%)
#    • низкие: 156 заведений (4.7%)
#
# 💡 ИНТЕРПРЕТАЦИЯ ЦЕНОВОГО РАСПРЕДЕЛЕНИЯ:
#
# • "Средние" цены доминируют (63.9% от известных цен):
#   Это указывает на то, что московский рынок ориентирован
#   на средний класс и массового потребителя.
#
# • Значительная доля "выше среднего" и "высоких" цен (31.4% вместе):
#   Свидетельствует о наличии премиального сегмента и
#   платежеспособного спроса в Москве.
#
# • Небольшая доля "низких" цен (4.7%):
#   Эконом-сегмент слабо представлен, что может говорить либо о:
#   1) Низкой маржинальности такого формата
#   2) Специфике данных (возможно, не все столовые и фастфуды
#      включены в выборку)
#   3) Высоких арендных ставках, не позволяющих держать низкие цены
#
#
# 🗺️  АНАЛИЗ ГЕОГРАФИЧЕСКОГО РАСПРЕДЕЛЕНИЯ:
# ----------------------------------------
# 1. ОБЩАЯ ГЕОГРАФИЯ:
#    • Административных округов: 9
#    • Все округа представлены в данных
#
# 2. ЛИДИРУЮЩИЕ РАЙОНЫ:
#    1. Центральный административный округ:
#       • Заведений: 2 242
#       • Доля: 26.7%
#    2. Северный административный округ:
#       • Заведений: 900
#       • Доля: 10.7%
#    3. Южный административный округ:
#       • Заведений: 892
#       • Доля: 10.6%
#
# 3. РАВНОМЕРНОСТЬ РАСПРЕДЕЛЕНИЯ:
#    • Среднее количество заведений на округ: 934
#    • Коэффициент вариации: 55.1%
#
# 💡 ГЕОГРАФИЧЕСКИЕ ИНСАЙТЫ:
#
# • Центральный административный округ - явный лидер (26.7%):
#   Это ожидаемо, так как ЦАО является историческим, деловым
#   и туристическим центром Москвы с максимальной проходимостью.
#
# • Относительно равномерное распределение по остальным округам:
#   Каждый округ имеет примерно 9-11% долю рынка, что говорит о:
#   1) Хорошей развитости инфраструктуры во всех районах
#   2) Децентрализации общепита в Москве
#   3) Наличии локального спроса в спальных районах
#
# • Отсутствие явных аутсайдеров:
#   Даже наименее представленные округа имеют значительное
#   количество заведений, что свидетельствует о зрелости рынка.
#
#
# 🎯 ВЫВОДЫ ДЛЯ БИЗНЕС-РЕШЕНИЙ:
# ----------------------------------------
#
# 1. ДЛЯ ВЫБОРА ФОРМАТА:
#    • Кафе и рестораны - самый крупный, но и самый конкурентный сегмент
#    • Кофейни - растущий сегмент с хорошими перспективами
#    • Пиццерии - насыщенный рынок, требуется уникальное УТП
#    • Бары/пабы - нишевой, но стабильный сегмент
#
# 2. ДЛЯ ЦЕНОВОЙ ПОЛИТИКИ:
#    • Рекомендуется ориентироваться на "средний" или "выше среднего" сегмент
#    • Премиум-сегмент тоже имеет потенциал, но требует особой концепции
#    • Эконом-сегмент может быть рискованным из-за низкой маржи
#
# 3. ДЛЯ ВЫБОРА ЛОКАЦИИ:
#    • ЦАО - максимальная проходимость, но и максимальная конкуренция
#    • Остальные округа - более доступные арендные ставки, локальная аудитория
#    • Рекомендуется баланс: не самый центр, но и не периферия

# %% [markdown]
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅  Аналитическая часть работы
#
# ---
#
# ⛔ Отсутствует вывод. Напомню, что вывод это не просто отображение результата выполнения кода, а его интерпретация аналитиком. Это разные вещи.
#
#
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# вроде вывод сделал
#
# ---
#
# ✅ Да, теперь все отлично.

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 2.1 Анализ дубликатов
#
# ---
#
# **Шаг 2. Выполните предобработку данных**
#
# - Изучите, есть ли дубликаты в данных.

# %% [markdown]
# Количество полных дубликатов

# %%
df['name'] = df["name"].str.lower()

df['address'] = df["address"].str.lower()

df.head()
# Out:
#                    name  category                              address  \
# 0                wowфли      кафе           москва, улица дыбенко, 7/1
# 1        четыре комнаты  ресторан   москва, улица дыбенко, 36, корп. 1
# 2                 хазри      кафе       москва, клязьминская улица, 15
# 3  dormouse coffee shop   кофейня  москва, улица маршала федоренко, 12
# 4             иль марко  пиццерия      москва, правобережная улица, 1б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                hours        lat        lng  \
# 0                             ежедневно, 10:00–22:00  55.878494  37.478860
# 1                             ежедневно, 10:00–22:00  55.875801  37.484479
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00...  55.889146  37.525901
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ⚠️ Работа с дубликатами
#
# ---
#
# ✅ Хорошо, явных дубликатов нет это говорит о том, что данные изначально достаточно чистые и не требуют дополнительной обработки на этом этапе.
#
#
# ---
#
# ⚠️ В данных есть два столбца количество дубликатов в связке которых быть не должно. Это `name` и `address`.
#
# Но перед этим нужно провести нормализацию данных. Например, шоколадница и ШОКОЛАДНИЦА -> Шоколадница.
#
# ![image.png](attachment:image.png)
#
# ---
#
# 💬 Здесь можно оставить комментарий.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 2.2 Анализ пропущенных значений
#
# ---
#
# - Поищите пропуски: встречаются ли они, в каких столбцах?
# - Можно ли их обработать или оставить как есть?

# %% [markdown]
# ПРОПУЩЕННЫЕ ЗНАЧЕНИЯ

# %%
missing_data = df.isnull().sum()
missing_percent = (missing_data / len(df)) * 100
missing_df = pd.DataFrame({
    'Пропущено': missing_data,
    'Процент': missing_percent
})
print(missing_df[missing_df['Пропущено'] > 0])
# Out:
#                    Пропущено    Процент
# hours                    536   6.376398
# price                   5091  60.563883
# avg_bill                4590  54.603854
# middle_avg_bill         5257  62.538663
# middle_coffee_cup       7871  93.635498
# seats                   3611  42.957411

# %% [markdown]
# Анализ столбца middle_avg_bill

# %%
print(f"Заполнено: {df['middle_avg_bill'].notna().sum()} / {len(df)}")
# Out:
# Заполнено: 3149 / 8406

# %%
print(f"Процент заполнения: {(df['middle_avg_bill'].notna().sum() / len(df) * 100):.2f}%")
# Out:
# Процент заполнения: 37.46%

# %% [markdown]
# Анализ столбца middle_coffee_cup

# %%
print(f"Заполнено: {df['middle_coffee_cup'].notna().sum()} / {len(df)}")
print(f"Процент заполнения: {(df['middle_coffee_cup'].notna().sum() / len(df) * 100):.2f}%")
# Out:
# Заполнено: 535 / 8406
# Процент заполнения: 6.36%

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 2.3 Создание столбцов
#
# ---
#
# Выполните предобработку данных:
# - Создайте столбец `street` с названиями улиц из столбца с адресом.
# - Создайте столбец `is_24_7` с обозначением, что заведение работает ежедневно и круглосуточно (24/7):
#     - логическое значение True — если заведение работает ежедневно и круглосуточно;
#     - логическое значение False — в противоположном случае.

# %% [markdown]
# Создание столбца street (название улицы)

# %%
def extract_street(address):
    if pd.isna(address):
        return None
    
    # Разбиваем адрес на части
    parts = str(address).split(',')
    
    # Ищем улицу (обычно это второй элемент после номера дома)
    for part in parts:
        part = part.strip()
        # Проверяем, содержит ли часть слово "улица", "проспект", "бульвар" и т.д.
        street_keywords = ['ул.', 'улица', 'пр.', 'проспект', 'б-р', 'бульвар', 
                          'ш.', 'шоссе', 'наб.', 'набережная', 'аллея', 'пер.', 'переулок']
        
        for keyword in street_keywords:
            if keyword in part.lower():
                return part
    
    # Если не нашли, возвращаем второй элемент (обычно это улица)
    if len(parts) > 1:
        return parts[1].strip()
    
    return None

# %% [markdown]
# Применяем функцию к столбцу address

# %%
df['street'] = df['address'].apply(extract_street)

# %% [markdown]
# Проверяем результат

# %%
print(f"\nУдалось извлечь улицы для {df['street'].notna().sum()} / {len(df)} записей")
print("\nПримеры извлеченных улиц:")
print(df['street'].head(10))
# Out:
# Удалось извлечь улицы для 8406 / 8406 записей
#
# Примеры извлеченных улиц:
# 0              улица дыбенко
# 1              улица дыбенко
# 2         клязьминская улица
# 3    улица маршала федоренко
# 4        правобережная улица
# 5             ижорская улица
# 6         клязьминская улица
# 7         клязьминская улица
# 8          дмитровское шоссе
# 9            ангарская улица
# Name: street, dtype: object

# %% [markdown]
# Создание столбца is_24_7 (круглосуточные заведения)

# %%
def check_24_7(hours):
    if pd.isna(hours):
        return False
    
    hours_str = str(hours).lower()
    
    # Проверяем различные варианты обозначения круглосуточной работы
    patterns = [
        r'24/7',
        r'круглосуточно',
        r'ежедневно.*24.*часа',
        r'24 часа',
        r'0:00.*24:00',
        r'00:00.*24:00',
        r'00:00.*00:00'
    ]
    
    for pattern in patterns:
        if re.search(pattern, hours_str):
            return True
    
    # Дополнительная проверка для формата "пн-вс 0:00-24:00"
    if re.search(r'пн.*вс.*0.*24', hours_str) or re.search(r'ежедневно.*0.*24', hours_str):
        return True
    
    return False

# %% [markdown]
# Применяем функцию

# %%
df['is_24_7'] = df['hours'].apply(check_24_7)

print(f"\nКоличество круглосуточных заведений: {df['is_24_7'].sum()}")

# Преобразование типов данных
df['seats'] = pd.to_numeric(df['seats'], errors='coerce')
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
# Out:
# Количество круглосуточных заведений: 1139

# %%
def check_24_7_corrected(hours):
    """
    Определяет, работает ли заведение круглосуточно.
    Учитывает различные форматы записи времени работы.
    """
    if pd.isna(hours):
        return False
    
    hours_str = str(hours).lower()
    
    # Очищаем строку от лишних пробелов и символов
    hours_str = hours_str.strip()
    
    # Если строка слишком короткая или содержит ошибки, пропускаем
    if len(hours_str) < 5:
        return False
    
    # 1. Прямые указания на круглосуточную работу
    round_the_clock_keywords = [
        'круглосуточно',
        '24/7',
        '24 часа',
        'круглосут',
        '24часа',
        '24 ч',
        '24ч',
        '24 часа в сутки',
        'ежедневно, круглосуточно',
        'работаем круглосуточно',
        'открыто круглосуточно',
        'круглосуточный',
        '24 7',
        '24 часа без перерыва'
    ]
    
    for keyword in round_the_clock_keywords:
        if keyword in hours_str:
            return True
    
    # 2. Проверяем формат времени, охватывающий все 24 часа
    time_patterns = [
        # Полные форматы с двоеточием
        r'00:00.*24:00',
        r'0:00.*24:00',
        r'00:00.*00:00',  # тоже круглосуточно
        r'0:00.*0:00',
        
        # Форматы с тире вместо двоеточия
        r'00-00.*24-00',
        r'0-00.*24-00',
        r'00-00.*00-00',
        
        # Форматы без разделителей
        r'0000.*2400',
        r'00 00.*24 00',
        
        # Форматы с точками
        r'00.00.*24.00',
        
        # Любой формат от 0 до 24
        r'\b0[:\-\s\.]?00.*24[:\-\s\.]?00\b',
        r'\b00[:\-\s\.]?00.*00[:\-\s\.]?00\b'  # от 00:00 до 00:00
    ]
    
    for pattern in time_patterns:
        if re.search(pattern, hours_str, re.IGNORECASE):
            return True
    
    # 3. Проверяем по дням недели с указанием 0-24 часов
    days_of_week = ['пн', 'вт', 'ср', 'чт', 'пт', 'сб', 'вс', 'ежедневно']
    days_patterns = [
        # Любой день недели с 0 до 24
        r'[\w\-]*0.*24',
        r'[\w\-]*00.*24',
        
        # Конкретные форматы
        r'пн.*вс.*0.*24',
        r'пн.*вс.*00.*24',
        r'ежедневно.*0.*24',
        r'ежедневно.*00.*24',
        r'пн-вс.*0.*24',
        r'пн-вс.*00.*24',
        
        # С понедельника по воскресенье
        r'с.*пн.*по.*вс.*0.*24',
        r'с.*пн.*по.*вс.*00.*24',
        
        # Без выходных
        r'без.*выходных.*0.*24',
        r'без.*выходных.*00.*24'
    ]
    
    for pattern in days_patterns:
        if re.search(pattern, hours_str, re.IGNORECASE):
            return True
    
    # 4. Проверяем, есть ли указание на работу все 24 часа
    if re.search(r'24\s*час', hours_str) or re.search(r'24\s*часов', hours_str):
        # Убедимся, что это именно про время работы, а не про что-то другое
        time_related = any(word in hours_str for word in ['работа', 'открыт', 'закрыт', 'час', 'время'])
        if time_related:
            return True
    
    return False

# Применяем исправленную функцию
df['is_24_7'] = df['hours'].apply(check_24_7_corrected)

print(f"✅ Столбец is_24_7 создан успешно")
print(f"📊 Количество круглосуточных заведений: {df['is_24_7'].sum():,}".replace(',', ' '))
print(f"📈 Доля круглосуточных заведений: {(df['is_24_7'].sum() / len(df) * 100):.2f}%")

# Проверяем примеры круглосуточных заведений
print("\n🔍 ПРИМЕРЫ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ:")
round_the_clock_examples = df[df['is_24_7'] == True][['name', 'category', 'hours']].head(10)
print(f"Найдено примеров: {len(round_the_clock_examples)}")
for idx, row in round_the_clock_examples.iterrows():
    hours_display = str(row['hours'])[:50] + "..." if len(str(row['hours'])) > 50 else str(row['hours'])
    print(f"• {row['name']} ({row['category']}): {hours_display}")

# Проверяем распределение по категориям
print("\n📊 РАСПРЕДЕЛЕНИЕ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ:")
if df['is_24_7'].sum() > 0:
    round_the_clock_by_category = df[df['is_24_7'] == True]['category'].value_counts().head(10)
    total_24_7 = df['is_24_7'].sum()
    
    for category, count in round_the_clock_by_category.items():
        percentage = (count / total_24_7 * 100)
        total_in_category = df[df['category'] == category].shape[0]
        category_percentage = (count / total_in_category * 100)
        print(f"  {category}: {count} заведений ({percentage:.1f}% от всех круглосуточных, {category_percentage:.1f}% в категории)")
else:
    print("Круглосуточных заведений не найдено")

# Дополнительная валидация
print("\n🔍 ПРОВЕРКА КАЧЕСТВА ДАННЫХ:")
print("-" * 40)

# Проверяем заведения с упоминанием "24" в часах работы
hours_with_24 = df[df['hours'].notna() & df['hours'].str.contains('24', na=False)]
print(f"Заведений с упоминанием '24' в часах: {len(hours_with_24)}")

if len(hours_with_24) > 0:
    # Смотрим, какие из них определены как круглосуточные
    correctly_identified = hours_with_24[hours_with_24['is_24_7'] == True]
    not_identified = hours_with_24[hours_with_24['is_24_7'] == False]
    
    print(f"Из них определены как круглосуточные: {len(correctly_identified)}")
    print(f"Не определены как круглосуточные: {len(not_identified)}")
    
    if len(not_identified) > 0:
        print("\nПримеры неопределенных заведений (первые 3):")
        for idx, row in not_identified.head(3).iterrows():
            print(f"• {row['name']}: {row['hours']}")
            # Проверяем почему не определилось
            test_result = check_24_7_corrected(row['hours'])
            print(f"  Проверка функции: {test_result}")

# Проверяем заведения с упоминанием "круглосуточно"
hours_with_kruglosut = df[df['hours'].notna() & df['hours'].str.contains('круглосут', na=False, case=False)]
print(f"\nЗаведений с упоминанием 'круглосут' в часах: {len(hours_with_kruglosut)}")

if len(hours_with_kruglosut) > 0:
    correctly_identified_krug = hours_with_kruglosut[hours_with_kruglosut['is_24_7'] == True]
    print(f"Из них определены как круглосуточные: {len(correctly_identified_krug)}")

# =============================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД ПО КРУГЛОСУТОЧНЫМ ЗАВЕДЕНИЯМ
# =============================================================================

print("\n" + "="*80)
print("АНАЛИТИЧЕСКИЙ ВЫВОД: КРУГЛОСУТОЧНЫЕ ЗАВЕДЕНИЯ В МОСКВЕ")
print("="*80)

total_establishments = len(df)
total_24_7 = df['is_24_7'].sum()
percentage_24_7 = (total_24_7 / total_establishments * 100)

print(f"\n📊 ОБЩАЯ СТАТИСТИКА:")
print(f"• Всего заведений в датасете: {total_establishments:,}".replace(',', ' '))
print(f"• Круглосуточных заведений: {total_24_7:,}".replace(',', ' '))
print(f"• Доля круглосуточных заведений: {percentage_24_7:.2f}%")
print(f"• Примерно каждое {int(100/percentage_24_7) if percentage_24_7 > 0 else 'N/A'}-е заведение работает круглосуточно")

if total_24_7 > 0:
    # Анализ по категориям
    top_categories_24_7 = df[df['is_24_7'] == True]['category'].value_counts().head(5)
    
    print(f"\n🏆 ТОП-5 КАТЕГОРИЙ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ:")
    for i, (category, count) in enumerate(top_categories_24_7.items(), 1):
        cat_percentage = (count / total_24_7 * 100)
        overall_cat_count = df[df['category'] == category].shape[0]
        cat_24_7_percentage = (count / overall_cat_count * 100)
        print(f"  {i}. {category}:")
        print(f"     • Круглосуточных: {count} ({cat_percentage:.1f}% от всех круглосуточных)")
        print(f"     • Доля в категории: {cat_24_7_percentage:.1f}% от всех заведений этой категории")
    
    # Проверка качества определения
    print(f"\n🔍 КАЧЕСТВО ОПРЕДЕЛЕНИЯ:")
    print(f"• Заведений с '24' в часах работы: {len(hours_with_24)}")
    if len(hours_with_24) > 0:
        accuracy = (len(correctly_identified) / len(hours_with_24) * 100)
        print(f"• Из них правильно определены: {len(correctly_identified)} ({accuracy:.1f}%)")
    
    print(f"• Заведений с 'круглосут' в часах работы: {len(hours_with_kruglosut)}")
    if len(hours_with_kruglosut) > 0:
        accuracy_krug = (len(correctly_identified_krug) / len(hours_with_kruglosut) * 100)
        print(f"• Из них правильно определены: {len(correctly_identified_krug)} ({accuracy_krug:.1f}%)")
# Out:
# ✅ Столбец is_24_7 создан успешно
# 📊 Количество круглосуточных заведений: 1 673
# 📈 Доля круглосуточных заведений: 19.90%
#
# 🔍 ПРИМЕРЫ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ:
# Найдено примеров: 10
# • mr. уголёк (быстрое питание): пн-чт 10:00–22:00; пт,сб 10:00–23:00; вс 10:00–22:...
# • great room bar (бар,паб): ежедневно, круглосуточно
# • дом обеда (столовая): пн-пт 08:30–18:30; сб 10:00–20:00
# • чайхана беш-бармак (ресторан): ежедневно, круглосуточно
# • пекарня (булочная): ежедневно, круглосуточно
# • drive café (кафе): ежедневно, круглосуточно
# • 2u-ту-ю (пиццерия): ежедневно, круглосуточно
# • шаурма (быстрое питание): ежедневно, круглосуточно
# • шашлык (быстрое питание): ежедневно, круглосуточно
# • кафе лоза (ресторан): ежедневно, круглосуточно
#
# 📊 РАСПРЕДЕЛЕНИЕ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ:
#   кафе: 430 заведений (25.7% от всех круглосуточных, 18.1% в категории)
#   ресторан: 403 заведений (24.1% от всех круглосуточных, 19.7% в категории)
# ...

# %% [markdown]
# ✅ Столбец is_24_7 создан успешно
# 📊 Количество круглосуточных заведений: 1 673
# 📈 Доля круглосуточных заведений: 19.90%
#
# 🔍 ПРИМЕРЫ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ:
# Найдено примеров: 10
# • Mr. Уголёк (быстрое питание): пн-чт 10:00–22:00; пт,сб 10:00–23:00; вс 10:00–22:...
# • Great Room Bar (бар,паб): ежедневно, круглосуточно
# • Дом обеда (столовая): пн-пт 08:30–18:30; сб 10:00–20:00
# • Чайхана Беш-Бармак (ресторан): ежедневно, круглосуточно
# • Пекарня (булочная): ежедневно, круглосуточно
# • Drive Café (кафе): ежедневно, круглосуточно
# • 2U-Ту-Ю (пиццерия): ежедневно, круглосуточно
# • Шаурма (быстрое питание): ежедневно, круглосуточно
# • Шашлык (быстрое питание): ежедневно, круглосуточно
# • Кафе Лоза (ресторан): ежедневно, круглосуточно
#
# 📊 РАСПРЕДЕЛЕНИЕ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ:
#   кафе: 430 заведений (25.7% от всех круглосуточных, 18.1% в категории)
#   ресторан: 403 заведений (24.1% от всех круглосуточных, 19.7% в категории)
#   бар,паб: 277 заведений (16.6% от всех круглосуточных, 36.2% в категории)
#   кофейня: 189 заведений (11.3% от всех круглосуточных, 13.4% в категории)
#   быстрое питание: 188 заведений (11.2% от всех круглосуточных, 31.2% в категории)
#   пиццерия: 123 заведений (7.4% от всех круглосуточных, 19.4% в категории)
#   булочная: 36 заведений (2.2% от всех круглосуточных, 14.1% в категории)
#   столовая: 27 заведений (1.6% от всех круглосуточных, 8.6% в категории)
#
# 🔍 ПРОВЕРКА КАЧЕСТВА ДАННЫХ:
# ----------------------------------------
# Заведений с упоминанием '24' в часах: 0
#
# Заведений с упоминанием 'круглосут' в часах: 772
# Из них определены как круглосуточные: 772
#
# ================================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД: КРУГЛОСУТОЧНЫЕ ЗАВЕДЕНИЯ В МОСКВЕ
# ================================================================================
#
# 📊 ОБЩАЯ СТАТИСТИКА:
# • Всего заведений в датасете: 8 406
# • Круглосуточных заведений: 1 673
# • Доля круглосуточных заведений: 19.90%
# • Примерно каждое 5-е заведение работает круглосуточно
#
# 🏆 ТОП-5 КАТЕГОРИЙ КРУГЛОСУТОЧНЫХ ЗАВЕДЕНИЙ:
#   1. кафе:
#      • Круглосуточных: 430 (25.7% от всех круглосуточных)
#      • Доля в категории: 18.1% от всех заведений этой категории
#   2. ресторан:
#      • Круглосуточных: 403 (24.1% от всех круглосуточных)
#      • Доля в категории: 19.7% от всех заведений этой категории
#   3. бар,паб:
#      • Круглосуточных: 277 (16.6% от всех круглосуточных)
#      • Доля в категории: 36.2% от всех заведений этой категории
#   4. кофейня:
#      • Круглосуточных: 189 (11.3% от всех круглосуточных)
#      • Доля в категории: 13.4% от всех заведений этой категории
#   5. быстрое питание:
#      • Круглосуточных: 188 (11.2% от всех круглосуточных)
#      • Доля в категории: 31.2% от всех заведений этой категории
#
# 🔍 КАЧЕСТВО ОПРЕДЕЛЕНИЯ:
# • Заведений с '24' в часах работы: 0
# • Заведений с 'круглосут' в часах работы: 772
# • Из них правильно определены: 772 (100.0%)

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Столбец is_24_7
#
# ---
#
# ⛔ Стобец создан некорректно.
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий.
#
# вроде сейчас корректно сделал
#
# ---
#
# ✅ Да, теперь все верно.

# %% [markdown]
# Типы данных после преобразования:

# %%
df.dtypes
# Out:
# name                  object
# category              object
# address               object
# district              object
# hours                 object
# lat                  float64
# lng                  float64
# rating               float64
# price                 object
# avg_bill              object
# middle_avg_bill      float64
# middle_coffee_cup    float64
# chain                  int64
# seats                float64
# street                object
# is_24_7                 bool
# dtype: object

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Вынужден прервать проверку, так не выполнены условия задания и из-за этого прокет мало похож на исследование. Так как весь код находится в нескольких ячейках, нет разделения на логические блоки, нет выводов по каждому пункту, не прокомментированы графики, нет развернутого итогового вывода.
#
# Согласно заданию:
#
#
#
# Пример, как должен быть оформить проект, оставил ниже:
#
#
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# ✅ Сейчас посмотрю.

# %%
df.head()
# Out:
#                    name  category                              address  \
# 0                wowфли      кафе           москва, улица дыбенко, 7/1
# 1        четыре комнаты  ресторан   москва, улица дыбенко, 36, корп. 1
# 2                 хазри      кафе       москва, клязьминская улица, 15
# 3  dormouse coffee shop   кофейня  москва, улица маршала федоренко, 12
# 4             иль марко  пиццерия      москва, правобережная улица, 1б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                hours        lat        lng  \
# 0                             ежедневно, 10:00–22:00  55.878494  37.478860
# 1                             ежедневно, 10:00–22:00  55.875801  37.484479
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00...  55.889146  37.525901
# ...

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Потребление памяти
#
# ---
#
# ⚠️ Лучше ограничивать кол-во выводимых строк. Если делать вывод без ограничения кол-ва, то это сильно подгружает тетрадку, и это будет тратить твое время.
#
# А еще это может вызывать ошибку при загрузке тетрадки на JH, при большом количестве строк.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
#     df.head()
#
# ---
#
# ✅ Хорошо.

# %% [markdown]
# # Анализ данных

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.1 Анализ категорий
#
# ---
#
# **Шаг 3. Анализ данных**
#
# Какие категории заведений представлены в данных?
#
# - Исследуйте количество объектов общественного питания по категориям: рестораны, кофейни, пиццерии, бары и так далее.
# - Постройте визуализации.
# - Ответьте на вопрос о распределении заведений по категориям.

# %% [markdown]
# РАСПРЕДЕЛЕНИЕ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ

# %%
category_counts = df['category'].value_counts()

# %% [markdown]
# Всего категорий:

# %%
len(category_counts)
# Out:
# 8

# %% [markdown]
# Топ-10 категорий

# %%
category_counts.head(10)
# Out:
# category
# кафе               2378
# ресторан           2043
# кофейня            1413
# бар,паб             765
# пиццерия            633
# быстрое питание     603
# столовая            315
# булочная            256
# Name: count, dtype: int64

# %% [markdown]
# Визуализация: распределение по категориям (топ-15)

# %%
plt.figure(figsize=(14, 8))
top_categories = category_counts.head(15)
bars = plt.barh(top_categories.index[::-1], top_categories.values[::-1])
plt.xlabel('Количество заведений')
plt.title('Топ-15 категорий заведений общественного питания в Москве', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

for bar in bars:
    width = bar.get_width()
    plt.text(width + 10, bar.get_y() + bar.get_height()/2, 
             f'{int(width)}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Круговой график для основных категорий

# %%
main_categories = ['кафе', 'ресторан', 'кофейня', 'бар', 'паб', 'столовая', 
                   'пиццерия', 'фастфуд', 'буфет', 'кондитерская']
main_df = df[df['category'].isin(main_categories)]

plt.figure(figsize=(10, 10))
main_counts = main_df['category'].value_counts()
plt.pie(main_counts.values, labels=main_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Распределение основных категорий заведений', fontsize=16, fontweight='bold')
plt.axis('equal')
plt.show()

# %% [markdown]
# В итоге что мы имеем:
#
# распределение основных категорий заведений:
#
# кафе - 35%
#
# столовые - 4.6%
#
# пиццерия - 9.3%
#
# кофейня - 20.8%
#
# ресторан - 30%

# %% [markdown]
# ================================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД: РАСПРЕДЕЛЕНИЕ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ
# ================================================================================
#
# 📊 ОБЩАЯ СТАТИСТИКА:
# • Всего заведений в датасете: 8 406
# • Количество категорий: 8
# • Наиболее представленная категория: 'кафе'
#
# 🏆 РАСПРЕДЕЛЕНИЕ ПО КАТЕГОРИЯМ:
# ============================================================
#       Категория  Количество  Доля, % Каждое N-е заведение
#            кафе        2378     28.3               1 из 3
#        ресторан        2043     24.3               1 из 4
#         кофейня        1413     16.8               1 из 5
#         бар,паб         765      9.1              1 из 10
#        пиццерия         633      7.5              1 из 13
# быстрое питание         603      7.2              1 из 13
#        столовая         315      3.7              1 из 27
#        булочная         256      3.0              1 из 33
#
# 📈 ДЕТАЛЬНЫЙ АНАЛИЗ КЛЮЧЕВЫХ КАТЕГОРИЙ:
# ============================================================
#
# 📍 КАФЕ:
#    • Количество: 2 378
#    • Доля рынка: 28.3%
#    • Частота: каждое 3-е заведение
#    • Анализ: Самая популярная категория, составляет более трети всего рынка.
#      Это базовый формат общепита в Москве, подходящий для различных концепций.
#
# 📍 РЕСТОРАН:
#    • Количество: 2 043
#    • Доля рынка: 24.3%
#    • Частота: каждое 4-е заведение
#    • Анализ: Вторая по популярности категория, почти треть рынка.
#      Свидетельствует о развитой ресторанной культуре и платежеспособном спросе.
#
# 📍 КОФЕЙНЯ:
#    • Количество: 1 413
#    • Доля рынка: 16.8%
#    • Частота: каждое 5-е заведение
#    • Анализ: Значительная доля (20.8%), Москва - 'кофейный' город.
#      Высокая конкуренция, но и стабильный спрос на кофе навынос.
#
# 📍 ПИЦЦЕРИЯ:
#    • Количество: 633
#    • Доля рынка: 7.5%
#    • Частота: каждое 13-е заведение
#    • Анализ: Стабильная ниша (9.3%), популярный формат для доставки.
#      Конкуренция с сетями и локальными пиццериями.
#
# 📍 БАР,ПАБ:
#    • Количество: 765
#    • Доля рынка: 9.1%
#    • Частота: каждое 10-е заведение
#    • Анализ: 9.1% рынка, развитая культура посиделок в барах.
#      Зависит от локации (центр vs спальные районы).
#
# 📍 СТОЛОВАЯ:
#    • Количество: 315
#    • Доля рынка: 3.7%
#    • Частота: каждое 27-е заведение
#
# 📍 БУЛОЧНАЯ:
#    • Количество: 256
#    • Доля рынка: 3.0%
#    • Частота: каждое 33-е заведение
#
# 📍 БЫСТРОЕ ПИТАНИЕ:
#    • Количество: 603
#    • Доля рынка: 7.2%
#    • Частота: каждое 13-е заведение
#
# 🔍 КЛЮЧЕВЫЕ ИНСАЙТЫ И ВЫВОДЫ:
# ============================================================
#
# 1. СТРУКТУРА РЫНКА:
#
# • Три категории доминируют (85.8% рынка вместе):
#   - Кафе (35.3%) - массовый сегмент
#   - Рестораны (30.0%) - премиальный и средний сегмент
#   - Кофейни (20.8%) - специализированный сегмент
#
# • Остальные 5 категорий делят лишь 14.2% рынка, что указывает на:
#   - Специализированный характер этих форматов
#   - Возможность нишевого позиционирования
#
#
# 2. СРАВНИТЕЛЬНЫЙ АНАЛИЗ:
#
# • Кафе vs Рестораны:
#   - Кафе на 5.3% более распространены
#   - Разница незначительна, что говорит о сбалансированности рынка
#   - Кафе чаще ориентированы на повседневное посещение, рестораны - на особые случаи
#
# • Кофейни как отдельный сегмент:
#   - 20.8% - очень высокая доля для специализированного формата
#   - Указывает на зрелую кофейную культуру в Москве
#   - Высокая конкуренция, но и стабильный спрос
#
#
# 3. РЫНОЧНЫЕ ТЕНДЕНЦИИ:
#
# • Массовость vs Специализация:
#   - 85% рынка - это универсальные форматы (кафе, рестораны, кофейни)
#   - 15% рынка - специализированные форматы (пиццерии, бары и т.д.)
#
# • Потенциал роста:
#   - Нишевые форматы могут иметь меньше конкурентов
#   - Универсальные форматы имеют большую целевую аудиторию
#
# • Географические особенности:
#   - Распределение может значительно различаться по районам
#   - Центр: больше ресторанов и кофеен
#   - Спальные районы: больше кафе и столовых
#
#
# 💼 БИЗНЕС-ИНТЕРПРЕТАЦИЯ ДЛЯ ИНВЕСТОРОВ:
# ============================================================
#
# 1. ДЛЯ НОВОГО ЗАВЕДЕНИЯ РЕКОМЕНДУЕТСЯ:
#
# • Формат кафе (если цель - массовый рынок):
#   - Преимущества: Широкая аудитория, гибкая концепция
#   - Риски: Высокая конкуренция, требуется уникальное УТП
#
# • Формат кофейни (если цель - специализация):
#   - Преимущества: Стабильный спрос, лояльная аудитория
#   - Риски: Насыщенный рынок, требуется качество кофе
#
# • Формат ресторана (если есть опыт и бюджет):
#   - Преимущества: Высокий средний чек, престиж
#   - Риски: Высокие инвестиции, сезонность спроса
#
#
# 2. АЛЬТЕРНАТИВНЫЕ ВАРИАНТЫ (НИШЕВЫЕ):
#
# • Пиццерия (9.3%):
#   - Плюсы: Популярный формат, хорош для доставки
#   - Минусы: Конкуренция с сетями
#
# • Бар/паб (9.1%):
#   - Плюсы: Лояльная аудитория, вечерний трафик
#   - Минусы: Зависит от локации, лицензирование
#
# • Столовая (2.4%):
#   - Плюсы: Низкая конкуренция, стабильный спрос
#   - Минусы: Низкая маржинальность, сегмент B2B
#
#
# 3. РЕКОМЕНДАЦИИ ПО ВЫБОРУ ФОРМАТА:
#
# ✅ Для первого проекта: Кафе или кофейня среднего формата
# ✅ При наличии опыта: Специализированный ресторан или бар
# ✅ Для низкого бюджета: Небольшая кофейня или нишевое кафе
# ✅ Для масштабирования: Сетевая кофейня или фастфуд

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Задача 3.1 Анализ категорий
#
# ---
#
# Цитата из задания:
#
# ```
# Какие категории заведений представлены в данных? Исследуйте количество объектов общественного питания по категориям: рестораны, кофейни, пиццерии, бары и так далее. Постройте визуализации. Ответьте на вопрос о распределении заведений по категориям.
# ```
#
# ---
#
# ⚠️ Исследованы категории
#
# - Данные стоит рассматривать не только в абсолютных значениях, но и в процентах, так их проще и быстрее анализировать.
#
# ---
#
# ✅ Оформление графиков.
#
# ---
#
# ⛔ Аналитический вывод по итогам исследования задачи.
#
# - Интерпретация данных отсутствует. Важно учитывать, что у заказчика тетрадка может открыться с ячейками, в которых не отображаются результаты выполнения кода. В таком случае он увидит только код — без чисел и графиков, а значит, исследование потеряет смысл.
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# ✅ Молодец.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.2 Анализ мест
#
# ---
#
# - Исследуйте количество посадочных мест в местах по категориям: рестораны, кофейни, пиццерии, бары и так далее.
# - Постройте визуализации.
# - Проанализируйте результаты и сделайте выводы.

# %% [markdown]
# АНАЛИЗ ПОСАДОЧНЫХ МЕСТ ПО КАТЕГОРИЯМ

# %%
seats_df = df.dropna(subset=['seats'])

seats_by_category = seats_df.groupby('category')['seats'].agg(['mean', 'median', 'count']).round(1)
seats_by_category = seats_by_category.sort_values('median', ascending=False)

print("Топ-10 категорий по медианному количеству мест:")
print(seats_by_category.head(10))
# Out:
# Топ-10 категорий по медианному количеству мест:
#                   mean  median  count
# category
# ресторан         121.9    86.0   1270
# бар,паб          124.5    82.5    468
# кофейня          111.2    80.0    751
# столовая          99.8    75.5    164
# быстрое питание   98.9    65.0    349
# кафе              97.5    60.0   1218
# пиццерия          94.5    55.0    427
# булочная          89.4    50.0    148

# %% [markdown]
# Визуализация: boxplot по основным категориям

# %%
plt.figure(figsize=(14, 8))
main_cats_seats = seats_df[seats_df['category'].isin(main_categories)]

# Убираем выбросы для лучшей визуализации
Q1 = main_cats_seats['seats'].quantile(0.25)
Q3 = main_cats_seats['seats'].quantile(0.75)
IQR = Q3 - Q1
filtered_seats = main_cats_seats[
    (main_cats_seats['seats'] >= Q1 - 1.5*IQR) & 
    (main_cats_seats['seats'] <= Q3 + 1.5*IQR)
]

sns.boxplot(data=filtered_seats, x='seats', y='category', color='steelblue', order=filtered_seats.groupby('category')['seats'].median().sort_values(ascending=False).index)
plt.xlabel('Количество посадочных мест')
plt.ylabel('Категория')
plt.title('Распределение посадочных мест по основным категориям', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Из графика видно, что рестораны имеют наибольшее количество посадочных мест, за ними следуют кофейни и столовые. Кафе и пиццерии имеют примерно одинаковое количество посадочных мест, которое меньше, чем у предыдущих категорий. Это может свидетельствовать о том, что рестораны, как правило, рассчитаны на большее количество посетителей одновременно, в то время как кафе и пиццерии могут быть более компактными и ориентированы на меньшие группы людей

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Задача 3.2 Анализ посадочных мест
#
# ---
#
# Цитата из задания:
#
# ```
# Исследуйте количество посадочных мест в местах по категориям: рестораны, кофейни, пиццерии, бары и так далее. Постройте визуализации. Проанализируйте результаты и сделайте выводы.
# ```
#
# ---
#
# ✅ Исследовано кол-во посадочных мест по категориям.
#
# ---
#
# ⛔ Оформление графиков.
#
# - Хорошая визуализация, осталось сделать шкалы одним цветом. Разноцветные шкалы нужны когда столбцы нужно различать, например когда есть легенда.
#
#
#
# ---
#
# ⛔ Аналитический вывод по итогам исследования задачи.
#
# - Интерпретация данных отсутствует.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# **Итерация 3**
#
# ---
#
# ⛔ Комментарий не исправлен. Интерпретация данных отсутствует.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# вроде внес комментарий
#
# Из графика видно, что рестораны имеют наибольшее количество посадочных мест, за ними следуют кофейни и столовые. Кафе и пиццерии имеют примерно одинаковое количество посадочных мест, которое меньше, чем у предыдущих категорий. Это может свидетельствовать о том, что рестораны, как правило, рассчитаны на большее количество посетителей одновременно, в то время как кафе и пиццерии могут быть более компактными и ориентированы на меньшие группы людей
#
#
# ---
#
# **Итерация 4**
#
# ✅ Хорошо.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.3 Анализ сетей
#
# ---
#
# Рассмотрите и изобразите соотношение сетевых и несетевых заведений в датасете.
#
# - Каких заведений больше?

# %% [markdown]
# СООТНОШЕНИЕ СЕТЕВЫХ И НЕСЕТЕВЫХ ЗАВЕДЕНИЙ
# ==================================================
# Сетевые заведения: 3205 (38.1%)
#
# Несетевые заведения: 5201 (61.9%)
#
# КАТЕГОРИИ, ЧАЩЕ ЯВЛЯЮЩИЕСЯ СЕТЕВЫМИ
# ==================================================
# Топ-10 категорий по доле сетевых заведений:
#
#                  total  chain_count  chain_percent
#
# category
#
# булочная           256          157           61.3
#
# пиццерия           633          330           52.1
#
# кофейня           1413          720           51.0
#
# быстрое питание    603          232           38.5
#
# ресторан          2043          730           35.7
#
# кафе              2378          779           32.8
#
# столовая           315           88           27.9
#
# бар,паб            765          169           22.1
#
#
#
# ТОП-15 ПОПУЛЯРНЫХ СЕТЕЙ
# ==================================================
# Топ-15 сетей по количеству заведений:
#  1. шоколадница                              - 120 заведений (кофейня)
#  2. домино'с пицца                           -  76 заведений (пиццерия)
#  3. додо пицца                               -  74 заведений (пиццерия)
#  4. one price coffee                         -  71 заведений (кофейня)
#  5. яндекс лавка                             -  69 заведений (ресторан)
#  6. cofix                                    -  65 заведений (кофейня)
#  7. prime                                    -  50 заведений (ресторан)
#  8. хинкальная                               -  44 заведений (быстрое питание)
#  9. кофепорт                                 -  42 заведений (кофейня)
# 10. кулинарная лавка братьев караваевых      -  39 заведений (кафе)
# 11. теремок                                  -  38 заведений (ресторан)
# 12. чайхана                                  -  37 заведений (кафе)
# 13. cofefest                                 -  32 заведений (кофейня)
# 14. буханка                                  -  32 заведений (булочная)
# 15. му-му                                    -  27 заведений (кафе)
#
#
#
#
# РАСПРЕДЕЛЕНИЕ ЗАВЕДЕНИЙ ПО РАЙОНАМ
# ==================================================
# Всего районов: 9
#
# Топ-10 районов по количеству заведений:
#
# district
#
# Центральный административный округ         2242
#
# Северный административный округ             900
#
# Южный административный округ                892
#
# Северо-Восточный административный округ     891
#
# Западный административный округ             851
#
# Восточный административный округ            798
#
# Юго-Восточный административный округ        714
#
# Юго-Западный административный округ         709
#
# Северо-Западный административный округ      409
#
#
#
# РАСПРЕДЕЛЕНИЕ РЕЙТИНГОВ ПО КАТЕГОРИЯМ
# ==================================================
# Топ-10 категорий по среднему рейтингу:
#
#                   mean  median  count    std
#
# category
#
# бар,паб          4.388     4.4    765  0.380
#
# пиццерия         4.301     4.3    633  0.336
#
# ресторан         4.290     4.3   2043  0.413
#
# кофейня          4.277     4.3   1413  0.372
#
# булочная         4.268     4.3    256  0.386
#
# столовая         4.211     4.3    315  0.454
#
# кафе             4.124     4.2   2378  0.566
#
# быстрое питание  4.050     4.2    603  0.561
#
#
#
# Низ-10 категорий по среднему рейтингу:
#
#                   mean  median  count    std
#
# category
#
# бар,паб          4.388     4.4    765  0.380
#
# пиццерия         4.301     4.3    633  0.336
#
# ресторан         4.290     4.3   2043  0.413
#
# кофейня          4.277     4.3   1413  0.372
#
# булочная         4.268     4.3    256  0.386
#
# столовая         4.211     4.3    315  0.454
#
# кафе             4.124     4.2   2378  0.566
#
# быстрое питание  4.050     4.2    603  0.561

# %% [markdown]
# На основе предоставленной информации можно сделать следующие выводы:
#
# 1. **Соотношение сетевых и несетевых заведений**:
#    - Несетевые заведения составляют большинство (61.9%), что указывает на преобладание небольших, независимых заведений в Москве.
#    - Сетевые заведения (38.1%) также занимают значительную долю рынка, что свидетельствует о популярности и успешности сетевых форматов.
#
# 2. **Категории, чаще являющиеся сетевыми**:
#    - Булочные, пиццерии и кофейни чаще всего являются сетевыми заведениями, что может быть связано с их популярностью и возможностью масштабирования.
#    - Рестораны и кафе также имеют значительную долю сетевых заведений, что указывает на успешность сетевых форматов в этих категориях.
#
# 3. **Топ-15 популярных сетей**:
#    - Сеть "Шоколадница" лидирует по количеству заведений, что подчеркивает ее популярность и успешность.
#    - Пиццерии и кофейни занимают значительную часть топ-15, что подтверждает их популярность среди потребителей.
#
# 4. **Распределение заведений по районам**:
#    - Центральный административный округ имеет наибольшее количество заведений, что связано с его высокой плотностью населения и туристической активностью.
#    - Остальные районы также имеют значительное количество заведений, что указывает на равномерное распределение заведений по городу.
#
# 5. **Распределение рейтингов по категориям**:
#    - Бары, пиццерии и рестораны имеют самые высокие средние рейтинги, что может быть связано с их качеством обслуживания и едой.
#    - Быстрое питание и кафе имеют более низкие рейтинги, что может быть связано с более низкими ожиданиями потребителей в этих категориях.
#
# 6. **Создание карты с кластерами**:
#    - Карта с кластерами заведений создана и сохранена в файл, что позволяет визуально оценить распределение заведений по городу.
#
# 7. **Топ-15 улиц по количеству заведений**:
#    - Проспект Мира и Профсоюзная улица лидируют по количеству заведений, что указывает на их популярность и высокую плотность заведений.
#
# 8. **Улицы с одним заведением**:
#    - Существует значительное количество улиц с одним заведением, что указывает на разнообразие и уникальность заведений в Москве.
#
# 9. **Анализ средних чеков по районам**:
#    - Центральный и Западный административные округа имеют самые высокие средние чеки, что может быть связано с их престижностью и высоким уровнем жизни.
#    - Юго-Восточный административный округ имеет самые низкие средние чеки, что может быть связано с его более низким уровнем жизни и экономическими условиями.
#
# Эти выводы помогают понять структуру и динамику рынка общественного питания в Москве, а также выявить ключевые тренды и особенности.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩ПИТАНИЕ  -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Вынужден повторно прервать проверку, так как не выполнены условия брифа и из-за далее проект мало похож на исследование. В проекте полностью отсутствует структура - нет заголовков шагов и заданий, текстовые комментарии находятся в ячейках code, что не соответствует требованиям. Нет форматирования текста, заголовков разделов, выводов по каждому пункту, а графики не прокомментированы.
#
# Цитаты из задания:
#
# ```
# Как сдать проект
#
# Основное задание выполните в Jupyter Notebook, программный код заполните в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
# ```
#
# ```
# Как будут проверять мой проект?
#
# ...
# - Cблюдаете ли вы структуру проекта и поддерживаете ли аккуратность кода?
# - Какие выводы вы делаете?
#     - Вывод очевиден из полученного результата.
#     - Вывод отвечает на поставленный вопрос.
# - Оставляете ли вы комментарии к шагам?
# - Комментарии расшифровывают, что вы делаете (в коде, в проекте).
# ```
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# далее я выводил статистику и объяснял ее
#
# ---
#
# ✅ Я написал не про статистику, а про нарушение ТЗ по оформлению.

# %%
# 3.3 Соотношение сетевых и несетевых заведений
print("\nСООТНОШЕНИЕ СЕТЕВЫХ И НЕСЕТЕВЫХ ЗАВЕДЕНИЙ")
print("=" * 50)

chain_counts = df['chain'].value_counts()
chain_percent = (chain_counts / len(df)) * 100

print(f"Сетевые заведения: {chain_counts.get(1, 0)} ({chain_percent.get(1, 0):.1f}%)")
print(f"Несетевые заведения: {chain_counts.get(0, 0)} ({chain_percent.get(0, 0):.1f}%)")

# Визуализация
plt.figure(figsize=(8, 8))
labels = ['Несетевые', 'Сетевые']
colors = ['#ff9999', '#66b3ff']
plt.pie([chain_counts.get(0, 0), chain_counts.get(1, 0)], 
        labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Соотношение сетевых и несетевых заведений', fontsize=16, fontweight='bold')
plt.axis('equal')
plt.show()

# 3.4 Какие категории чаще являются сетевыми
print("\nКАТЕГОРИИ, ЧАЩЕ ЯВЛЯЮЩИЕСЯ СЕТЕВЫМИ")
print("=" * 50)

# Группируем по категориям и считаем долю сетевых
chain_by_category = df.groupby('category').agg(
    total=('chain', 'count'),
    chain_count=('chain', lambda x: (x == 1).sum())
)
chain_by_category['chain_percent'] = (chain_by_category['chain_count'] / chain_by_category['total'] * 100).round(1)
chain_by_category = chain_by_category.sort_values('chain_percent', ascending=False)

print("Топ-10 категорий по доле сетевых заведений:")
print(chain_by_category.head(10))

# Визуализация (только категории с достаточным количеством заведений)
filtered_chain = chain_by_category[chain_by_category['total'] >= 10].head(15)

plt.figure(figsize=(14, 8))
bars = plt.barh(filtered_chain.index[::-1], filtered_chain['chain_percent'][::-1])
plt.xlabel('Доля сетевых заведений, %')
plt.title('Категории с наибольшей долей сетевых заведений', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

# Добавляем значения
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.5, bar.get_y() + bar.get_height()/2, 
             f'{width:.1f}%', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# 3.5 Топ-15 популярных сетей
print("\nТОП-15 ПОПУЛЯРНЫХ СЕТЕЙ")
print("=" * 50)

# Группируем по названиям заведений
chain_names = df[df['chain'] == 1]['name'].value_counts().head(15)

print("Топ-15 сетей по количеству заведений:")
for i, (name, count) in enumerate(chain_names.items(), 1):
    # Находим категорию для этой сети
    category = df[df['name'] == name]['category'].iloc[0] if not df[df['name'] == name].empty else 'Неизвестно'
    print(f"{i:2}. {name:40} - {count:3} заведений ({category})")

# Визуализация
plt.figure(figsize=(14, 10))
bars = plt.barh(range(len(chain_names)), chain_names.values[::-1])
plt.yticks(range(len(chain_names)), chain_names.index[::-1])
plt.xlabel('Количество заведений')
plt.title('Топ-15 популярных сетей в Москве', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

# Добавляем значения
for i, bar in enumerate(bars):
    width = bar.get_width()
    plt.text(width + 0.5, bar.get_y() + bar.get_height()/2, 
             f'{int(width)}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# 3.6 Распределение заведений по административным районам
print("\nРАСПРЕДЕЛЕНИЕ ЗАВЕДЕНИЙ ПО РАЙОНАМ")
print("=" * 50)

district_counts = df['district'].value_counts()
print(f"Всего районов: {len(district_counts)}")
print("\nТоп-10 районов по количеству заведений:")
print(district_counts.head(10))

# Визуализация: распределение по районам
plt.figure(figsize=(14, 10))
top_districts = district_counts.head(15)
bars = plt.barh(top_districts.index[::-1], top_districts.values[::-1])
plt.xlabel('Количество заведений')
plt.title('Топ-15 районов по количеству заведений общественного питания', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

# Добавляем значения
for bar in bars:
    width = bar.get_width()
    plt.text(width + 5, bar.get_y() + bar.get_height()/2, 
             f'{int(width)}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# Распределение категорий по районам (heatmap)
# Берем топ-10 районов и топ-10 категорий
top_10_districts = district_counts.head(10).index
top_10_categories = category_counts.head(10).index

# Создаем сводную таблицу
pivot_data = df[df['district'].isin(top_10_districts) & df['category'].isin(top_10_categories)]
pivot_table = pd.crosstab(pivot_data['district'], pivot_data['category'])

# Нормализуем по строкам для лучшей визуализации
pivot_table_norm = pivot_table.div(pivot_table.sum(axis=1), axis=0) * 100

plt.figure(figsize=(16, 10))
sns.heatmap(pivot_table_norm, annot=True, fmt='.1f', cmap='YlOrRd', linewidths=0.5)
plt.title('Доля категорий заведений по районам (%)', fontsize=16, fontweight='bold')
plt.xlabel('Категория')
plt.ylabel('Район')
plt.tight_layout()
plt.show()

# 3.7 Распределение средних рейтингов по категориям
print("\nРАСПРЕДЕЛЕНИЕ РЕЙТИНГОВ ПО КАТЕГОРИЯМ")
print("=" * 50)

# Удаляем пропуски в рейтингах
rating_df = df.dropna(subset=['rating'])

# Группируем по категориям
rating_by_category = rating_df.groupby('category')['rating'].agg(['mean', 'median', 'count', 'std']).round(3)
rating_by_category = rating_by_category[rating_by_category['count'] >= 10].sort_values('mean', ascending=False)

print("Топ-10 категорий по среднему рейтингу:")
print(rating_by_category.head(10))

print("\nНиз-10 категорий по среднему рейтингу:")
print(rating_by_category.tail(10))

# Визуализация: boxplot рейтингов по основным категориям
plt.figure(figsize=(14, 8))
main_cats_rating = rating_df[rating_df['category'].isin(main_categories)]

sns.boxplot(data=main_cats_rating, x='rating', y='category', 
            order=main_cats_rating.groupby('category')['rating'].median().sort_values(ascending=False).index)
plt.xlabel('Рейтинг')
plt.ylabel('Категория')
plt.title('Распределение рейтингов по основным категориям', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# 3.8 Карта с кластерами заведений
print("\nСОЗДАНИЕ КАРТЫ С КЛАСТЕРАМИ")
print("=" * 50)

# Создаем базовую карту Москвы
moscow_center = [55.7558, 37.6173]
m = folium.Map(location=moscow_center, zoom_start=11, tiles='CartoDB positron')

# Добавляем кластеры
marker_cluster = MarkerCluster().add_to(m)

# Добавляем заведения (выборочно для производительности)
sample_df = df.dropna(subset=['lat', 'lng']).sample(n=1000, random_state=42)

for idx, row in sample_df.iterrows():
    popup_text = f"""
    <b>{row['name']}</b><br>
    Категория: {row['category']}<br>
    Рейтинг: {row['rating'] if not pd.isna(row['rating']) else 'Н/Д'}<br>
    Адрес: {row['address'][:50]}...
    """
    
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=folium.Popup(popup_text, max_width=300),
        icon=folium.Icon(color='blue' if row['chain'] == 1 else 'green')
    ).add_to(marker_cluster)

print("Карта создана. Сохраняем в файл...")
m.save('moscow_restaurants_map.html')
print("Карта сохранена в файл 'moscow_restaurants_map.html'")

# 3.9 Топ-15 улиц по количеству заведений
print("\nТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ")
print("=" * 50)

street_counts = df['street'].value_counts().head(15)

print("Топ-15 улиц по количеству заведений:")
for i, (street, count) in enumerate(street_counts.items(), 1):
    print(f"{i:2}. {street:40} - {count:3} заведений")

# Визуализация: распределение категорий на топ-улицах
top_streets = street_counts.index
streets_data = df[df['street'].isin(top_streets)]

# Создаем сводную таблицу
street_category_pivot = pd.crosstab(streets_data['street'], streets_data['category'])

# Берем топ-5 категорий для каждой улицы
top_categories_per_street = {}
for street in top_streets:
    if street in street_category_pivot.index:
        top_cats = street_category_pivot.loc[street].nlargest(5)
        top_categories_per_street[street] = top_cats

# Визуализируем
fig, axes = plt.subplots(5, 3, figsize=(18, 20))
axes = axes.flatten()

for i, (street, cats) in enumerate(top_categories_per_street.items()):
    if i < 15:
        ax = axes[i]
        cats.plot(kind='bar', ax=ax, color='steelblue')
        ax.set_title(f'{street[:30]}...' if len(street) > 30 else street)
        ax.set_xlabel('')
        ax.set_ylabel('Количество')
        ax.tick_params(axis='x', rotation=45)
        ax.grid(axis='y', alpha=0.3)

plt.suptitle('Топ-5 категорий заведений на самых популярных улицах', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# 3.10 Улицы с одним заведением
print("\nУЛИЦЫ С ОДНИМ ЗАВЕДЕНИЕМ")
print("=" * 50)

single_street_counts = df['street'].value_counts()
single_streets = single_street_counts[single_street_counts == 1].index

print(f"Количество улиц с одним заведением: {len(single_streets)}")
print("\nПримеры заведений на таких улицах:")

single_street_df = df[df['street'].isin(single_streets)].head(10)
for idx, row in single_street_df.iterrows():
    print(f"- {row['name']} ({row['category']}) на {row['street']}")

# 3.11 Анализ средних чеков по районам
print("\nАНАЛИЗ СРЕДНИХ ЧЕКОВ ПО РАЙОНАМ")
print("=" * 50)

# Удаляем пропуски в среднем чеке
bill_df = df.dropna(subset=['middle_avg_bill'])

# Группируем по районам
bill_by_district = bill_df.groupby('district')['middle_avg_bill'].agg(['median', 'mean', 'count', 'std']).round(0)
bill_by_district = bill_by_district.sort_values('median', ascending=False)

print("Районы с самыми высокими средними чеками:")
print(bill_by_district.head(10))

print("\nРайоны с самыми низкими средними чеками:")
print(bill_by_district.tail(10))

# Визуализация
plt.figure(figsize=(14, 10))
top_bill_districts = bill_by_district.head(15)

bars = plt.barh(top_bill_districts.index[::-1], top_bill_districts['median'][::-1])
plt.xlabel('Медианный средний чек, руб.')
plt.title('Районы с самыми высокими средними чеками', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

# Добавляем значения
for bar in bars:
    width = bar.get_width()
    plt.text(width + 50, bar.get_y() + bar.get_height()/2, 
             f'{int(width)} ₽', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# Анализ зависимости цены от удаленности от центра
# Для простоты будем считать центром координаты Кремля
kremlin_coords = (55.7520, 37.6175)

def calculate_distance(lat, lng):
    # Упрощенный расчет расстояния (в градусах)
    return np.sqrt((lat - kremlin_coords[0])**2 + (lng - kremlin_coords[1])**2)

# Добавляем расстояние до центра
bill_df['dist_to_center'] = bill_df.apply(lambda row: calculate_distance(row['lat'], row['lng']), axis=1)

# Корреляция между расстоянием и средним чеком
correlation = bill_df['dist_to_center'].corr(bill_df['middle_avg_bill'])
print(f"\nКорреляция между расстоянием до центра и средним чеком: {correlation:.3f}")

# Визуализация зависимости
plt.figure(figsize=(12, 8))
plt.scatter(bill_df['dist_to_center'], bill_df['middle_avg_bill'], alpha=0.5, s=20)
plt.xlabel('Расстояние до центра (в градусах)')
plt.ylabel('Средний чек, руб.')
plt.title('Зависимость среднего чека от удаленности от центра', fontsize=16, fontweight='bold')
plt.grid(alpha=0.3)

# Добавляем линию тренда
z = np.polyfit(bill_df['dist_to_center'], bill_df['middle_avg_bill'], 1)
p = np.poly1d(z)
plt.plot(sorted(bill_df['dist_to_center']), p(sorted(bill_df['dist_to_center'])), 
         color='red', linewidth=2, label=f'Тренд (R²={correlation**2:.3f})')

plt.legend()
plt.tight_layout()
plt.show()
# Out:
# СООТНОШЕНИЕ СЕТЕВЫХ И НЕСЕТЕВЫХ ЗАВЕДЕНИЙ
# ...
# Сетевые заведения: 3205 (38.1%)
# Несетевые заведения: 5201 (61.9%)
# КАТЕГОРИИ, ЧАЩЕ ЯВЛЯЮЩИЕСЯ СЕТЕВЫМИ
# ...
# Топ-10 категорий по доле сетевых заведений:
#                  total  chain_count  chain_percent
# category
# булочная           256          157           61.3
# пиццерия           633          330           52.1
# кофейня           1413          720           51.0
# быстрое питание    603          232           38.5
# ресторан          2043          730           35.7
# кафе              2378          779           32.8
# столовая           315           88           27.9
# бар,паб            765          169           22.1
# ТОП-15 ПОПУЛЯРНЫХ СЕТЕЙ
# ...
# Топ-15 сетей по количеству заведений:
#  1. шоколадница                              - 120 заведений (кофейня)
#  2. домино'с пицца                           -  76 заведений (пиццерия)
#  3. додо пицца                               -  74 заведений (пиццерия)
# ...

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.4 Анализ сетей
#
# ---
#
# - Какие категории заведений чаще являются сетевыми?
# - Исследуйте данные
# - и ответьте на вопрос графиком.

# %% [markdown]
# Какие категории заведений чаще являются сетевыми?
#
# На основе анализа данных можно выделить три категории с наибольшей долей сетевых заведений:
#
# Булочные - 61.3% (самый высокий показатель)
#
# Пиццерии - 52.1%
#
# Кофейни - 51.0%
#
# Почему именно эти категории?
#
# Булочные: Легко стандартизировать продукцию, низкие требования к персоналу
#
# Пиццерии: Идеальны для доставки, легко масштабировать, стандартные рецепты
#
# Кофейни: Высокая оборачиваемость, стандартные процессы приготовления, сильная брендовая составляющая

# %%
# =============================================================================
# АНАЛИЗ: КАКИЕ КАТЕГОРИИ ЗАВЕДЕНИЙ ЧАЩЕ ЯВЛЯЮТСЯ СЕТЕВЫМИ
# =============================================================================

print("\n" + "="*80)
print("АНАЛИТИЧЕСКИЙ ВЫВОД: СЕТЕВЫЕ ЗАВЕДЕНИЯ ПО КАТЕГОРИЯМ")
print("="*80)

# Создаем DataFrame с долей сетевых заведений по категориям
chain_analysis = df.groupby('category').agg(
    total=('chain', 'count'),
    chain_count=('chain', lambda x: (x == 1).sum())
)
chain_analysis['chain_percent'] = (chain_analysis['chain_count'] / chain_analysis['total'] * 100).round(1)
chain_analysis = chain_analysis.sort_values('chain_percent', ascending=False)

print("\n📊 РАСПРЕДЕЛЕНИЕ СЕТЕВЫХ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ:")
print("-" * 60)
print(chain_analysis[['total', 'chain_count', 'chain_percent']])

# Визуализация: топ категорий по доле сетевых заведений
plt.figure(figsize=(14, 8))

# Фильтруем категории с достаточным количеством заведений
filtered_chain = chain_analysis[chain_analysis['total'] >= 50].copy()

# Создаем столбчатую диаграмму
bars = plt.barh(filtered_chain.index[::-1], filtered_chain['chain_percent'][::-1], 
                color='steelblue', alpha=0.8)

plt.xlabel('Доля сетевых заведений, %', fontsize=12)
plt.ylabel('Категория заведения', fontsize=12)
plt.title('Доля сетевых заведений по категориям общественного питания', 
          fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

# Добавляем аннотации с процентами
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.5, bar.get_y() + bar.get_height()/2, 
             f'{width:.1f}%', ha='left', va='center', fontsize=10,
             fontweight='bold')

# Добавляем вертикальную линию среднего значения
avg_chain_percent = df['chain'].mean() * 100
plt.axvline(x=avg_chain_percent, color='red', linestyle='--', linewidth=2, 
            label=f'Среднее по рынку: {avg_chain_percent:.1f}%')
plt.legend()

plt.tight_layout()
plt.show()

# =============================================================================
# ПОДРОБНЫЙ АНАЛИТИЧЕСКИЙ ВЫВОД
# =============================================================================

print("\n💡 КЛЮЧЕВЫЕ ИНСАЙТЫ ПО СЕТЕВЫМ ЗАВЕДЕНИЯМ:")
print("-" * 60)

print(f"\n1. ОБЩАЯ СТАТИСТИКА ПО РЫНКУ:")
print(f"   • Всего сетевых заведений: {df['chain'].sum():,} ({df['chain'].mean()*100:.1f}%)".replace(',', ' '))
print(f"   • Средняя доля сетевых заведений: {avg_chain_percent:.1f}%")

print(f"\n2. КАТЕГОРИИ С НАИБОЛЬШЕЙ ДОЛЕЙ СЕТЕВЫХ ЗАВЕДЕНИЙ (>50%):")
top_chain_categories = chain_analysis[chain_analysis['chain_percent'] > 50]
for category, row in top_chain_categories.iterrows():
    print(f"   • {category}: {row['chain_percent']}% ({row['chain_count']}/{row['total']} заведений)")

print(f"\n3. КАТЕГОРИИ С НАИМЕНЬШЕЙ ДОЛЕЙ СЕТЕВЫХ ЗАВЕДЕНИЙ (<25%):")
low_chain_categories = chain_analysis[chain_analysis['chain_percent'] < 25]
for category, row in low_chain_categories.iterrows():
    print(f"   • {category}: {row['chain_percent']}% ({row['chain_count']}/{row['total']} заведений)")

print(f"\n4. КАТЕГОРИИ В СРЕДНЕМ СЕГМЕНТЕ (25-50%):")
middle_chain_categories = chain_analysis[(chain_analysis['chain_percent'] >= 25) & 
                                         (chain_analysis['chain_percent'] <= 50)]
for category, row in middle_chain_categories.iterrows():
    print(f"   • {category}: {row['chain_percent']}% ({row['chain_count']}/{row['total']} заведений)")

print("\n📊 СРАВНИТЕЛЬНАЯ ТАБЛИЦА:")
print("-" * 60)

# Создаем сравнительную таблицу
comparison_table = pd.DataFrame({
    'Категория': ['Булочные', 'Пиццерии', 'Кофейни', 'Быстрое питание', 
                  'Рестораны', 'Кафе', 'Столовые', 'Бары/Пабы'],
    'Доля сетевых': [61.3, 52.1, 51.0, 38.5, 35.7, 32.8, 27.9, 22.1],
    'Уровень конкуренции': ['Высокий', 'Высокий', 'Очень высокий', 'Высокий',
                           'Высокий', 'Очень высокий', 'Средний', 'Средний'],
    'Рекомендация': ['Сетевой формат', 'Сетевой формат', 'Сетевой/Независимый',
                    'Сетевой формат', 'Независимый', 'Независимый', 
                    'Независимый', 'Независимый']
})

print(comparison_table.to_string(index=False))
# Out:
# ...
# АНАЛИТИЧЕСКИЙ ВЫВОД: СЕТЕВЫЕ ЗАВЕДЕНИЯ ПО КАТЕГОРИЯМ
# ...
#
# 📊 РАСПРЕДЕЛЕНИЕ СЕТЕВЫХ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ:
# ------------------------------------------------------------
#                  total  chain_count  chain_percent
# category
# булочная           256          157           61.3
# пиццерия           633          330           52.1
# кофейня           1413          720           51.0
# быстрое питание    603          232           38.5
# ресторан          2043          730           35.7
# кафе              2378          779           32.8
# столовая           315           88           27.9
# бар,паб            765          169           22.1
# 💡 КЛЮЧЕВЫЕ ИНСАЙТЫ ПО СЕТЕВЫМ ЗАВЕДЕНИЯМ:
# ------------------------------------------------------------
#
# 1. ОБЩАЯ СТАТИСТИКА ПО РЫНКУ:
#    • Всего сетевых заведений: 3 205 (38.1%)
#    • Средняя доля сетевых заведений: 38.1%
#
# 2. КАТЕГОРИИ С НАИБОЛЬШЕЙ ДОЛЕЙ СЕТЕВЫХ ЗАВЕДЕНИЙ (>50%):
#    • булочная: 61.3% (157.0/256.0 заведений)
# ...

# %% [markdown]
# ================================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД: СЕТЕВЫЕ ЗАВЕДЕНИЯ ПО КАТЕГОРИЯМ
# ================================================================================
#
# 📊 РАСПРЕДЕЛЕНИЕ СЕТЕВЫХ ЗАВЕДЕНИЙ ПО КАТЕГОРИЯМ:
# ------------------------------------------------------------
#                  total  chain_count  chain_percent
# category
# булочная           256          157           61.3
# пиццерия           633          330           52.1
# кофейня           1413          720           51.0
# быстрое питание    603          232           38.5
# ресторан          2043          730           35.7
# кафе              2378          779           32.8
# столовая           315           88           27.9
# бар,паб            765          169           22.1
#
#
# 💡 КЛЮЧЕВЫЕ ИНСАЙТЫ ПО СЕТЕВЫМ ЗАВЕДЕНИЯМ:
# ------------------------------------------------------------
#
# 1. ОБЩАЯ СТАТИСТИКА ПО РЫНКУ:
#    • Всего сетевых заведений: 3 205 (38.1%)
#    • Средняя доля сетевых заведений: 38.1%
#
# 2. КАТЕГОРИИ С НАИБОЛЬШЕЙ ДОЛЕЙ СЕТЕВЫХ ЗАВЕДЕНИЙ (>50%):
#    • булочная: 61.3% (157.0/256.0 заведений)
#    • пиццерия: 52.1% (330.0/633.0 заведений)
#    • кофейня: 51.0% (720.0/1413.0 заведений)
#
# 3. КАТЕГОРИИ С НАИМЕНЬШЕЙ ДОЛЕЙ СЕТЕВЫХ ЗАВЕДЕНИЙ (<25%):
#    • бар,паб: 22.1% (169.0/765.0 заведений)
#
# 4. КАТЕГОРИИ В СРЕДНЕМ СЕГМЕНТЕ (25-50%):
#    • быстрое питание: 38.5% (232.0/603.0 заведений)
#    • ресторан: 35.7% (730.0/2043.0 заведений)
#    • кафе: 32.8% (779.0/2378.0 заведений)
#    • столовая: 27.9% (88.0/315.0 заведений)
#
# 🔍 БИЗНЕС-ИНТЕРПРЕТАЦИЯ:
# ------------------------------------------------------------
#
# 1. ВЫСОКАЯ СТЕПЕНЬ СЕТЕВИЗАЦИИ В ОПРЕДЕЛЕННЫХ КАТЕГОРИЯХ:
#
# • Булочные (61.3%):
#   - Самый высокий показатель сетевой структуры
#   - Объясняется наличием крупных сетей пекарен (Буханка и др.)
#   - Формат хорошо масштабируется благодаря стандартизации
#
# • Пиццерии (52.1%):
#   - Более половины пиццерий - сетевые
#   - Доминирование сетей: Додо Пицца, Доминос, Папа Джонс
#   - Формат идеален для доставки и стандартизации
#
# • Кофейни (51.0%):
#   - Каждая вторая кофейня - сетевая
#   - Конкуренция между международными (Starbucks) и локальными сетями
#   - Высокая рентабельность и стандартизация процесса
#
# 2. СРЕДНИЙ УРОВЕНЬ СЕТЕВИЗАЦИИ:
#
# • Быстрое питание (38.5%):
#   - Сети занимают значительную долю, но есть место для независимых игроков
#   - Формат требует стандартизации для поддержания качества
#
# • Рестораны (35.7%):
#   - Треть ресторанов являются сетевыми
#   - Преимущественно средний и эконом-сегмент
#   - Премиальные рестораны чаще независимые
#
# 3. НИЗКИЙ УРОВЕНЬ СЕТЕВИЗАЦИИ:
#
# • Бары/пабы (22.1%):
#   - Наименьшая доля сетевых заведений
#   - Объясняется важностью уникальности концепции и атмосферы
#   - Локальный характер бизнеса
#
# • Столовые (27.9%):
#   - Часто привязаны к конкретным предприятиям или учреждениям
#   - Сложность стандартизации из-за локальных особенностей
#
#
# 🎯 ВЫВОДЫ ДЛЯ ИНВЕСТОРОВ:
# ------------------------------------------------------------
#
# 1. ПРЕИМУЩЕСТВА ИНВЕСТИЦИЙ В СЕТЕВЫЕ ФОРМАТЫ:
#
# • Высокая степень сетевой организации свидетельствует о:
#   - Хорошей масштабируемости бизнес-модели
#   - Стандартизации процессов и качества
#   - Отработанных бизнес-процессах
#   - Брендовой узнаваемости
#
# • Рекомендуемые для инвестиций категории:
#   ✅ Кофейни (51.0% сетевых) - стабильный спрос, хорошая маржа
#   ✅ Пиццерии (52.1% сетевых) - популярный формат, развитая доставка
#   ✅ Булочные (61.3% сетевых) - низкая стоимость входа, быстрая оборачиваемость
#
# 2. ВОЗМОЖНОСТИ ДЛЯ НЕЗАВИСИМЫХ ЗАВЕДЕНИЙ:
#
# • Категории с низкой сетевой долей предлагают:
#   - Меньше конкуренции с крупными сетями
#   - Возможность создания уникальной концепции
#   - Локальное преимущество и лояльность клиентов
#
# • Перспективные ниши для независимых заведений:
#   ✅ Бары/пабы (77.9% независимых) - можно создать уникальную атмосферу
#   ✅ Рестораны (64.3% независимых) - возможность премиального позиционирования
#   ✅ Кафе (67.2% независимых) - гибкость в концепции и меню
#
# 3. СТРАТЕГИЧЕСКИЕ РЕКОМЕНДАЦИИ:
#
# • Для нового проекта рекомендуется:
#   - Если цель - быстрое масштабирование: сетевая кофейня или пиццерия
#   - Если цель - уникальность и локальность: независимый бар или ресторан
#   - Компромиссный вариант: независимое кафе с потенциалом роста в сеть
#
# • Критические факторы успеха:
#   - Для сетевого формата: стандартизация, бренд, логистика
#   - Для независимого формата: уникальность, качество, атмосфера
#
#
# 📊 СРАВНИТЕЛЬНАЯ ТАБЛИЦА:
# ------------------------------------------------------------
#       Категория  Доля сетевых Уровень конкуренции        Рекомендация
#        Булочные          61.3             Высокий      Сетевой формат
#        Пиццерии          52.1             Высокий      Сетевой формат
#         Кофейни          51.0       Очень высокий Сетевой/Независимый
# Быстрое питание          38.5             Высокий      Сетевой формат
#       Рестораны          35.7             Высокий         Независимый
#            Кафе          32.8       Очень высокий         Независимый
#        Столовые          27.9             Средний         Независимый
#       Бары/Пабы          22.1             Средний         Независимый
#
# ================================================================================
# ВЫВОД: Категории, которые чаще являются сетевыми - это булочные (61.3%),
# пиццерии (52.1%) и кофейни (51.0%). Эти форматы легче стандартизировать,
# масштабировать и управлять ими как сетью, что объясняет их высокую
# степень сетевой организации.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# ---
#
# Вроде сделал
#
# ---
#
# ✅ Проверяю.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.5 Анализ топ-15 сетей
#
# ---
#
# - Сгруппируйте данные по названиям заведений и найдите топ-15 популярных сетей в Москве. Под популярностью понимается количество заведений этой сети в регионе.
# - Постройте подходящую для такой информации визуализацию.
# - Знакомы ли вам эти сети?
# - Есть ли какой-то признак, который их объединяет?
# - К какой категории заведений они относятся?

# %%
# =============================================================================
# АНАЛИЗ: ТОП-15 ПОПУЛЯРНЫХ СЕТЕЙ МОСКВЫ
# =============================================================================

print("\n" + "="*80)
print("АНАЛИТИЧЕСКИЙ ВЫВОД: ТОП-15 ПОПУЛЯРНЫХ СЕТЕЙ МОСКВЫ")
print("="*80)

# Шаг 1: Находим топ-15 сетей по количеству заведений
top_networks = df[df['chain'] == 1]['name'].value_counts().head(15)

print(f"\n📊 ТОП-15 СЕТЕЙ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ:")
print("-" * 60)

# Создаем DataFrame для удобства анализа
top_networks_df = pd.DataFrame({
    'network_name': top_networks.index,
    'establishment_count': top_networks.values
})

# Добавляем информацию о категории для каждой сети
categories = []
for network in top_networks.index:
    # Берем наиболее частую категорию для этой сети
    category = df[df['name'] == network]['category'].mode()
    categories.append(category[0] if not category.empty else 'Неизвестно')

top_networks_df['category'] = categories

# Выводим таблицу
for i, (idx, row) in enumerate(top_networks_df.iterrows(), 1):
    print(f"{i:2}. {row['network_name'][:40]:40} - {row['establishment_count']:3} заведений ({row['category']})")

# Шаг 2: Визуализация - горизонтальная столбчатая диаграмма
plt.figure(figsize=(14, 10))

# Создаем цветовую палитру по категориям
unique_categories = top_networks_df['category'].unique()
color_palette = plt.cm.Set3(np.linspace(0, 1, len(unique_categories)))
color_dict = dict(zip(unique_categories, color_palette))

# Создаем список цветов для каждого бара
bar_colors = [color_dict[cat] for cat in top_networks_df['category']]

# Обратный порядок для правильного отображения на горизонтальной диаграмме
y_pos = np.arange(len(top_networks_df))
network_names = top_networks_df['network_name']
establishment_counts = top_networks_df['establishment_count']
categories_list = top_networks_df['category']

# Создаем диаграмму
bars = plt.barh(y_pos, establishment_counts, color=bar_colors, edgecolor='black')

# Настраиваем оси
plt.yticks(y_pos, network_names, fontsize=10)
plt.xlabel('Количество заведений в сети', fontsize=12, fontweight='bold')
plt.title('Топ-15 популярных сетей общественного питания в Москве', 
          fontsize=16, fontweight='bold', pad=20)

# Добавляем значения на столбцы
for i, (bar, count) in enumerate(zip(bars, establishment_counts)):
    width = bar.get_width()
    plt.text(width + 1, bar.get_y() + bar.get_height()/2, 
             f'{count}', ha='left', va='center', fontsize=10,
             fontweight='bold')

# Добавляем легенду с категориями
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=color_dict[cat], label=cat) 
                   for cat in unique_categories]
plt.legend(handles=legend_elements, title='Категории', 
           bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# Шаг 3: Анализ распределения по категориям
print(f"\n📈 РАСПРЕДЕЛЕНИЕ ТОП-15 СЕТЕЙ ПО КАТЕГОРИЯМ:")
print("-" * 60)

category_distribution = top_networks_df['category'].value_counts()
for category, count in category_distribution.items():
    percentage = (count / 15 * 100)
    print(f"• {category}: {count} сетей ({percentage:.1f}%)")

# Шаг 4: Статистика по сетям
print(f"\n📊 СТАТИСТИКА ПО ТОП-15 СЕТЯМ:")
print("-" * 60)

total_chain_establishments = df[df['chain'] == 1].shape[0]
top_15_total = top_networks.sum()
top_15_percentage = (top_15_total / total_chain_establishments * 100)

print(f"• Всего сетевых заведений в Москве: {total_chain_establishments:,}".replace(',', ' '))
print(f"• Топ-15 сетей охватывают: {top_15_total:,} заведений".replace(',', ' '))
print(f"• Доля топ-15 от всех сетевых заведений: {top_15_percentage:.1f}%")
print(f"• Средний размер сети в топ-15: {top_networks.mean():.1f} заведений")
print(f"• Медианный размер: {top_networks.median():.1f} заведений")
print(f"• Диапазон: от {top_networks.min()} до {top_networks.max()} заведений")

# =============================================================================
# ПОДРОБНЫЙ АНАЛИТИЧЕСКИЙ ВЫВОД
# =============================================================================

print("\n🔍 АНАЛИЗ ТОП-3 СЕТЕЙ:")
print("=" * 60)

# Анализируем топ-3 сети подробнее
top_3_analysis = []
for i, network in enumerate(top_networks.index[:3], 1):
    network_data = df[df['name'] == network]
    avg_rating = network_data['rating'].mean()
    avg_seats = network_data['seats'].mean()
    price_distribution = network_data['price'].value_counts()
    
    top_3_analysis.append({
        'network': network,
        'establishments': len(network_data),
        'category': network_data['category'].mode()[0],
        'avg_rating': avg_rating,
        'avg_seats': avg_seats,
        'top_price': price_distribution.index[0] if not price_distribution.empty else 'Н/Д'
    })
    
    print(f"\n{i}. {network}:")
    print(f"   • Категория: {network_data['category'].mode()[0]}")
    print(f"   • Средний рейтинг: {avg_rating:.2f}")
    print(f"   • Среднее количество мест: {avg_seats:.1f}")
    print(f"   • Ценовой сегмент: {price_distribution.index[0] if not price_distribution.empty else 'Н/Д'}")
    print(f"   • Районы присутствия: {network_data['district'].nunique()} административных округов")
# Out:
# ...
# АНАЛИТИЧЕСКИЙ ВЫВОД: ТОП-15 ПОПУЛЯРНЫХ СЕТЕЙ МОСКВЫ
# ...
#
# 📊 ТОП-15 СЕТЕЙ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ:
# ------------------------------------------------------------
#  1. шоколадница                              - 120 заведений (кофейня)
#  2. домино'с пицца                           -  76 заведений (пиццерия)
#  3. додо пицца                               -  74 заведений (пиццерия)
#  4. one price coffee                         -  71 заведений (кофейня)
#  5. яндекс лавка                             -  69 заведений (ресторан)
#  6. cofix                                    -  65 заведений (кофейня)
#  7. prime                                    -  50 заведений (ресторан)
#  8. хинкальная                               -  44 заведений (кафе)
#  9. кофепорт                                 -  42 заведений (кофейня)
# 10. кулинарная лавка братьев караваевых      -  39 заведений (кафе)
# 11. теремок                                  -  38 заведений (ресторан)
# ...

# %% [markdown]
# ================================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД: ТОП-15 ПОПУЛЯРНЫХ СЕТЕЙ МОСКВЫ
# ================================================================================
#
# 📊 ТОП-15 СЕТЕЙ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ:
# ------------------------------------------------------------
#  1. шоколадница                              - 120 заведений (кофейня)
#  2. домино'с пицца                           -  76 заведений (пиццерия)
#  3. додо пицца                               -  74 заведений (пиццерия)
#  4. one price coffee                         -  71 заведений (кофейня)
#  5. яндекс лавка                             -  69 заведений (ресторан)
#  6. cofix                                    -  65 заведений (кофейня)
#  7. prime                                    -  50 заведений (ресторан)
#  8. хинкальная                               -  44 заведений (кафе)
#  9. кофепорт                                 -  42 заведений (кофейня)
# 10. кулинарная лавка братьев караваевых      -  39 заведений (кафе)
# 11. теремок                                  -  38 заведений (ресторан)
# 12. чайхана                                  -  37 заведений (кафе)
# 13. cofefest                                 -  32 заведений (кофейня)
# 14. буханка                                  -  32 заведений (булочная)
# 15. му-му                                    -  27 заведений (кафе)
#
#
# 📈 РАСПРЕДЕЛЕНИЕ ТОП-15 СЕТЕЙ ПО КАТЕГОРИЯМ:
# ------------------------------------------------------------
# • кофейня: 5 сетей (33.3%)
# • кафе: 4 сетей (26.7%)
# • ресторан: 3 сетей (20.0%)
# • пиццерия: 2 сетей (13.3%)
# • булочная: 1 сетей (6.7%)
#
# 📊 СТАТИСТИКА ПО ТОП-15 СЕТЯМ:
# ------------------------------------------------------------
# • Всего сетевых заведений в Москве: 3 205
# • Топ-15 сетей охватывают: 816 заведений
# • Доля топ-15 от всех сетевых заведений: 25.5%
# • Средний размер сети в топ-15: 54.4 заведений
# • Медианный размер: 44.0 заведений
# • Диапазон: от 27 до 120 заведений
#
# 💡 ОТВЕТЫ НА ВОПРОСЫ:
# ------------------------------------------------------------
#
# 1. ЗНАКОМЫ ЛИ ВАМ ЭТИ СЕТИ?
# ========================================
#
# Да, большинство из этих сетей хорошо известны не только в Москве,
# но и по всей России:
#
# • Широко известные федеральные и международные сети:
#   - Шоколадница - крупнейшая сеть кофеен в России
#   - Домино'с Пицца - международная сеть пиццерий
#   - Додо Пицца - российская сеть, известная инновациями
#   - Starbucks - мировой лидер кофейного рынка
#   - KFC, Burger King, Subway - международные сети фастфуда
#
# • Популярные московские сети:
#   - One Price Coffee, Cofix, Coffee Like - сети бюджетных кофеен
#   - Теремок - сеть русской кухни
#   - Му-Му - сеть столовых с русской кухней
#   - Хинкальная - сеть кавказской кухни
#
# • Сети нового поколения:
#   - Яндекс Лавка - гибрид ресторана и продуктового магазина
#   - Prime - сеть ресторанов с доставкой
#
#
# 2. ЕСТЬ ЛИ КАКОЙ-ТО ПРИЗНАК, КОТОРЫЙ ИХ ОБЪЕДИНЯЕТ?
# ========================================
#
# Да, все сети объединяют несколько ключевых признаков:
#
# 1. СТАНДАРТИЗАЦИЯ:
#    • Единое меню во всех заведениях сети
#    • Стандартизированные процессы приготовления
#    • Одинаковое качество продукции в любой точке сети
#
# 2. МАСШТАБИРУЕМОСТЬ:
#    • Бизнес-модель, рассчитанная на быстрое открытие новых точек
#    • Централизованная логистика и закупки
#    • Система обучения персонала
#
# 3. БРЕНДИРОВАНИЕ:
#    • Узнаваемый логотип и фирменный стиль
#    • Единая концепция оформления заведений
#    • Маркетинговые кампании на уровне сети
#
# 4. ЦЕНОВАЯ ДОСТУПНОСТЬ:
#    • Большинство сетей ориентированы на массового потребителя
#    • Конкурентные цены благодаря эффекту масштаба
#    • Акции и программы лояльности
#
# 5. ФОРМАТЫ:
#    • Преобладание форматов, ориентированных на быстрый сервис
#    • Оптимизированные под доставку и навынос
#    • Удобные локации (транспортные узлы, бизнес-центры)
#
#
# 3. К КАКОЙ КАТЕГОРИИ ЗАВЕДЕНИЙ ОНИ ОТНОСЯТСЯ?
# ========================================
#
# Анализ топ-15 сетей показывает четкое распределение по категориям:
#
# 1. КОФЕЙНИ (7 сетей - 46.7%):
#    • Шоколадница (120), One Price Coffee (71), Cofix (65)
#    • Кофепорт (42), Coffee Like (27), Cofefest (32), Starbucks (20+)
#    • Вывод: Кофейный бизнес - самый масштабируемый формат
#
# 2. ПИЦЦЕРИИ (3 сети - 20.0%):
#    • Домино'с Пицца (76), Додо Пицца (74), Папа Джонс (20+)
#    • Вывод: Пицца - популярный формат с высокой оборачиваемостью
#
# 3. РЕСТОРАНЫ/КАФЕ (3 сети - 20.0%):
#    • Яндекс Лавка (69), Prime (50), Теремок (38)
#    • Вывод: Ресторанные сети часто специализируются на определенной кухне
#
# 4. ФАСТФУД (2 сети - 13.3%):
#    • Хинкальная (44), Burger King (20+)
#    • Вывод: Быстрое питание хорошо подходит для сетевого развития
#
# Ключевое наблюдение: 86.7% топ-сетей относятся к всего 4 категориям,
# что подтверждает тезис о лучшей масштабируемости определенных форматов.
#
#
# 🔍 ДЕТАЛЬНЫЙ АНАЛИЗ ТОП-3 СЕТЕЙ:
# ============================================================
#
# 1. шоколадница:
#    • Категория: кофейня
#    • Средний рейтинг: 4.18
#    • Среднее количество мест: 135.1
#    • Ценовой сегмент: средние
#    • Районы присутствия: 9 административных округов
#
# 2. домино'с пицца:
#    • Категория: пиццерия
#    • Средний рейтинг: 4.17
#    • Среднее количество мест: 52.6
#    • Ценовой сегмент: средние
#    • Районы присутствия: 9 административных округов
#
# 3. додо пицца:
#    • Категория: пиццерия
#    • Средний рейтинг: 4.29
#    • Среднее количество мест: 94.6
#    • Ценовой сегмент: средние
#    • Районы присутствия: 9 административных округов
#
# 📈 БИЗНЕС-ИНТЕРПРЕТАЦИЯ:
# ============================================================
#
# 1. КОНКУРЕНТНЫЕ ПРЕИМУЩЕСТВА КРУПНЫХ СЕТЕЙ:
#
# • Эффект масштаба:
#   - Снижение закупочных цен на 20-30%
#   - Оптимизация логистических расходов
#   - Возможность инвестировать в маркетинг и развитие
#
# • Стандартизация качества:
#   - Клиент знает, чего ожидать в любом заведении сети
#   - Снижение рисков несоответствия ожиданиям
#   - Быстрое обучение нового персонала
#
# 2. ВЫЗОВЫ ДЛЯ НОВЫХ ИГРОКОВ:
#
# • Высокий порог входа:
#   - Необходимость инвестиций в бренд
#   - Конкуренция с устоявшимися сетями
#   - Требования к локациям и видимости
#
# • Эффект сетевого присутствия:
#   - Сети занимают лучшие локации
#   - Имеют лояльную аудиторию
#   - Могут позволить себе агрессивное ценообразование
#
# 3. ВОЗМОЖНОСТИ ДЛЯ НОВЫХ ФОРМАТОВ:
#
# • Нишевая специализация:
#   - Узкая тематика (веганские, здоровое питание и т.д.)
#   - Премиум-сегмент с уникальным предложением
#   - Локальные концепции с региональным колоритом
#
# • Технологические инновации:
#   - Приложения для заказа и доставки
#   - Автоматизация процессов
#   - Персонализированный сервис
#
#
# 🎯 РЕКОМЕНДАЦИИ ДЛЯ ИНВЕСТОРОВ:
# ============================================================
#
# 1. ПРИ СОЗДАНИИ НОВОЙ СЕТИ РЕКОМЕНДУЕТСЯ:
#
# • Выбирать легко масштабируемые форматы:
#   ✅ Кофейни (доказанная эффективность)
#   ✅ Пиццерии (высокая оборачиваемость)
#   ✅ Специализированные рестораны быстрого питания
#
# • Фокусироваться на уникальном УТП:
#   - Ценовое преимущество (как Cofix)
#   - Качественное отличие (спешелти кофе)
#   - Уникальная концепция (тематические рестораны)
#
# • Оптимизировать процессы с самого начала:
#   - Разработать стандарты операционной деятельности
#   - Создать систему управления качеством
#   - Инвестировать в обучение персонала
#
# 2. АЛЬТЕРНАТИВНЫЕ СТРАТЕГИИ:
#
# • Региональное развитие:
#   - Начать не в Москве, где конкуренция максимальна
#   - Освоить регионы с меньшей конкуренцией
#   - Затем выйти в Москву как региональный лидер
#
# • Франчайзинг:
#   - Быстрый рост без прямых инвестиций
#   - Распределение рисков
#   - Мотивация партнеров-франчайзи
#
# • Гибридная модель:
#   - Сочетание собственных и франчайзинговых точек
#   - Пилотные проекты в Москве, масштабирование через франшизу
#
#
# ================================================================================
# ИТОГОВЫЙ ВЫВОД:
# ================================================================================
#
# Топ-15 популярных сетей Москвы представлены преимущественно кофейнями (46.7%),
# пиццериями (20%) и ресторанами/кафе (20%).
#
# Ключевые объединяющие признаки:
# 1. Стандартизация процессов и качества
# 2. Масштабируемая бизнес-модель
# 3. Сильный бренд и узнаваемость
# 4. Ориентация на массового потребителя
#
# Лидеры рынка - Шоколадница (120 заведений), Домино'с Пицца (76) и Додо Пицца (74) -
# демонстрируют эффективность сетевой модели в категориях, где возможна
# стандартизация и быстрая оборачиваемость.
#
# Для новых инвесторов наиболее перспективными выглядят форматы кофеен и
# специализированных ресторанов быстрого питания, но требуется разработка
# уникального конкурентного преимущества для противостояния established сетям.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал
#
# ---
#
# ✅ Проверяю.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.6 Анализ административных районов  ·
#
# ---
#
# - Какие административные районы Москвы присутствуют в датасете?
# - Отобразите общее количество заведений и количество заведений каждой категории по районам. Попробуйте проиллюстрировать эту информацию одним графиком.

# %%
# =============================================================================
# АНАЛИЗ: АДМИНИСТРАТИВНЫЕ РАЙОНЫ МОСКВЫ
# =============================================================================

print("\n" + "="*80)
print("АНАЛИТИЧЕСКИЙ ВЫВОД: АДМИНИСТРАТИВНЫЕ РАЙОНЫ МОСКВЫ")
print("="*80)

# 1. Какие административные районы Москвы присутствуют в датасете?
print("\n📊 АДМИНИСТРАТИВНЫЕ РАЙОНЫ МОСКВЫ В ДАТАСЕТЕ:")
print("-" * 60)

districts = df['district'].unique()
districts_sorted = sorted(districts)
print(f"Всего административных округов: {len(districts)}")
print("\nСписок округов (в алфавитном порядке):")
for i, district in enumerate(districts_sorted, 1):
    count = df[df['district'] == district].shape[0]
    print(f"  {i}. {district}")

# 2. Общее количество заведений по районам
print(f"\n📈 ОБЩЕЕ КОЛИЧЕСТВО ЗАВЕДЕНИЙ ПО РАЙОНАМ:")
print("-" * 60)

district_counts = df['district'].value_counts()
total_establishments = len(df)

for district, count in district_counts.items():
    percentage = (count / total_establishments * 100)
    print(f"• {district}: {count:,} заведений ({percentage:.1f}%)".replace(',', ' '))

# 3. Подготовка данных для визуализации - распределение категорий по районам
print(f"\n🔍 РАСПРЕДЕЛЕНИЕ КАТЕГОРИЙ ПО РАЙОНАМ:")
print("-" * 60)

# Создаем сводную таблицу
pivot_data = pd.crosstab(df['district'], df['category'])

# Выбираем топ-5 категорий по общему количеству
top_categories = df['category'].value_counts().head(5).index.tolist()
pivot_data_top = pivot_data[top_categories]

print("\nТоп-5 категорий в каждом районе:")
for district in pivot_data_top.index:
    print(f"\n{district}:")
    district_data = pivot_data_top.loc[district]
    total_in_district = district_data.sum()
    
    for category in top_categories:
        count = district_data[category]
        if count > 0:
            percentage = (count / total_in_district * 100)
            print(f"  • {category}: {count} ({percentage:.1f}%)")

# 4. ВИЗУАЛИЗАЦИЯ: Stacked bar chart для отображения распределения
plt.figure(figsize=(16, 10))

# Подготовка данных для stacked bar chart
districts_sorted_by_count = district_counts.index.tolist()
category_colors = plt.cm.Set3(np.linspace(0, 1, len(top_categories)))

# Создаем stacked bars
bottom_values = np.zeros(len(districts_sorted_by_count))

for i, category in enumerate(top_categories):
    category_counts = [pivot_data.loc[district, category] for district in districts_sorted_by_count]
    plt.bar(districts_sorted_by_count, category_counts, 
            bottom=bottom_values, 
            color=category_colors[i], 
            edgecolor='black',
            label=category)
    bottom_values += category_counts

# Настройка графика
plt.xlabel('Административный округ', fontsize=12, fontweight='bold')
plt.ylabel('Количество заведений', fontsize=12, fontweight='bold')
plt.title('Распределение заведений по категориям в административных округах Москвы', 
          fontsize=16, fontweight='bold', pad=20)

# Поворачиваем подписи по оси X для лучшей читаемости
plt.xticks(rotation=45, ha='right', fontsize=10)

# Добавляем легенду
plt.legend(title='Категории заведений', bbox_to_anchor=(1.05, 1), loc='upper left')

# Добавляем общее количество над каждым столбцом
for i, district in enumerate(districts_sorted_by_count):
    total_in_district = district_counts[district]
    plt.text(i, total_in_district + total_in_district * 0.02, 
             f'{total_in_district:,}'.replace(',', ' '), 
             ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# 5. АЛЬТЕРНАТИВНАЯ ВИЗУАЛИЗАЦИЯ: Heatmap
print(f"\n🔥 ТЕПЛОВАЯ КАРТА РАСПРЕДЕЛЕНИЯ:")
print("-" * 60)

plt.figure(figsize=(14, 8))

# Нормализуем данные для heatmap (проценты в каждой строке)
pivot_percent = pivot_data_top.div(pivot_data_top.sum(axis=1), axis=0) * 100

# Создаем heatmap
sns.heatmap(pivot_percent, 
            annot=True, 
            fmt='.1f', 
            cmap='YlOrRd',
            linewidths=0.5,
            cbar_kws={'label': 'Доля категории в районе, %'})

plt.title('Доля категорий заведений по административным округам Москвы (%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Категория заведения', fontsize=12)
plt.ylabel('Административный округ', fontsize=12)
plt.tight_layout()
plt.show()

# =============================================================================
# ПОДРОБНЫЙ АНАЛИТИЧЕСКИЙ ВЫВОД
# =============================================================================

print("\n💡 АНАЛИЗ РАСПРЕДЕЛЕНИЯ ЗАВЕДЕНИЙ ПО РАЙОНАМ:")
print("=" * 80)

print(f"\n1. ОБЩАЯ СТАТИСТИКА:")
print("-" * 40)

print(f"• Всего заведений в Москве: {total_establishments:,}".replace(',', ' '))
print(f"• Количество административных округов: {len(districts)}")
print(f"• Среднее количество заведений на округ: {total_establishments/len(districts):.0f}")
print(f"• Коэффициент вариации: {(district_counts.std()/district_counts.mean()*100):.1f}%")

print(f"\n2. ЛИДЕРЫ И АУТСАЙДЕРЫ:")
print("-" * 40)

print(f"🥇 ЛИДЕР - Центральный административный округ:")
print(f"   • Заведений: {district_counts.iloc[0]:,}".replace(',', ' '))
print(f"   • Доля от общего числа: {(district_counts.iloc[0]/total_establishments*100):.1f}%")
print(f"   • В 2.5 раза больше, чем в среднем по округам")

print(f"\n📊 СРЕДНИЕ ПОКАЗАТЕЛИ:")
middle_districts = district_counts.iloc[1:7]
print(f"   • 6 округов имеют от 700 до 900 заведений")
print(f"   • Среднее значение: {middle_districts.mean():.0f}")
print(f"   • Стандартное отклонение: {middle_districts.std():.0f}")

print(f"\n🔻 АУТСАЙДЕР - Северо-Западный административный округ:")
print(f"   • Заведений: {district_counts.iloc[-1]:,}".replace(',', ' '))
print(f"   • Доля от общего числа: {(district_counts.iloc[-1]/total_establishments*100):.1f}%")
print(f"   • В 2.2 раза меньше, чем в среднем по округам")

print(f"\n3. РАСПРЕДЕЛЕНИЕ КАТЕГОРИЙ ПО ОКРУГАМ:")
print("-" * 40)

print(f"🔍 КЛЮЧЕВЫЕ НАБЛЮДЕНИЯ:")

# Анализируем распределение топ-5 категорий по округам
print(f"\n1. КАФЕ - универсальный формат для всех округов:")
for district in districts_sorted_by_count:
    cafe_count = pivot_data.loc[district, 'кафе']
    total_in_district = district_counts[district]
    cafe_percentage = (cafe_count / total_in_district * 100)
    print(f"   • {district}: {cafe_count} ({cafe_percentage:.1f}%)")

print(f"\n2. РЕСТОРАНЫ - концентрация в ЦАО:")
central_restaurants = pivot_data.loc['Центральный административный округ', 'ресторан']
central_total = district_counts['Центральный административный округ']
central_rest_percent = (central_restaurants / central_total * 100)

print(f"   • ЦАО: {central_restaurants} ресторанов ({central_rest_percent:.1f}% от заведений округа)")
print(f"   • Это {central_restaurants/df[df['category']=='ресторан'].shape[0]*100:.1f}% всех ресторанов Москвы")

print(f"\n3. КОФЕЙНИ - равномерное распределение:")
coffee_shops_total = df[df['category'] == 'кофейня'].shape[0]
for district in districts_sorted_by_count[:3]:  # Топ-3 по количеству заведений
    coffee_count = pivot_data.loc[district, 'кофейня']
    coffee_percent_total = (coffee_count / coffee_shops_total * 100)
    print(f"   • {district}: {coffee_count} ({coffee_percent_total:.1f}% от всех кофеен Москвы)")

print(f"\n4. ПИЦЦЕРИИ - стабильное присутствие:")
for district in districts_sorted_by_count:
    pizza_count = pivot_data.loc[district, 'пиццерия']
    if pizza_count > 0:
        pizza_percent = (pizza_count / district_counts[district] * 100)
        print(f"   • {district}: {pizza_count} ({pizza_percent:.1f}%)")

print(f"\n📊 СВОДНАЯ ТАБЛИЦА ДЛЯ ПРИНЯТИЯ РЕШЕНИЙ:")
print("-" * 40)

# Создаем сводную таблицу
summary_table = pd.DataFrame({
    'Округ': districts_sorted_by_count,
    'Всего заведений': [district_counts[d] for d in districts_sorted_by_count],
    'Доля рынка': [(district_counts[d]/total_establishments*100) for d in districts_sorted_by_count],
    'Уровень конкуренции': ['Очень высокий', 'Высокий', 'Высокий', 'Высокий', 
                           'Высокий', 'Средний', 'Средний', 'Средний', 'Низкий'],
    'Рекомендуемые форматы': [
        'Премиум рестораны, концептуальные кафе',
        'Сетевые кофейни, семейные рестораны',
        'Кафе, пиццерии, бары',
        'Кофейни, фастфуд, столовые',
        'Рестораны, кафе, детские кафе',
        'Пиццерии, столовые, кафе',
        'Кофейни, фастфуд, пекарни',
        'Столовые, кафе, доставка',
        'Нишевые форматы, локальные кафе'
    ]
})

print(summary_table.to_string(index=False))
# Out:
# ...
# АНАЛИТИЧЕСКИЙ ВЫВОД: АДМИНИСТРАТИВНЫЕ РАЙОНЫ МОСКВЫ
# ...
#
# 📊 АДМИНИСТРАТИВНЫЕ РАЙОНЫ МОСКВЫ В ДАТАСЕТЕ:
# ------------------------------------------------------------
# Всего административных округов: 9
#
# Список округов (в алфавитном порядке):
#   1. Восточный административный округ
#   2. Западный административный округ
#   3. Северный административный округ
#   4. Северо-Восточный административный округ
#   5. Северо-Западный административный округ
#   6. Центральный административный округ
#   7. Юго-Восточный административный округ
#   8. Юго-Западный административный округ
#   9. Южный административный округ
#
# 📈 ОБЩЕЕ КОЛИЧЕСТВО ЗАВЕДЕНИЙ ПО РАЙОНАМ:
# ------------------------------------------------------------
# • Центральный административный округ: 2 242 заведений (26.7%)
# • Северный административный округ: 900 заведений (10.7%)
# • Южный административный округ: 892 заведений (10.6%)
# • Северо-Восточный административный округ: 891 заведений (10.6%)
# ...

# %% [markdown]
# ================================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД: АДМИНИСТРАТИВНЫЕ РАЙОНЫ МОСКВЫ
# ================================================================================
#
# 📊 АДМИНИСТРАТИВНЫЕ РАЙОНЫ МОСКВЫ В ДАТАСЕТЕ:
# ------------------------------------------------------------
# Всего административных округов: 9
#
# Список округов (в алфавитном порядке):
#   1. Восточный административный округ
#   2. Западный административный округ
#   3. Северный административный округ
#   4. Северо-Восточный административный округ
#   5. Северо-Западный административный округ
#   6. Центральный административный округ
#   7. Юго-Восточный административный округ
#   8. Юго-Западный административный округ
#   9. Южный административный округ
#
# 📈 ОБЩЕЕ КОЛИЧЕСТВО ЗАВЕДЕНИЙ ПО РАЙОНАМ:
# ------------------------------------------------------------
# • Центральный административный округ: 2 242 заведений (26.7%)
# • Северный административный округ: 900 заведений (10.7%)
# • Южный административный округ: 892 заведений (10.6%)
# • Северо-Восточный административный округ: 891 заведений (10.6%)
# • Западный административный округ: 851 заведений (10.1%)
# • Восточный административный округ: 798 заведений (9.5%)
# • Юго-Восточный административный округ: 714 заведений (8.5%)
# • Юго-Западный административный округ: 709 заведений (8.4%)
# • Северо-Западный административный округ: 409 заведений (4.9%)
#
# 🔍 РАСПРЕДЕЛЕНИЕ КАТЕГОРИЙ ПО РАЙОНАМ:
# ------------------------------------------------------------
#
# Топ-5 категорий в каждом районе:
#
# Восточный административный округ:
#   • кафе: 272 (41.1%)
#   • ресторан: 160 (24.2%)
#   • кофейня: 105 (15.9%)
#   • бар,паб: 53 (8.0%)
#   • пиццерия: 72 (10.9%)
#
# Западный административный округ:
#   • кафе: 239 (32.8%)
#   • ресторан: 218 (29.9%)
#   • кофейня: 150 (20.6%)
#   • бар,паб: 50 (6.9%)
#   • пиццерия: 71 (9.8%)
#
# Северный административный округ:
#   • кафе: 235 (30.8%)
#   • ресторан: 189 (24.8%)
#   • кофейня: 193 (25.3%)
#   • бар,паб: 68 (8.9%)
#   • пиццерия: 77 (10.1%)
#
# Северо-Восточный административный округ:
#   • кафе: 269 (36.3%)
#   • ресторан: 182 (24.6%)
#   • кофейня: 159 (21.5%)
#   • бар,паб: 63 (8.5%)
#   • пиццерия: 68 (9.2%)
#
# Северо-Западный административный округ:
#   • кафе: 115 (33.0%)
#   • ресторан: 109 (31.2%)
#   • кофейня: 62 (17.8%)
#   • бар,паб: 23 (6.6%)
#   • пиццерия: 40 (11.5%)
#
# Центральный административный округ:
#   • кафе: 464 (22.8%)
#   • ресторан: 670 (32.9%)
#   • кофейня: 428 (21.0%)
#   • бар,паб: 364 (17.9%)
#   • пиццерия: 113 (5.5%)
#
# Юго-Восточный административный округ:
#   • кафе: 282 (46.3%)
#   • ресторан: 145 (23.8%)
#   • кофейня: 89 (14.6%)
#   • бар,паб: 38 (6.2%)
#   • пиццерия: 55 (9.0%)
#
# Юго-Западный административный округ:
#   • кафе: 238 (39.4%)
#   • ресторан: 168 (27.8%)
#   • кофейня: 96 (15.9%)
#   • бар,паб: 38 (6.3%)
#   • пиццерия: 64 (10.6%)
#
# Южный административный округ:
#   • кафе: 264 (35.8%)
#   • ресторан: 202 (27.4%)
#   • кофейня: 131 (17.8%)
#   • бар,паб: 68 (9.2%)
#   • пиццерия: 73 (9.9%)
#
#
#
#
# 💡 АНАЛИЗ РАСПРЕДЕЛЕНИЯ ЗАВЕДЕНИЙ ПО РАЙОНАМ:
# ================================================================================
#
# 1. ОБЩАЯ СТАТИСТИКА:
# ----------------------------------------
# • Всего заведений в Москве: 8 406
# • Количество административных округов: 9
# • Среднее количество заведений на округ: 934
# • Коэффициент вариации: 55.1%
#
# 2. ЛИДЕРЫ И АУТСАЙДЕРЫ:
# ----------------------------------------
# 🥇 ЛИДЕР - Центральный административный округ:
#    • Заведений: 2 242
#    • Доля от общего числа: 26.7%
#    • В 2.5 раза больше, чем в среднем по округам
#
# 📊 СРЕДНИЕ ПОКАЗАТЕЛИ:
#    • 6 округов имеют от 700 до 900 заведений
#    • Среднее значение: 841
#    • Стандартное отклонение: 73
#
# 🔻 АУТСАЙДЕР - Северо-Западный административный округ:
#    • Заведений: 409
#    • Доля от общего числа: 4.9%
#    • В 2.2 раза меньше, чем в среднем по округам
#
# 3. РАСПРЕДЕЛЕНИЕ КАТЕГОРИЙ ПО ОКРУГАМ:
# ----------------------------------------
# 🔍 КЛЮЧЕВЫЕ НАБЛЮДЕНИЯ:
#
# 1. КАФЕ - универсальный формат для всех округов:
#    • Центральный административный округ: 464 (20.7%)
#    • Северный административный округ: 235 (26.1%)
#    • Южный административный округ: 264 (29.6%)
#    • Северо-Восточный административный округ: 269 (30.2%)
#    • Западный административный округ: 239 (28.1%)
#    • Восточный административный округ: 272 (34.1%)
#    • Юго-Восточный административный округ: 282 (39.5%)
#    • Юго-Западный административный округ: 238 (33.6%)
#    • Северо-Западный административный округ: 115 (28.1%)
#
# 2. РЕСТОРАНЫ - концентрация в ЦАО:
#    • ЦАО: 670 ресторанов (29.9% от заведений округа)
#    • Это 32.8% всех ресторанов Москвы
#
# 3. КОФЕЙНИ - равномерное распределение:
#    • Центральный административный округ: 428 (30.3% от всех кофеен Москвы)
#    • Северный административный округ: 193 (13.7% от всех кофеен Москвы)
#    • Южный административный округ: 131 (9.3% от всех кофеен Москвы)
#
# 4. ПИЦЦЕРИИ - стабильное присутствие:
#    • Центральный административный округ: 113 (5.0%)
#    • Северный административный округ: 77 (8.6%)
#    • Южный административный округ: 73 (8.2%)
#    • Северо-Восточный административный округ: 68 (7.6%)
#    • Западный административный округ: 71 (8.3%)
#    • Восточный административный округ: 72 (9.0%)
#    • Юго-Восточный административный округ: 55 (7.7%)
#    • Юго-Западный административный округ: 64 (9.0%)
#    • Северо-Западный административный округ: 40 (9.8%)
#
# 4. ГЕОГРАФИЧЕСКИЕ ОСОБЕННОСТИ:
# ----------------------------------------
#
# • ЦЕНТРАЛЬНЫЙ АДМИНИСТРАТИВНЫЙ ОКРУГ:
#   - Абсолютный лидер по количеству заведений (26.7% рынка)
#   - Высокая концентрация ресторанов и премиальных заведений
#   - Туристический и деловой центр города
#   - Максимальная проходимость и покупательская способность
#
# • ОКРУГА-СЕРЕДНЯКИ (700-900 заведений):
#   - Северный, Южный, СВАО, Западный, Восточный, ЮВАО, ЮЗАО
#   - Стабильное развитие инфраструктуры
#   - Локальные центры притяжения в спальных районах
#   - Более доступные арендные ставки
#
# • СЕВЕРО-ЗАПАДНЫЙ АДМИНИСТРАТИВНЫЙ ОКРУГ:
#   - Наименьшее количество заведений (4.9% рынка)
#   - Возможные причины:
#     1. Меньшая плотность населения
#     2. Более позднее развитие инфраструктуры
#     3. Особенности застройки и планировки
#
#
# 5. БИЗНЕС-ИНТЕРПРЕТАЦИЯ ДЛЯ ИНВЕСТОРОВ:
# ----------------------------------------
#
# 🎯 ВЫБОР ЛОКАЦИИ ДЛЯ НОВОГО ЗАВЕДЕНИЯ:
#
# ✅ ЦЕНТРАЛЬНЫЙ АДМИНИСТРАТИВНЫЙ ОКРУГ:
#    Преимущества:
#    • Максимальный трафик (туристы, бизнесмены, местные жители)
#    • Высокая покупательская способность
#    • Престиж локации
#
#    Риски:
#    • Максимальная конкуренция
#    • Высокие арендные ставки
#    • Сложности с логистикой и парковкой
#
#    Рекомендация: Только для премиальных или уникальных концепций
#
# ✅ ОКРУГА С 700-900 ЗАВЕДЕНИЯМИ:
#    Преимущества:
#    • Сбалансированная конкуренция
#    • Доступные арендные ставки
#    • Локальная лояльная аудитория
#    • Развитая инфраструктура
#
#    Риски:
#    • Меньший трафик по сравнению с центром
#    • Сезонные колебания спроса
#
#    Рекомендация: Оптимальный выбор для первого проекта
#
# ✅ СЕВЕРО-ЗАПАДНЫЙ АДМИНИСТРАТИВНЫЙ ОКРУГ:
#    Преимущества:
#    • Низкая конкуренция
#    • Возможность стать локальным лидером
#    • Нишевые возможности
#
#    Риски:
#    • Ограниченный трафик
#    • Меньшая плотность населения
#    • Возможные сложности с логистикой
#
#    Рекомендация: Для специализированных или нишевых форматов
#
#
# 6. КОНКРЕТНЫЕ РЕКОМЕНДАЦИИ:
# ----------------------------------------
#
# 📍 ДЛЯ КАЖДОГО ФОРМАТА СВОЯ ОПТИМАЛЬНАЯ ЛОКАЦИЯ:
#
# • Рестораны и премиальные заведения:
#   ✅ ЦАО - максимальная видимость и трафик
#   ✅ ЮЗАО/ЗАО - районы с высокой покупательской способностью
#
# • Кофейни и кафе:
#   ✅ Все округа, но с разной концепцией:
#      - ЦАО: премиум-кофейни для туристов и бизнесменов
#      - Остальные округа: neighborhood-кофейни для локальной аудитории
#
# • Пиццерии и фастфуд:
#   ✅ Округа с высокой плотностью населения
#   ✅ Около транспортных узлов и бизнес-центров
#
# • Бары и пабы:
#   ✅ ЦАО - центр ночной жизни
#   ✅ Около университетов и студенческих городков
#
#
# 📊 СВОДНАЯ ТАБЛИЦА ДЛЯ ПРИНЯТИЯ РЕШЕНИЙ:
# ----------------------------------------
#                                   Округ  Всего заведений  Доля рынка Уровень конкуренции                  Рекомендуемые форматы
#      Центральный административный округ             2242   26.671425       Очень высокий Премиум рестораны, концептуальные кафе
#         Северный административный округ              900   10.706638             Высокий    Сетевые кофейни, семейные рестораны
#            Южный административный округ              892   10.611468             Высокий                   Кафе, пиццерии, бары
# Северо-Восточный административный округ              891   10.599572             Высокий             Кофейни, фастфуд, столовые
#         Западный административный округ              851   10.123721             Высокий          Рестораны, кафе, детские кафе
#        Восточный административный округ              798    9.493219             Средний               Пиццерии, столовые, кафе
#    Юго-Восточный административный округ              714    8.493933             Средний              Кофейни, фастфуд, пекарни
#     Юго-Западный административный округ              709    8.434452             Средний               Столовые, кафе, доставка
#  Северо-Западный административный округ              409    4.865572              Низкий        Нишевые форматы, локальные кафе
#
# ================================================================================
# ИТОГОВЫЙ ВЫВОД:
# ================================================================================
#
# В датасете представлены все 9 административных округов Москвы.
#
# КЛЮЧЕВЫЕ ВЫВОДЫ:
# 1. ЦАО доминирует с 26.7% рынка - это центр притяжения ресторанов и премиальных заведений
# 2. 7 округов имеют сбалансированное развитие (9-11% рынка каждый)
# 3. СЗАО отстает с 4.9% рынка, что может быть как риском, так и возможностью
#
# РАСПРЕДЕЛЕНИЕ КАТЕГОРИЙ:
# • Кафе - равномерно распределены по всем округам (35-40% в каждом)
# • Рестораны - сконцентрированы в ЦАО (до 35% от всех заведений округа)
# • Кофейни - равномерное присутствие, но с разной концепцией по округам
#
# РЕКОМЕНДАЦИЯ ДЛЯ ИНВЕСТОРОВ:
# Для первого проекта рекомендуется выбрать один из округов со средним
# уровнем развития (700-900 заведений), где конкуренция сбалансирована,
# а арендные ставки разумны. ЦАО стоит рассматривать только для уникальных
# или премиальных концепций с соответствующим бюджетом.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал шаг

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.7 Анализ рейтингов
#
# ---
#
# - Визуализируйте распределение средних рейтингов по категориям заведений.
# - Сильно ли различаются усреднённые рейтинги в разных типах общепита?

# %%
# # =============================================================================
# # АНАЛИЗ: РАСПРЕДЕЛЕНИЕ РЕЙТИНГОВ ПО КАТЕГОРИЯМ ЗАВЕДЕНИЙ
# # =============================================================================

# print("\n" + "="*80)
# print("АНАЛИТИЧЕСКИЙ ВЫВОД: РАСПРЕДЕЛЕНИЕ РЕЙТИНГОВ ПО КАТЕГОРИЯМ")
# print("="*80)

# # 1. Подготовка данных
# print("\n📊 ПОДГОТОВКА ДАННЫХ ДЛЯ АНАЛИЗА РЕЙТИНГОВ:")
# print("-" * 60)

# # Удаляем пропуски в рейтингах
# rating_df = df.dropna(subset=['rating']).copy()

# print(f"• Всего заведений в датасете: {len(df):,}".replace(',', ' '))
# print(f"• Заведений с указанным рейтингом: {len(rating_df):,} ({len(rating_df)/len(df)*100:.1f}%)".replace(',', ' '))
# print(f"• Заведений без рейтинга: {df['rating'].isnull().sum():,} ({df['rating'].isnull().sum()/len(df)*100:.1f}%)".replace(',', ' '))

# # Проверяем распределение рейтингов
# print(f"\n📈 ОБЩАЯ СТАТИСТИКА ПО РЕЙТИНГАМ:")
# print(f"• Средний рейтинг по всем заведениям: {rating_df['rating'].mean():.2f}")
# print(f"• Медианный рейтинг: {rating_df['rating'].median():.2f}")
# print(f"• Стандартное отклонение: {rating_df['rating'].std():.2f}")
# print(f"• Минимальный рейтинг: {rating_df['rating'].min():.2f}")
# print(f"• Максимальный рейтинг: {rating_df['rating'].max():.2f}")

# # 2. Анализ рейтингов по категориям
# print(f"\n🔍 АНАЛИЗ РЕЙТИНГОВ ПО КАТЕГОРИЯМ:")
# print("-" * 60)

# # Группируем по категориям
# rating_by_category = rating_df.groupby('category')['rating'].agg([
#     ('mean', 'mean'),
#     ('median', 'median'),
#     ('count', 'count'),
#     ('std', 'std'),
#     ('min', 'min'),
#     ('max', 'max'),
#     ('q1', lambda x: x.quantile(0.25)),
#     ('q3', lambda x: x.quantile(0.75))
# ]).round(3)

# # Фильтруем категории с достаточным количеством данных
# rating_by_category_filtered = rating_by_category[rating_by_category['count'] >= 30].copy()
# rating_by_category_filtered = rating_by_category_filtered.sort_values('mean', ascending=False)

# print("\nСтатистика рейтингов по категориям (минимум 30 заведений):")
# print(rating_by_category_filtered[['mean', 'median', 'count', 'std']].head(15))

# # 3. ВИЗУАЛИЗАЦИЯ 1: Boxplot распределения рейтингов по категориям
# print(f"\n📊 ВИЗУАЛИЗАЦИЯ 1: BOXPLOT РАСПРЕДЕЛЕНИЯ РЕЙТИНГОВ")
# print("-" * 60)

# plt.figure(figsize=(16, 10))

# # Фильтруем данные для визуализации
# main_categories = rating_by_category_filtered.index.tolist()
# rating_main_cats = rating_df[rating_df['category'].isin(main_categories)]

# # Создаем boxplot
# boxplot = sns.boxplot(data=rating_main_cats, 
#                       x='rating', 
#                       y='category',
#                       order=rating_by_category_filtered.index.tolist(),
#                       palette='Set2',
#                       linewidth=1.5)

# plt.xlabel('Рейтинг заведения', fontsize=12, fontweight='bold')
# plt.ylabel('Категория заведения', fontsize=12, fontweight='bold')
# plt.title('Распределение рейтингов заведений по категориям', 
#           fontsize=16, fontweight='bold', pad=20)

# # Добавляем вертикальные линии для ориентиров
# plt.axvline(x=4.0, color='green', linestyle='--', alpha=0.5, label='Рейтинг 4.0')
# plt.axvline(x=4.5, color='blue', linestyle='--', alpha=0.5, label='Рейтинг 4.5')
# plt.axvline(x=rating_df['rating'].mean(), color='red', linestyle='-', 
#             label=f'Среднее по рынку: {rating_df["rating"].mean():.2f}')

# plt.legend()
# plt.grid(axis='x', alpha=0.3)
# plt.tight_layout()
# plt.show()

# # 4. ВИЗУАЛИЗАЦИЯ 2: Bar chart средних рейтингов по категориям
# print(f"\n📊 ВИЗУАЛИЗАЦИЯ 2: СРЕДНИЕ РЕЙТИНГИ ПО КАТЕГОРИЯМ")
# print("-" * 60)

# plt.figure(figsize=(14, 8))

# # Сортируем категории по среднему рейтингу
# sorted_categories = rating_by_category_filtered.sort_values('mean', ascending=True)

# # Создаем цветовую схему на основе рейтинга
# norm = plt.Normalize(sorted_categories['mean'].min(), sorted_categories['mean'].max())
# colors = plt.cm.RdYlGn(norm(sorted_categories['mean']))

# # Создаем bar chart
# bars = plt.barh(sorted_categories.index, sorted_categories['mean'], color=colors, edgecolor='black')

# plt.xlabel('Средний рейтинг', fontsize=12, fontweight='bold')
# plt.ylabel('Категория заведения', fontsize=12, fontweight='bold')
# plt.title('Средние рейтинги заведений по категориям', 
#           fontsize=16, fontweight='bold', pad=20)

# # Добавляем значения на столбцы
# for bar, mean_rating, count in zip(bars, sorted_categories['mean'], sorted_categories['count']):
#     width = bar.get_width()
#     plt.text(width + 0.01, bar.get_y() + bar.get_height()/2, 
#              f'{mean_rating:.2f} (n={count})', 
#              ha='left', va='center', fontsize=10, fontweight='bold')

# # Добавляем линию среднего по рынку
# market_mean = rating_df['rating'].mean()
# plt.axvline(x=market_mean, color='red', linestyle='--', linewidth=2, 
#             label=f'Среднее по рынку: {market_mean:.2f}')

# plt.legend()
# plt.grid(axis='x', alpha=0.3)
# plt.xlim(3.8, 4.6)  # Ограничиваем для лучшей визуализации
# plt.tight_layout()
# plt.show()

# # 5. ВИЗУАЛИЗАЦИЯ 3: Violin plot для более детального анализа распределения
# print(f"\n📊 ВИЗУАЛИЗАЦИЯ 3: ДЕТАЛЬНОЕ РАСПРЕДЕЛЕНИЕ РЕЙТИНГОВ")
# print("-" * 60)

# plt.figure(figsize=(16, 10))

# # Выбираем топ-8 категорий по количеству заведений для violin plot
# top_categories_by_count = rating_by_category_filtered.nlargest(8, 'count').index.tolist()
# rating_top_cats = rating_df[rating_df['category'].isin(top_categories_by_count)]

# # Создаем violin plot
# violin = sns.violinplot(data=rating_top_cats, 
#                         x='category', 
#                         y='rating',
#                         order=top_categories_by_count,
#                         palette='Set3',
#                         inner='quartile')

# plt.xlabel('Категория заведения', fontsize=12, fontweight='bold')
# plt.ylabel('Рейтинг', fontsize=12, fontweight='bold')
# plt.title('Распределение рейтингов по основным категориям (violin plot)', 
#           fontsize=16, fontweight='bold', pad=20)
# plt.xticks(rotation=45, ha='right')
# plt.axhline(y=market_mean, color='red', linestyle='--', 
#             label=f'Среднее по рынку: {market_mean:.2f}')
# plt.legend()
# plt.grid(axis='y', alpha=0.3)
# plt.ylim(2.5, 5.1)
# plt.tight_layout()
# plt.show()

# # =============================================================================
# # ПОДРОБНЫЙ АНАЛИТИЧЕСКИЙ ВЫВОД
# # =============================================================================

# print("\n💡 АНАЛИЗ РАЗЛИЧИЙ РЕЙТИНГОВ ПО КАТЕГОРИЯМ:")
# print("=" * 80)

# print(f"\n1. ОБЩАЯ ОЦЕНКА РАЗБРОСА РЕЙТИНГОВ:")
# print("-" * 40)

# # Рассчитываем размах рейтингов
# rating_range = rating_by_category_filtered['mean'].max() - rating_by_category_filtered['mean'].min()
# rating_std_dev = rating_by_category_filtered['mean'].std()
# coef_of_variation = (rating_std_dev / rating_by_category_filtered['mean'].mean()) * 100

# print(f"• Размах средних рейтингов: {rating_range:.3f} балла")
# print(f"• Стандартное отклонение: {rating_std_dev:.3f}")
# print(f"• Коэффициент вариации: {coef_of_variation:.1f}%")
# print(f"• Средний рейтинг по рынку: {market_mean:.2f}")

# print(f"\n2. КАТЕГОРИИ С САМЫМИ ВЫСОКИМИ РЕЙТИНГАМИ:")
# print("-" * 40)

# top_3_categories = rating_by_category_filtered.nlargest(3, 'mean')
# for i, (category, row) in enumerate(top_3_categories.iterrows(), 1):
#     diff_from_mean = row['mean'] - market_mean
#     print(f"{i}. {category.upper()}:")
#     print(f"   • Средний рейтинг: {row['mean']:.2f}")
#     print(f"   • Выше среднего по рынку на: {diff_from_mean:.2f} балла")
#     print(f"   • Медианный рейтинг: {row['median']:.2f}")
#     print(f"   • Количество оценок: {row['count']:,}".replace(',', ' '))
#     print(f"   • Стабильность (std): {row['std']:.3f}")

# print(f"\n3. КАТЕГОРИИ С САМЫМИ НИЗКИМИ РЕЙТИНГАМИ:")
# print("-" * 40)

# bottom_3_categories = rating_by_category_filtered.nsmallest(3, 'mean')
# for i, (category, row) in enumerate(bottom_3_categories.iterrows(), 1):
#     diff_from_mean = market_mean - row['mean']
#     print(f"{i}. {category.upper()}:")
#     print(f"   • Средний рейтинг: {row['mean']:.2f}")
#     print(f"   • Ниже среднего по рынку на: {diff_from_mean:.2f} балла")
#     print(f"   • Медианный рейтинг: {row['median']:.2f}")
#     print(f"   • Количество оценок: {row['count']:,}".replace(',', ' '))
#     print(f"   • Стабильность (std): {row['std']:.3f}")

# print(f"\n4. СТАТИСТИЧЕСКАЯ ЗНАЧИМОСТЬ РАЗЛИЧИЙ:")
# print("-" * 40)

# # Проверяем статистическую значимость различий между топ-1 и bottom-1
# from scipy import stats

# top_category_data = rating_df[rating_df['category'] == top_3_categories.index[0]]['rating']
# bottom_category_data = rating_df[rating_df['category'] == bottom_3_categories.index[0]]['rating']

# # T-тест для сравнения средних
# t_stat, p_value = stats.ttest_ind(top_category_data, bottom_category_data, equal_var=False)

# print(f"• Сравнение {top_3_categories.index[0]} vs {bottom_3_categories.index[0]}:")
# print(f"  Разница в средних: {top_3_categories.iloc[0]['mean'] - bottom_3_categories.iloc[0]['mean']:.3f}")
# print(f"  T-статистика: {t_stat:.3f}")
# print(f"  P-значение: {p_value:.6f}")
# print(f"  Вывод: {'Различия статистически значимы' if p_value < 0.05 else 'Различия не статистически значимы'}")

# print(f"\n5. АНАЛИЗ СТАБИЛЬНОСТИ РЕЙТИНГОВ:")
# print("-" * 40)

# # Сортируем по стандартному отклонению (мера стабильности)
# stable_categories = rating_by_category_filtered.sort_values('std').head(3)
# volatile_categories = rating_by_category_filtered.sort_values('std', ascending=False).head(3)

# print(f"🔹 НАИБОЛЕЕ СТАБИЛЬНЫЕ КАТЕГОРИИ (низкий разброс оценок):")
# for i, (category, row) in enumerate(stable_categories.iterrows(), 1):
#     print(f"   {i}. {category}: std={row['std']:.3f}, диапазон Q1-Q3: {row['q3']-row['q1']:.3f}")

# print(f"\n🔸 НАИМЕНЕЕ СТАБИЛЬНЫЕ КАТЕГОРИИ (высокий разброс оценок):")
# for i, (category, row) in enumerate(volatile_categories.iterrows(), 1):
#     print(f"   {i}. {category}: std={row['std']:.3f}, диапазон Q1-Q3: {row['q3']-row['q1']:.3f}")

# print(f"\n6. БИЗНЕС-ИНТЕРПРЕТАЦИЯ РЕЙТИНГОВ:")
# print("=" * 80)



# =============================================================================
# ШАГ 3.7: ИСПРАВЛЕННАЯ ВИЗУАЛИЗАЦИЯ - VIOLIN PLOT С СОРТИРОВКОЙ
# =============================================================================

print("=" * 80)
print("VIOLIN PLOT РАСПРЕДЕЛЕНИЯ РЕЙТИНГОВ ПО КАТЕГОРИЯМ (С СОРТИРОВКОЙ)")
print("=" * 80)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 1. ПОДГОТОВКА ДАННЫХ С СОРТИРОВКОЙ
print("\n📊 ПОДГОТОВКА ДАННЫХ С СОРТИРОВКОЙ ПО МЕДИАНЕ:")
print("-" * 50)

# Удаляем пропуски в рейтингах
rating_df = df.dropna(subset=['rating']).copy()

# Выбираем основные категории для анализа
main_categories = ['кафе', 'ресторан', 'кофейня', 'пиццерия', 'бар,паб', 'столовая', 'быстрое питание']
rating_main_cats = rating_df[rating_df['category'].isin(main_categories)]

# Рассчитываем медианные рейтинги для каждой категории
median_ratings = rating_main_cats.groupby('category')['rating'].median().sort_values(ascending=False)

print("Медианные рейтинги по категориям (отсортированные):")
for category, median_rating in median_ratings.items():
    count = rating_main_cats[rating_main_cats['category'] == category].shape[0]
    print(f"• {category}: {median_rating:.2f} (n={count})")

# Сортируем категории по медианному рейтингу для визуализации
sorted_categories = median_ratings.index.tolist()

# 2. VIOLIN PLOT С СОРТИРОВКОЙ ПО МЕДИАНЕ
print("\n🎻 СОЗДАНИЕ VIOLIN PLOT С СОРТИРОВКОЙ:")
print("-" * 50)

plt.figure(figsize=(14, 10))

# Создаем violin plot с сортировкой по медиане
violin = sns.violinplot(data=rating_main_cats, 
                        x='category', 
                        y='rating',
                        order=sorted_categories,  # Ключевое исправление: добавляем сортировку
                        palette='Set3',
                        inner='quartile',
                        linewidth=1.5,
                        cut=0)  # Не обрезаем распределение

plt.xlabel('Категория заведения', fontsize=12, fontweight='bold')
plt.ylabel('Рейтинг', fontsize=12, fontweight='bold')
plt.title('Распределение рейтингов по основным категориям заведений (отсортировано по медиане)', 
          fontsize=16, fontweight='bold', pad=20)

# Добавляем горизонтальные линии для ориентиров
plt.axhline(y=4.0, color='green', linestyle='--', alpha=0.5, linewidth=1, label='Рейтинг 4.0')
plt.axhline(y=4.5, color='blue', linestyle='--', alpha=0.5, linewidth=1, label='Рейтинг 4.5')

# Добавляем среднее значение по всем категориям
overall_mean = rating_df['rating'].mean()
plt.axhline(y=overall_mean, color='red', linestyle='-', linewidth=2, 
            label=f'Среднее по рынку: {overall_mean:.2f}')

# Добавляем медианные значения на график
for i, category in enumerate(sorted_categories):
    median_val = median_ratings[category]
    plt.text(i, median_val + 0.02, f'{median_val:.2f}', 
             ha='center', va='bottom', fontsize=10, fontweight='bold',
             bbox=dict(boxstyle='round,pad=0.3', facecolor='white', alpha=0.8))

plt.xticks(rotation=45, ha='right')
plt.ylim(2.5, 5.1)
plt.legend(loc='upper right', fontsize=10)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# 3. ДОПОЛНИТЕЛЬНАЯ ВИЗУАЛИЗАЦИЯ: BOXPLOT С СОРТИРОВКОЙ
print("\n📦 ДОПОЛНИТЕЛЬНАЯ ВИЗУАЛИЗАЦИЯ: BOXPLOT С СОРТИРОВКОЙ:")
print("-" * 50)

plt.figure(figsize=(14, 8))

# Создаем boxplot с сортировкой
boxplot = sns.boxplot(data=rating_main_cats, 
                      x='category', 
                      y='rating',
                      order=sorted_categories,  # Сортируем по медиане
                      palette='pastel',
                      showfliers=False,  # Скрываем выбросы для лучшей читаемости
                      linewidth=1.5)

plt.xlabel('Категория заведения', fontsize=12, fontweight='bold')
plt.ylabel('Рейтинг', fontsize=12, fontweight='bold')
plt.title('Boxplot распределения рейтингов по категориям (отсортировано по медиане)', 
          fontsize=16, fontweight='bold', pad=20)

# Добавляем средние значения
means = rating_main_cats.groupby('category')['rating'].mean().loc[sorted_categories]
for i, mean_val in enumerate(means):
    plt.scatter(i, mean_val, color='red', s=100, zorder=5, 
                label='Среднее' if i == 0 else "")
    plt.text(i, mean_val - 0.05, f'{mean_val:.2f}', 
             ha='center', va='top', fontsize=9, fontweight='bold', color='red')

plt.axhline(y=overall_mean, color='black', linestyle='--', linewidth=2, 
            label=f'Общее среднее: {overall_mean:.2f}')

plt.xticks(rotation=45, ha='right')
plt.ylim(3.5, 5.0)
plt.legend(loc='upper right')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# 4. СТАТИСТИЧЕСКИЙ АНАЛИЗ РАЗЛИЧИЙ
print("\n📊 СТАТИСТИЧЕСКИЙ АНАЛИЗ РАЗЛИЧИЙ МЕЖДУ КАТЕГОРИЯМИ:")
print("-" * 50)

from scipy import stats

print("Сравнение категорий с наибольшим и наименьшим рейтингом:")
top_category = sorted_categories[0]
bottom_category = sorted_categories[-1]

top_data = rating_main_cats[rating_main_cats['category'] == top_category]['rating']
bottom_data = rating_main_cats[rating_main_cats['category'] == bottom_category]['rating']

# T-тест
t_stat, p_value = stats.ttest_ind(top_data, bottom_data, equal_var=False)

print(f"\n{top_category} vs {bottom_category}:")
print(f"• Медиана {top_category}: {median_ratings[top_category]:.3f}")
print(f"• Медиана {bottom_category}: {median_ratings[bottom_category]:.3f}")
print(f"• Разница: {median_ratings[top_category] - median_ratings[bottom_category]:.3f}")
print(f"• T-статистика: {t_stat:.3f}")
print(f"• P-значение: {p_value:.6f}")
print(f"• Вывод: {'Различия статистически значимы (p < 0.05)' if p_value < 0.05 else 'Различия не статистически значимы'}")

# 5. ТАБЛИЦА С РАНЖИРОВАНИЕМ КАТЕГОРИЙ
print("\n🏆 ТАБЛИЦА РАНЖИРОВАНИЯ КАТЕГОРИЙ ПО РЕЙТИНГАМ:")
print("-" * 50)

# Создаем DataFrame с ранжированием
ranking_df = pd.DataFrame({
    'Место': range(1, len(sorted_categories) + 1),
    'Категория': sorted_categories,
    'Медианный рейтинг': [median_ratings[cat] for cat in sorted_categories],
    'Средний рейтинг': [rating_main_cats[rating_main_cats['category'] == cat]['rating'].mean() for cat in sorted_categories],
    'Количество оценок': [rating_main_cats[rating_main_cats['category'] == cat].shape[0] for cat in sorted_categories],
    'Стандартное отклонение': [rating_main_cats[rating_main_cats['category'] == cat]['rating'].std() for cat in sorted_categories]
}).round(3)

print(ranking_df.to_string(index=False))

# 6. ВИЗУАЛИЗАЦИЯ РАНЖИРОВАНИЯ
print("\n📈 ВИЗУАЛИЗАЦИЯ РАНЖИРОВАНИЯ КАТЕГОРИЙ:")
print("-" * 50)

plt.figure(figsize=(12, 8))

# Горизонтальная столбчатая диаграмма с ранжированием
bars = plt.barh(range(len(sorted_categories)), 
                [median_ratings[cat] for cat in sorted_categories],
                color=plt.cm.RdYlGn(np.linspace(0.2, 0.8, len(sorted_categories))),
                edgecolor='black')

plt.yticks(range(len(sorted_categories)), sorted_categories)
plt.xlabel('Медианный рейтинг', fontsize=12, fontweight='bold')
plt.ylabel('Категория заведения', fontsize=12, fontweight='bold')
plt.title('Ранжирование категорий по медианному рейтингу', 
          fontsize=16, fontweight='bold', pad=20)

# Добавляем значения на столбцы
for i, bar in enumerate(bars):
    width = bar.get_width()
    # Размещаем текст внутри столбца для лучшей читаемости
    text_x = width - 0.05 if width > 4.2 else width + 0.02
    text_color = 'white' if width > 4.2 else 'black'
    plt.text(text_x, bar.get_y() + bar.get_height()/2, 
             f'{width:.3f}', 
             ha='right' if width > 4.2 else 'left', 
             va='center', fontsize=10, fontweight='bold', color=text_color)

plt.axvline(x=overall_mean, color='red', linestyle='--', linewidth=2, 
            label=f'Среднее по рынку: {overall_mean:.2f}')
plt.grid(axis='x', alpha=0.3)
plt.legend(loc='lower right')
plt.xlim(3.9, 4.6)
plt.tight_layout()
plt.show()

# 7. СВОДНЫЙ АНАЛИЗ
print("\n" + "="*80)
print("СВОДНЫЙ АНАЛИЗ РЕЙТИНГОВ ПО КАТЕГОРИЯМ")
print("="*80)

print(f"\n📊 ОБЩАЯ СТАТИСТИКА:")
print(f"• Всего заведений с рейтингом: {len(rating_df):,}".replace(',', ' '))
print(f"• Средний рейтинг по всем заведениям: {overall_mean:.3f}")
print(f"• Медианный рейтинг: {rating_df['rating'].median():.3f}")
print(f"• Стандартное отклонение: {rating_df['rating'].std():.3f}")

print(f"\n🏆 ТОП-3 КАТЕГОРИЙ ПО РЕЙТИНГУ:")
for i, category in enumerate(sorted_categories[:3], 1):
    median_val = median_ratings[category]
    diff_from_mean = median_val - overall_mean
    print(f"{i}. {category}: {median_val:.3f} (+{diff_from_mean:.3f} к среднему)")

print(f"\n🔻 НИЗ-3 КАТЕГОРИЙ ПО РЕЙТИНГУ:")
for i, category in enumerate(sorted_categories[-3:], len(sorted_categories)-2):
    median_val = median_ratings[category]
    diff_from_mean = median_val - overall_mean
    print(f"{i}. {category}: {median_val:.3f} ({diff_from_mean:+.3f} к среднему)")

print(f"\n📈 РАЗБРОС РЕЙТИНГОВ:")
max_median = median_ratings.max()
min_median = median_ratings.min()
range_median = max_median - min_median
print(f"• Максимальная медиана: {max_median:.3f} ({sorted_categories[0]})")
print(f"• Минимальная медиана: {min_median:.3f} ({sorted_categories[-1]})")
print(f"• Размах медиан: {range_median:.3f}")
print(f"• Коэффициент вариации: {(median_ratings.std() / median_ratings.mean() * 100):.1f}%")

print(f"\n🎯 ВЫВОДЫ ДЛЯ ИНВЕСТОРОВ:")
print(f"1. Категория {sorted_categories[0]} имеет наивысший медианный рейтинг ({median_ratings[sorted_categories[0]]:.3f})")
print(f"2. Категория {sorted_categories[-1]} имеет самый низкий медианный рейтинг ({median_ratings[sorted_categories[-1]]:.3f})")
print(f"3. Разница между лучшей и худшей категорией: {range_median:.3f} балла")
print(f"4. Все категории находятся в диапазоне 'хорошо-отлично' (4.0-4.5)")

print("\n" + "="*80)
# Out:
# ...
# VIOLIN PLOT РАСПРЕДЕЛЕНИЯ РЕЙТИНГОВ ПО КАТЕГОРИЯМ (С СОРТИРОВКОЙ)
# ...
#
# 📊 ПОДГОТОВКА ДАННЫХ С СОРТИРОВКОЙ ПО МЕДИАНЕ:
# --------------------------------------------------
# Медианные рейтинги по категориям (отсортированные):
# • бар,паб: 4.40 (n=765)
# • кофейня: 4.30 (n=1413)
# • пиццерия: 4.30 (n=633)
# • ресторан: 4.30 (n=2043)
# • столовая: 4.30 (n=315)
# • быстрое питание: 4.20 (n=603)
# • кафе: 4.20 (n=2378)
#
# 🎻 СОЗДАНИЕ VIOLIN PLOT С СОРТИРОВКОЙ:
# --------------------------------------------------
# 📦 ДОПОЛНИТЕЛЬНАЯ ВИЗУАЛИЗАЦИЯ: BOXPLOT С СОРТИРОВКОЙ:
# --------------------------------------------------
# 📊 СТАТИСТИЧЕСКИЙ АНАЛИЗ РАЗЛИЧИЙ МЕЖДУ КАТЕГОРИЯМИ:
# --------------------------------------------------
# Сравнение категорий с наибольшим и наименьшим рейтингом:
#
# бар,паб vs кафе:
# • Медиана бар,паб: 4.400
# • Медиана кафе: 4.200
# • Разница: 0.200
# • T-статистика: 14.665
# • P-значение: 0.000000
# • Вывод: Различия статистически значимы (p < 0.05)
#
# ...

# %% [markdown]
# **АНАЛИТИЧЕСКИЙ ВЫВОД: РАЗЛИЧИЯ РЕЙТИНГОВ МЕЖДУ КАТЕГОРИЯМИ**
#
# ---
#
# ### 📊 **КЛЮЧЕВЫЕ НАБЛЮДЕНИЯ:**
#
# **1. ОБЩИЙ УРОВЕНЬ РЕЙТИНГОВ ВЫСОКИЙ:**
# - Средний рейтинг по всем заведениям: **4.23/5.0**
# - Медианный рейтинг: **4.30/5.0**
# - Это указывает на **систематическое завышение оценок** или высокие стандарты качества в целом
#
# **2. РАЗНИЦЫ МЕЖДУ КАТЕГОРИЯМИ НЕЗНАЧИТЕЛЬНЫ, НО СТАТИСТИЧЕСКИ ЗНАЧИМЫ:**
# - Размах средних рейтингов: **всего 0.338 балла** (от 4.05 до 4.39)
# - Коэффициент вариации: **всего 2.5%** - разброс минимальный
# - **НО:** Различия статистически значимы (p-value ≈ 0)
#
# **3. ЧЕТКОЕ РАНЖИРОВАНИЕ КАТЕГОРИЙ:**
#
# **ТОП-3 (выше среднего по рынку 4.23):**
# 1. **Бары/пабы** - 4.39 (+0.16 к среднему)
# 2. **Пиццерии** - 4.30 (+0.07)
# 3. **Рестораны** - 4.29 (+0.06)
#
# **НИЗ-3 (ниже среднего по рынку):**
# 1. **Быстрое питание** - 4.05 (-0.18)
# 2. **Кафе** - 4.12 (-0.11)
# 3. **Столовые** - 4.21 (-0.02)
#
# **СРЕДНИЕ ПОЗИЦИИ:**
# - Кофейни - 4.28 (+0.05)
# - Булочные - 4.27 (+0.04)
#
# ---
#
# ### 🔍 **ГЛУБОКИЕ ИНСАЙТЫ:**
#
# **1. "ЭМОЦИОНАЛЬНЫЙ РЕЙТИНГ" vs "УТИЛИТАРНЫЙ РЕЙТИНГ":**
# - **Высокие оценки:** Бары/пабы, пиццерии, рестораны
#   - Заведения для отдыха и развлечений
#   - Клиенты оценивают не только еду, но и атмосферу, эмоции
#   - Снисходительность в неформальной обстановке
#
# - **Низкие оценки:** Быстрое питание, кафе, столовые
#   - Утилитарные посещения (перекус, обед)
#   - Клиенты более требовательны к цене/качеству
#   - Меньше эмоциональной составляющей
#
# **2. СТАБИЛЬНОСТЬ ОЦЕНОК РАЗЛИЧАЕТСЯ СИЛЬНЕЕ, ЧЕМ СРЕДНИЕ ЗНАЧЕНИЯ:**
# - **Наиболее стабильные категории** (низкий std):
#   - Пиццерии (0.336) - стандартизированный продукт
#   - Кофейни (0.372) - предсказуемое качество кофе
#   - Бары (0.380) - стабильный опыт
#
# - **Наименее стабильные категории** (высокий std):
#   - Кафе (0.566) - большой разброс качества
#   - Быстрое питание (0.561) - зависимость от локации и персонала
#   - Столовые (0.454) - разный уровень в разных учреждениях
#
# **3. ПАРАДОКС "КАФЕ":**
# - Самая массовая категория (2,378 заведений)
# - Один из самых низких средних рейтингов (4.12)
# - Самый высокий разброс оценок (std=0.566)
# - **Вывод:** Кафе - самый разнородный сегмент по качеству
#
# ---
#
# ### 💼 **БИЗНЕС-ИНТЕРПРЕТАЦИЯ:**
#
# **1. КОНКУРЕНТНЫЕ ПРЕИМУЩЕСТВА НА РЫНКЕ:**
# - **Высокие рейтинги** ≠ **высокая прибыльность**
# - Бары/пабы имеют лучшие оценки, но:
#   - Сезонный бизнес
#   - Зависимость от локации
#   - Лицензирование алкоголя
#
# - **Пиццерии** - оптимальный баланс:
#   - Высокие оценки (4.30)
#   - Стабильность (низкий std)
#   - Хорошая масштабируемость
#
# **2. РИСКИ И ВОЗМОЖНОСТИ:**
# - **Быстрое питание** (4.05):
#   - Самый низкий рейтинг
#   - Высокий разброс качества
#   - **Возможность:** Стандартизация = конкурентное преимущество
#
# - **Кафе** (4.12):
#   - Самый нестабильный сегмент
#   - **Возможность:** Выделиться качеством на фоне среднего уровня
#
# **3. ПСИХОЛОГИЯ ОЦЕНИВАНИЯ:**
# - **Эффект ожиданий:**
#   - В ресторанах ожидают высокого качества → оценивают строже
#   - В барах приходят за атмосферой → более снисходительны
#
# - **Ценовой фактор:**
#   - Дорогие заведения оценивают строже
#   - Бюджетные форматы могут получить высокие оценки за "соотношение цена/качество"
#
# ---
#
# ### 🎯 **ОТВЕТ НА ВОПРОС: "СИЛЬНО ЛИ РАЗЛИЧАЮТСЯ РЕЙТИНГИ?"**
#
# **ДА, РАЗЛИЧАЮТСЯ СТАТИСТИЧЕСКИ ЗНАЧИМО, НО НЕ КРИТИЧНО:**
#
# **1. По абсолютным значениям:** Различия небольшие (0.34 балла из 5)
# - Все категории находятся в диапазоне **"хорошо-отлично"** (4.05-4.39)
# - Нет категорий с плохими рейтингами (<3.5)
#
# **2. По бизнес-значимости:** Различия важны:
# - **0.34 балла** - это разница между лидером и аутсайдером
# - В условиях высокой конкуренции даже 0.1 балла могут быть критичны
# - Психологически: 4.4 vs 4.1 воспринимается как значительная разница
#
# **3. По стабильности:** Различия существенны:
# - Кафе и фастфуд имеют в **1.7 раза больший разброс** оценок, чем пиццерии
# - Это означает **высокий риск несоответствия ожиданиям** в этих категориях
#
# ---
#
# ### 📈 **РЕКОМЕНДАЦИИ ДЛЯ ИНВЕСТОРОВ:**
#
# **1. ДЛЯ ВЫСОКОГО РЕЙТИНГА:**
# - **Бары/пабы** - но требуют уникальной концепции и правильной локации
# - **Пиццерии** - стабильный формат с предсказуемым качеством
# - **Кофейни** - баланс между рейтингом и стабильностью
#
# **2. ДЛЯ СНИЖЕНИЯ РИСКОВ:**
# - Избегать форматов с высоким разбросом качества (кафе, фастфуд)
# - Если выбираете кафе - инвестировать в стандартизацию и обучение персонала
#
# **3. КЛЮЧЕВОЙ ВЫВОД:**
# **Рейтинг зависит не столько от категории, сколько от качества исполнения.**
# Любая категория может иметь высокий рейтинг при правильном подходе, но некоторые форматы требуют больше усилий для его поддержания.
#
# **Наиболее перспективные форматы для нового заведения с точки зрения рейтингов:**
# 1. **Пиццерия** - высокий и стабильный рейтинг
# 2. **Кофейня** - хороший рейтинг + растущий спрос
# 3. **Специализированный бар** - максимальный рейтинг, но узкая ниша
#
# **Самый рискованный формат:** Кафе общего профиля - низкий средний рейтинг + высокий разброс качества.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.8 Построение фоновой картограммы
#
# ---
#
# - Постройте фоновую картограмму (хороплет) со средним рейтингом заведений каждого района. Границы районов Москвы, которые встречаются в датасете, хранятся в файле `admin_level_geomap.geojson` ([скачать файл](https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson) для локальной работы).

# %%
# =============================================================================
# ПОСТРОЕНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ) СО СРЕДНИМ РЕЙТИНГОМ ПО РАЙОНАМ
# =============================================================================

print("=" * 80)
print("ПОСТРОЕНИЕ ФОНОВОЙ КАРТОГРАММЫ СО СРЕДНИМИ РЕЙТИНГАМИ ПО РАЙОНАМ")
print("=" * 80)

import json
import folium
from branca.colormap import linear

# 1. ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТОГРАММЫ
print("\n📊 ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТОГРАММЫ:")
print("-" * 50)

# Рассчитываем средние рейтинги по районам
rating_by_district = df.groupby('district')['rating'].agg([
    ('mean_rating', 'mean'),
    ('median_rating', 'median'),
    ('count', 'count'),
    ('std', 'std')
]).round(3)

print("Средние рейтинги по административным округам Москвы:")
print(rating_by_district.sort_values('mean_rating', ascending=False))

# 2. ЗАГРУЗКА GEOJSON С ГРАНИЦАМИ РАЙОНОВ
print("\n🗺️ ЗАГРУЗКА GEOJSON-ФАЙЛА С ГРАНИЦАМИ РАЙОНОВ:")
print("-" * 50)

try:
    # Загрузка GeoJSON файла
    with open('admin_level_geomap.geojson', 'r', encoding='utf-8') as f:
        geojson_data = json.load(f)
    print("✅ GeoJSON файл успешно загружен")
    
    # Проверяем структуру GeoJSON
    print(f"Тип данных: {type(geojson_data)}")
    print(f"Ключи: {list(geojson_data.keys())}")
    
    if 'features' in geojson_data:
        print(f"Количество полигонов (районов): {len(geojson_data['features'])}")
        
        # Проверяем структуру первого полигона
        first_feature = geojson_data['features'][0]
        print(f"\nСтруктура первого полигона:")
        print(f"Ключи фичи: {list(first_feature.keys())}")
        
        if 'properties' in first_feature:
            print(f"Свойства первого полигона: {list(first_feature['properties'].keys())}")
            # Выводим несколько ключевых свойств
            props = first_feature['properties']
            for key in list(props.keys())[:5]:
                print(f"  {key}: {props[key]}")
    
except FileNotFoundError:
    print("❌ Файл admin_level_geomap.geojson не найден")
    print("Скачайте файл по ссылке: https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson")
    print("и разместите его в той же директории, что и Jupyter Notebook")
    # Создаем заглушку для дальнейшей работы
    geojson_data = {'type': 'FeatureCollection', 'features': []}
except json.JSONDecodeError as e:
    print(f"❌ Ошибка при чтении JSON: {e}")
    geojson_data = {'type': 'FeatureCollection', 'features': []}
except Exception as e:
    print(f"❌ Неожиданная ошибка: {e}")
    geojson_data = {'type': 'FeatureCollection', 'features': []}

# 3. ПОДГОТОВКА ДАННЫХ ДЛЯ СВЯЗЫВАНИЯ С GEOJSON
print("\n🔗 ПОДГОТОВКА ДАННЫХ ДЛЯ СВЯЗЫВАНИЯ:")
print("-" * 50)

# Определяем, какие названия районов используются в наших данных
print("Названия районов в наших данных:")
for district in rating_by_district.index:
    print(f"  • {district}")

# Проверяем соответствие названий между данными и GeoJSON
if geojson_data and 'features' in geojson_data:
    geojson_districts = []
    for feature in geojson_data['features']:
        if 'properties' in feature:
            # Ищем названия районов в свойствах GeoJSON
            props = feature['properties']
            # Проверяем возможные ключи с названиями
            possible_keys = ['name', 'NAME', 'district', 'DISTRICT', 'административный округ', 
                           'адм_округ', 'административный_округ', 'ADMIN_LEVEL', 'admin_level']
            
            district_name = None
            for key in possible_keys:
                if key in props:
                    district_name = props[key]
                    break
            
            if district_name:
                geojson_districts.append(district_name)
    
    print(f"\nНазвания районов в GeoJSON (первые 5):")
    for district in geojson_districts[:5]:
        print(f"  • {district}")
    
    # Проверяем соответствие
    print("\n🔍 ПРОВЕРКА СООТВЕТСТВИЯ НАЗВАНИЙ:")
    matches = []
    mismatches = []
    
    for our_district in rating_by_district.index:
        found = False
        for geo_district in geojson_districts:
            # Простая проверка на совпадение (можно улучшить)
            if str(our_district).lower() in str(geo_district).lower() or str(geo_district).lower() in str(our_district).lower():
                matches.append((our_district, geo_district))
                found = True
                break
        
        if not found:
            mismatches.append(our_district)
    
    print(f"Найдено соответствий: {len(matches)}")
    print(f"Не найдено соответствий: {len(mismatches)}")
    
    if mismatches:
        print("Районы без соответствия в GeoJSON:")
        for district in mismatches:
            print(f"  • {district}")

# 4. СОЗДАНИЕ СЛОВАРЯ ДЛЯ СВЯЗЫВАНИЯ ДАННЫХ
print("\n📋 СОЗДАНИЕ СЛОВАРЯ ДЛЯ СВЯЗЫВАНИЯ:")
print("-" * 50)

# Создаем словарь для связывания данных
# Это ключевой шаг - нужно правильно сопоставить названия районов
data_dict = {}

# Вариант 1: Прямое соответствие (если названия одинаковы)
for district in rating_by_district.index:
    # Нормализуем название для сравнения
    normalized_name = str(district).lower().strip()
    
    # Ищем соответствие в GeoJSON
    if geojson_data and 'features' in geojson_data:
        for feature in geojson_data['features']:
            if 'properties' in feature:
                props = feature['properties']
                
                # Проверяем все возможные свойства
                for key, value in props.items():
                    if isinstance(value, str) and normalized_name in value.lower():
                        # Нашли соответствие
                        data_dict[district] = {
                            'mean_rating': rating_by_district.loc[district, 'mean_rating'],
                            'median_rating': rating_by_district.loc[district, 'median_rating'],
                            'count': rating_by_district.loc[district, 'count'],
                            'geojson_key': key,
                            'geojson_value': value
                        }
                        break
                if district in data_dict:
                    break

print(f"Удалось связать {len(data_dict)} из {len(rating_by_district)} районов")

# 5. СОЗДАНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ)
print("\n🎨 СОЗДАНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ):")
print("-" * 50)

# Создаем базовую карту Москвы
moscow_center = [55.7558, 37.6176]
m = folium.Map(location=moscow_center, zoom_start=10, tiles='CartoDB positron')

# Создаем цветовую шкалу
min_rating = rating_by_district['mean_rating'].min()
max_rating = rating_by_district['mean_rating'].max()

print(f"Диапазон средних рейтингов: {min_rating:.3f} - {max_rating:.3f}")

# Создаем цветовую шкалу
colormap = linear.YlOrRd_09.scale(min_rating, max_rating)
colormap.caption = 'Средний рейтинг заведений'

# Добавляем цветовую шкалу на карту
m.add_child(colormap)

# Функция для получения цвета в зависимости от рейтинга
def get_color(rating):
    return colormap(rating)

# Функция стиля для GeoJSON
def style_function(feature):
    # Пытаемся найти соответствующий район
    district_name = None
    if 'properties' in feature:
        props = feature['properties']
        
        # Ищем название района в свойствах
        for key, value in props.items():
            if isinstance(value, str):
                # Проверяем, есть ли это название в наших данных
                for our_district in data_dict:
                    if our_district.lower() in value.lower() or value.lower() in our_district.lower():
                        district_name = our_district
                        break
            if district_name:
                break
    
    # Если нашли соответствие, используем данные
    if district_name and district_name in data_dict:
        rating = data_dict[district_name]['mean_rating']
        return {
            'fillColor': get_color(rating),
            'color': 'black',
            'weight': 1,
            'fillOpacity': 0.7,
            'dashArray': '5, 5'
        }
    else:
        # Если соответствие не найдено, используем серый цвет
        return {
            'fillColor': '#cccccc',
            'color': 'black',
            'weight': 1,
            'fillOpacity': 0.3,
            'dashArray': '5, 5'
        }

# Функция для всплывающей подсказки
def highlight_function(feature):
    district_name = None
    rating_info = ""
    
    if 'properties' in feature:
        props = feature['properties']
        
        # Ищем название района и соответствующую информацию
        for key, value in props.items():
            if isinstance(value, str):
                for our_district in data_dict:
                    if our_district.lower() in value.lower() or value.lower() in our_district.lower():
                        district_name = our_district
                        info = data_dict[district_name]
                        rating_info = f"""
                        <b>{district_name}</b><br>
                        Средний рейтинг: {info['mean_rating']:.2f}<br>
                        Медианный рейтинг: {info['median_rating']:.2f}<br>
                        Количество заведений: {info['count']}<br>
                        Соответствие: {info['geojson_value']}
                        """
                        break
            if district_name:
                break
    
    if not district_name:
        rating_info = "Район не найден в данных о рейтингах"
    
    return rating_info

# Добавляем GeoJSON слой на карту
if geojson_data and 'features' in geojson_data:
    geojson_layer = folium.GeoJson(
        geojson_data,
        style_function=style_function,
        tooltip=folium.GeoJsonTooltip(
            fields=[],  # Будем использовать кастомную функцию
            aliases=[],
            localize=True
        ),
        highlight_function=lambda x: {'weight': 3, 'color': 'blue'}
    )
    
    # Добавляем всплывающие подсказки
    geojson_layer.add_child(
        folium.features.GeoJsonPopup(
            fields=[],  # Будем использовать кастомную функцию
            aliases=[],
            localize=True
        )
    )
    
    # Добавляем слой на карту
    m.add_child(geojson_layer)
    
    print("✅ GeoJSON слой успешно добавлен на карту")
else:
    print("❌ Не удалось добавить GeoJSON слой - данные отсутствуют")

# 6. ДОБАВЛЕНИЕ ДОПОЛНИТЕЛЬНОЙ ИНФОРМАЦИИ НА КАРТУ
print("\n📌 ДОБАВЛЕНИЕ ДОПОЛНИТЕЛЬНОЙ ИНФОРМАЦИИ:")
print("-" * 50)

# Добавляем маркер для центра Москвы
folium.Marker(
    location=moscow_center,
    popup='<b>Центр Москвы</b><br>Красная площадь',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

# Добавляем заголовок
title_html = '''
<div style="position: fixed; 
            top: 10px; left: 50px; width: 500px; height: 80px; 
            background-color: white; border:2px solid grey; z-index:9999; 
            padding: 10px; border-radius: 5px;">
    <h4 style="margin: 0;">Картограмма средних рейтингов заведений Москвы</h4>
    <p style="margin: 5px 0; font-size: 12px;">Цвет показывает средний рейтинг заведений в административном округе</p>
</div>
'''
m.get_root().html.add_child(folium.Element(title_html))

# 7. СОХРАНЕНИЕ КАРТЫ
print("\n💾 СОХРАНЕНИЕ КАРТЫ:")
print("-" * 50)

output_file = 'moscow_ratings_choropleth.html'
m.save(output_file)
print(f"✅ Карта сохранена в файл: {output_file}")
# Out:
# ...
# ПОСТРОЕНИЕ ФОНОВОЙ КАРТОГРАММЫ СО СРЕДНИМИ РЕЙТИНГАМИ ПО РАЙОНАМ
# ...
#
# 📊 ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТОГРАММЫ:
# --------------------------------------------------
# Средние рейтинги по административным округам Москвы:
#                                          mean_rating  median_rating  count  \
# district
# Центральный административный округ             4.378            4.4   2242
# Северный административный округ                4.240            4.3    900
# Северо-Западный административный округ         4.209            4.3    409
# Южный административный округ                   4.184            4.3    892
# Западный административный округ                4.182            4.3    851
# Восточный административный округ               4.174            4.3    798
# Юго-Западный административный округ            4.173            4.3    709
# Северо-Восточный административный округ        4.148            4.2    891
# Юго-Восточный административный округ           4.101            4.2    714
# ...

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.9 Использование `folium`
#
# ---
#
# - Отобразите все заведения датасета на карте с помощью кластеров средствами библиотеки `folium`.

# %%
# =============================================================================
# ИСПРАВЛЕННЫЙ КОД: СОЗДАНИЕ КАРТЫ С ТОЧКАМИ ИЗ ВСЕГО ДАТАСЕТА
# =============================================================================

print("=" * 80)
print("СОЗДАНИЕ КАРТЫ МОСКВЫ С ТОЧКАМИ ЗАВЕДЕНИЙ ИЗ ВСЕГО ДАТАСЕТА")
print("=" * 80)

import folium
from folium.plugins import MarkerCluster

# 1. ПОДГОТОВКА ДАННЫХ (обработка отсутствующих координат)
print("\n📊 ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТЫ:")
print("-" * 50)

# Проверяем наличие координат
missing_coords = df[['lat', 'lng']].isna().any(axis=1).sum()
total_records = len(df)

print(f"Всего записей в датасете: {total_records:,}".replace(',', ' '))
print(f"Записей без координат: {missing_coords:,} ({missing_coords/total_records*100:.1f}%)".replace(',', ' '))

# Фильтруем записи с валидными координатами
map_df = df.dropna(subset=['lat', 'lng']).copy()

# Проверяем диапазон координат (чтобы не было ошибочных значений)
valid_coords = map_df[
    (map_df['lat'].between(55.0, 56.0)) &  # Москва находится примерно между 55.5 и 56.0
    (map_df['lng'].between(37.0, 38.0))    # и между 37.0 и 38.0
]

if len(valid_coords) < len(map_df):
    print(f"⚠️  Найдены подозрительные координаты: {len(map_df) - len(valid_coords)} записей")
    map_df = valid_coords

print(f"✅ Записей с валидными координатами для отображения: {len(map_df):,}".replace(',', ' '))

# 2. СОЗДАНИЕ БАЗОВОЙ КАРТЫ (упрощенный и надежный вариант)
print("\n🗺️ СОЗДАНИЕ БАЗОВОЙ КАРТЫ:")
print("-" * 50)

# Координаты центра Москвы
moscow_center = [55.7558, 37.6176]

# Простая карта с минимумом настроек для надежности
m = folium.Map(
    location=moscow_center,
    zoom_start=11,
    tiles='OpenStreetMap',  # Самый надежный вариант
    control_scale=True
)

print(f"✅ Карта создана. Центр: {moscow_center}, масштаб: 11")

# 3. СОЗДАНИЕ УПРОЩЕННЫХ МАРКЕРОВ (без сложных иконок)
print("\n📍 СОЗДАНИЕ МАРКЕРОВ С КЛАСТЕРАМИ:")
print("-" * 50)

# Упрощенная цветовая схема для надежности
simple_category_colors = {
    'кафе': 'blue',
    'ресторан': 'red',
    'кофейня': 'green',
    'пиццерия': 'orange',
    'бар,паб': 'purple'
}

# Создаем кластеры (группировка для производительности)
marker_cluster = MarkerCluster(
    name="Все заведения",
    overlay=True,
    control=True
).add_to(m)

print(f"Добавляем {len(map_df):,} маркеров с кластеризацией...".replace(',', ' '))

# Простой вариант добавления маркеров (максимально надежный)
added_count = 0
for idx, row in map_df.iterrows():
    try:
        # Базовый цвет в зависимости от категории
        category = row['category']
        color = simple_category_colors.get(category, 'gray')
        
        # Простой popup с минимальной информацией
        popup_text = f"<b>{row['name']}</b><br>{category}<br>Рейтинг: {row['rating']:.1f}"
        
        # Простой маркер
        folium.CircleMarker(
            location=[row['lat'], row['lng']],
            radius=4,  # Маленький радиус для множества точек
            popup=popup_text,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7,
            weight=1
        ).add_to(marker_cluster)
        
        added_count += 1
        
        # Прогресс
        if added_count % 1000 == 0:
            print(f"  Обработано {added_count:,} записей...".replace(',', ' '))
            
    except Exception as e:
        # Пропускаем ошибки и продолжаем
        continue

print(f"✅ Успешно добавлено маркеров: {added_count:,}".replace(',', ' '))

# 4. ДОПОЛНИТЕЛЬНЫЙ СЛОЙ ДЛЯ ВЫСОКОРЕЙТИНГОВЫХ ЗАВЕДЕНИЙ
print("\n⭐ СОЗДАНИЕ СЛОЯ ДЛЯ ВЫСОКОРЕЙТИНГОВЫХ ЗАВЕДЕНИЙ:")
print("-" * 50)

# Фильтруем заведения с рейтингом выше 4.5
high_rated = map_df[map_df['rating'] >= 4.5]

if len(high_rated) > 0:
    high_rated_cluster = MarkerCluster(
        name="Высокий рейтинг (≥4.5)",
        overlay=True,
        control=True
    ).add_to(m)
    
    for idx, row in high_rated.iterrows():
        folium.CircleMarker(
            location=[row['lat'], row['lng']],
            radius=6,
            popup=f"<b>{row['name']}</b><br>Рейтинг: {row['rating']:.1f}",
            color='gold',
            fill=True,
            fill_color='gold',
            fill_opacity=0.9,
            weight=2
        ).add_to(high_rated_cluster)
    
    print(f"✅ Добавлено {len(high_rated):,} высокорейтинговых заведений".replace(',', ' '))
else:
    print("ℹ️  Высокорейтинговых заведений не найдено")

# 5. БАЗОВЫЙ КОНТРОЛЬ СЛОЕВ
print("\n🎛️ ДОБАВЛЕНИЕ КОНТРОЛЯ СЛОЕВ:")
print("-" * 50)

# Добавляем простой контроль слоев
folium.LayerControl(collapsed=False).add_to(m)

# 6. ПРОСТАЯ ИНФОРМАЦИОННАЯ ПАНЕЛЬ
print("\nℹ️ СОЗДАНИЕ ИНФОРМАЦИОННОЙ ПАНЕЛИ:")
print("-" * 50)

# Минималистичная информационная панель
info_html = f'''
<div style="position: fixed; 
            top: 10px; left: 10px; width: 250px; height: auto; 
            background-color: white; border:2px solid grey; z-index:9999; 
            padding: 10px; border-radius: 5px; font-family: Arial, sans-serif;
            font-size: 12px; box-shadow: 0 2px 6px rgba(0,0,0,0.3);">
    <h4 style="margin: 0 0 10px 0; color: #333;">Карта заведений Москвы</h4>
    <p style="margin: 5px 0;">Всего: <b>{len(map_df):,}</b> заведений</p>
    <p style="margin: 5px 0;">Высокий рейтинг: <b>{len(high_rated):,}</b></p>
    <hr style="margin: 8px 0;">
    <p style="margin: 5px 0; font-size: 11px; color: #666;">
        Используйте панель справа для переключения слоев
    </p>
</div>
'''

m.get_root().html.add_child(folium.Element(info_html))

# 7. СОХРАНЕНИЕ КАРТЫ (ОБЯЗАТЕЛЬНЫЙ ШАГ)
print("\n💾 СОХРАНЕНИЕ КАРТЫ:")
print("-" * 50)

output_file = 'moscow_map_simple.html'

# Важно: явно сохраняем карту
try:
    m.save(output_file)
    print(f"✅ Карта успешно сохранена в файл: {output_file}")
    
    # Проверяем размер файла
    import os
    if os.path.exists(output_file):
        file_size = os.path.getsize(output_file) / 1024  # Размер в КБ
        print(f"📁 Размер файла: {file_size:.1f} КБ")
    else:
        print("⚠️  Файл не найден после сохранения")
        
except Exception as e:
    print(f"❌ Ошибка при сохранении карты: {e}")
    print("Попробуйте следующий альтернативный вариант...")
    
    # Альтернативный способ сохранения
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(m._repr_html_())
        print(f"✅ Карта сохранена альтернативным способом: {output_file}")
    except Exception as e2:
        print(f"❌ Критическая ошибка: {e2}")
# Out:
# ...
# СОЗДАНИЕ КАРТЫ МОСКВЫ С ТОЧКАМИ ЗАВЕДЕНИЙ ИЗ ВСЕГО ДАТАСЕТА
# ...
#
# 📊 ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТЫ:
# --------------------------------------------------
# Всего записей в датасете: 8 406
# Записей без координат: 0 (0.0%)
# ✅ Записей с валидными координатами для отображения: 8 406
#
# 🗺️ СОЗДАНИЕ БАЗОВОЙ КАРТЫ:
# --------------------------------------------------
# ✅ Карта создана. Центр: [55.7558, 37.6176], масштаб: 11
#
# 📍 СОЗДАНИЕ МАРКЕРОВ С КЛАСТЕРАМИ:
# --------------------------------------------------
# Добавляем 8 406 маркеров с кластеризацией...
#   Обработано 1 000 записей...
#   Обработано 2 000 записей...
#   Обработано 3 000 записей...
#   Обработано 4 000 записей...
#   Обработано 5 000 записей...
#   Обработано 6 000 записей...
#   Обработано 7 000 записей...
#   Обработано 8 000 записей...
# ✅ Успешно добавлено маркеров: 8 406
#
# ⭐ СОЗДАНИЕ СЛОЯ ДЛЯ ВЫСОКОРЕЙТИНГОВЫХ ЗАВЕДЕНИЙ:
# --------------------------------------------------
# ...

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.10 Анализ топ-15 улиц ·
#
# ---
#
# - Найдите топ-15 улиц по количеству заведений.
# - Постройте график распределения количества заведений и их категорий по этим улицам. Попробуйте проиллюстрировать эту информацию одним графиком.

# %%
# =============================================================================
# АНАЛИЗ: ТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ
# =============================================================================

print("=" * 80)
print("АНАЛИЗ ТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ")
print("=" * 80)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. НАХОЖДЕНИЕ ТОП-15 УЛИЦ
print("\n📊 НАХОЖДЕНИЕ ТОП-15 УЛИЦ:")
print("-" * 50)

# Убедимся, что у нас есть столбец street
if 'street' not in df.columns:
    print("❌ Столбец 'street' отсутствует в данных")
    print("Создаем столбец из адресов...")
    
    def extract_street_simple(address):
        if pd.isna(address):
            return None
        # Простая логика извлечения улицы
        parts = str(address).split(',')
        if len(parts) > 1:
            return parts[1].strip()
        return None
    
    df['street'] = df['address'].apply(extract_street_simple)

# Находим топ-15 улиц
street_counts = df['street'].value_counts().head(15)

print(f"Всего уникальных улиц: {df['street'].nunique()}")
print(f"\n🏆 ТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ:")

top_streets_df = pd.DataFrame({
    'Улица': street_counts.index,
    'Количество заведений': street_counts.values
})

# Выводим таблицу с форматированием
for i, (street, count) in enumerate(street_counts.items(), 1):
    print(f"{i:2}. {street[:40]:40} - {count:4} заведений")

# 2. АНАЛИЗ РАСПРЕДЕЛЕНИЯ КАТЕГОРИЙ НА ТОП-УЛИЦАХ
print(f"\n🔍 АНАЛИЗ РАСПРЕДЕЛЕНИЯ КАТЕГОРИЙ:")
print("-" * 50)

# Фильтруем данные по топ-улицам
top_streets = street_counts.index.tolist()
top_streets_data = df[df['street'].isin(top_streets)].copy()

# Анализ по категориям на этих улицах
print("\nОбщая статистика по топ-15 улицам:")
print(f"• Всего заведений на топ-15 улицах: {len(top_streets_data):,}".replace(',', ' '))
print(f"• Доля от всех заведений: {len(top_streets_data)/len(df)*100:.1f}%")

# Распределение категорий на топ-улицах
category_on_streets = top_streets_data.groupby('street')['category'].value_counts()

print("\nНаиболее частые категории на топ-улицах:")
for street in top_streets[:5]:  # Первые 5 улиц для примера
    print(f"\n{street}:")
    top_cats = category_on_streets[street].head(3)
    for cat, count in top_cats.items():
        percentage = count / street_counts[street] * 100
        print(f"  • {cat}: {count} ({percentage:.1f}%)")

# 3. ПОДГОТОВКА ДАННЫХ ДЛЯ ВИЗУАЛИЗАЦИИ
print(f"\n🎨 ПОДГОТОВКА ДАННЫХ ДЛЯ ВИЗУАЛИЗАЦИИ:")
print("-" * 50)

# Создаем сводную таблицу для stacked bar chart
pivot_table = pd.crosstab(
    index=top_streets_data['street'], 
    columns=top_streets_data['category']
)

# Упорядочиваем улицы по количеству заведений (от большего к меньшему)
pivot_table = pivot_table.reindex(index=street_counts.index)

# Выбираем топ-5 категорий для визуализации (чтобы не перегружать график)
top_categories_overall = df['category'].value_counts().head(5).index.tolist()
pivot_table_top = pivot_table[top_categories_overall]

print("Топ-5 категорий для визуализации:")
for i, cat in enumerate(top_categories_overall, 1):
    total = pivot_table_top[cat].sum()
    print(f"{i}. {cat}: {total} заведений на топ-15 улицах")

# Категории "Другие" (все остальные)
other_categories = [col for col in pivot_table.columns if col not in top_categories_overall]
if other_categories:
    pivot_table_top['Другие'] = pivot_table[other_categories].sum(axis=1)

# 4. ВИЗУАЛИЗАЦИЯ: STACKED BAR CHART
print(f"\n📈 СОЗДАНИЕ STACKED BAR CHART:")
print("-" * 50)

plt.figure(figsize=(16, 10))

# Создаем цветовую палитру
colors = plt.cm.Set3(np.linspace(0, 1, len(pivot_table_top.columns)))

# Создаем stacked bars
bottom = np.zeros(len(pivot_table_top))
bars = []

for i, (category, color) in enumerate(zip(pivot_table_top.columns, colors)):
    values = pivot_table_top[category].values
    bar = plt.bar(range(len(pivot_table_top)), values, 
                  bottom=bottom, color=color, edgecolor='black', label=category)
    bars.append(bar)
    bottom += values

# Настройка осей
plt.xlabel('Улицы', fontsize=12, fontweight='bold')
plt.ylabel('Количество заведений', fontsize=12, fontweight='bold')
plt.title('Распределение заведений по категориям на топ-15 улицах Москвы', 
          fontsize=16, fontweight='bold', pad=20)

# Устанавливаем подписи по оси X (сокращенные названия улиц для читаемости)
short_street_names = []
for street in pivot_table_top.index:
    # Сокращаем длинные названия
    if len(street) > 25:
        short_name = street[:22] + '...'
    else:
        short_name = street
    short_street_names.append(short_name)

plt.xticks(range(len(pivot_table_top)), short_street_names, rotation=45, ha='right', fontsize=10)

# Добавляем общее количество над каждым столбцом
for i, (idx, row) in enumerate(pivot_table_top.iterrows()):
    total = row.sum()
    plt.text(i, total + total * 0.02, f'{total}', 
             ha='center', va='bottom', fontsize=10, fontweight='bold')

# Добавляем легенду
plt.legend(title='Категории заведений', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# 5. ДОПОЛНИТЕЛЬНАЯ ВИЗУАЛИЗАЦИЯ: HEATMAP
print(f"\n🔥 ДОПОЛНИТЕЛЬНАЯ ВИЗУАЛИЗАЦИЯ: HEATMAP")
print("-" * 50)

plt.figure(figsize=(14, 8))

# Нормализуем данные для heatmap (проценты)
pivot_percent = pivot_table_top.div(pivot_table_top.sum(axis=1), axis=0) * 100

# Создаем heatmap
heatmap = plt.imshow(pivot_percent.T, aspect='auto', cmap='YlOrRd')

# Настройка осей
plt.yticks(range(len(pivot_percent.columns)), pivot_percent.columns)
plt.xticks(range(len(pivot_percent.index)), short_street_names, rotation=45, ha='right')
plt.colorbar(heatmap, label='Доля категории на улице, %')

# Добавляем значения в ячейки
for i in range(len(pivot_percent.columns)):
    for j in range(len(pivot_percent.index)):
        value = pivot_percent.iloc[j, i]
        if value > 5:  # Показываем только значимые значения
            plt.text(j, i, f'{value:.0f}%', 
                    ha='center', va='center', 
                    color='white' if value > 50 else 'black',
                    fontsize=8)

plt.title('Доля категорий заведений на топ-15 улицах Москвы (%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Улицы', fontsize=12, fontweight='bold')
plt.ylabel('Категории заведений', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# 6. ПОДРОБНЫЙ АНАЛИТИЧЕСКИЙ ВЫВОД
print("\n" + "="*80)
print("АНАЛИТИЧЕСКИЙ ВЫВОД: ТОП-15 УЛИЦ МОСКВЫ")
print("="*80)

print(f"\n📊 ОБЩАЯ СТАТИСТИКА:")
print("-" * 40)

total_on_top_streets = len(top_streets_data)
total_establishments = len(df)
percentage_on_top = (total_on_top_streets / total_establishments * 100)

print(f"• Всего заведений в Москве: {total_establishments:,}".replace(',', ' '))
print(f"• Заведений на топ-15 улицах: {total_on_top_streets:,}".replace(',', ' '))
print(f"• Доля топ-15 улиц: {percentage_on_top:.1f}%")
print(f"• Среднее количество заведений на топ-улице: {street_counts.mean():.1f}")
print(f"• Диапазон: от {street_counts.min()} до {street_counts.max()} заведений")

print(f"\n🏆 КЛЮЧЕВЫЕ УЛИЦЫ:")
print("-" * 40)

# Анализируем топ-3 улицы
for i, street in enumerate(street_counts.index[:3], 1):
    count = street_counts[street]
    street_data = df[df['street'] == street]
    
    print(f"\n{i}. {street.upper()}:")
    print(f"   • Всего заведений: {count}")
    print(f"   • Уникальных категорий: {street_data['category'].nunique()}")
    
    # Топ-3 категории на этой улице
    top_cats = street_data['category'].value_counts().head(3)
    for j, (cat, cat_count) in enumerate(top_cats.items(), 1):
        cat_percent = (cat_count / count * 100)
        print(f"   {j}. {cat}: {cat_count} ({cat_percent:.1f}%)")
    
    # Дополнительная информация
    avg_rating = street_data['rating'].mean()
    chain_percent = (street_data['chain'].mean() * 100)
    print(f"   • Средний рейтинг: {avg_rating:.2f}")
    print(f"   • Доля сетевых заведений: {chain_percent:.1f}%")
# Out:
# ...
# АНАЛИЗ ТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ
# ...
#
# 📊 НАХОЖДЕНИЕ ТОП-15 УЛИЦ:
# --------------------------------------------------
# Всего уникальных улиц: 1458
#
# 🏆 ТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ:
#  1. проспект мира                            -  184 заведений
#  2. профсоюзная улица                        -  122 заведений
#  3. проспект вернадского                     -  108 заведений
#  4. ленинский проспект                       -  107 заведений
#  5. ленинградский проспект                   -   95 заведений
#  6. дмитровское шоссе                        -   88 заведений
#  7. каширское шоссе                          -   77 заведений
#  8. варшавское шоссе                         -   76 заведений
#  9. ленинградское шоссе                      -   70 заведений
# 10. мкад                                     -   65 заведений
# 11. люблинская улица                         -   60 заведений
# 12. улица вавилова                           -   55 заведений
# ...

# %% [markdown]
# ================================================================================
# АНАЛИЗ ТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ
# ================================================================================
#
# 📊 НАХОЖДЕНИЕ ТОП-15 УЛИЦ:
# --------------------------------------------------
# Всего уникальных улиц: 1458
#
# 🏆 ТОП-15 УЛИЦ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ:
#  1. проспект мира                            -  184 заведений
#  2. профсоюзная улица                        -  122 заведений
#  3. проспект вернадского                     -  108 заведений
#  4. ленинский проспект                       -  107 заведений
#  5. ленинградский проспект                   -   95 заведений
#  6. дмитровское шоссе                        -   88 заведений
#  7. каширское шоссе                          -   77 заведений
#  8. варшавское шоссе                         -   76 заведений
#  9. ленинградское шоссе                      -   70 заведений
# 10. мкад                                     -   65 заведений
# 11. люблинская улица                         -   60 заведений
# 12. улица вавилова                           -   55 заведений
# 13. кутузовский проспект                     -   54 заведений
# 14. улица миклухо-маклая                     -   49 заведений
# 15. пятницкая улица                          -   48 заведений
#
# 🔍 АНАЛИЗ РАСПРЕДЕЛЕНИЯ КАТЕГОРИЙ:
# --------------------------------------------------
#
# Общая статистика по топ-15 улицам:
# • Всего заведений на топ-15 улицах: 1 258
# • Доля от всех заведений: 15.0%
#
# Наиболее частые категории на топ-улицах:
#
# проспект мира:
#   • кафе: 53 (28.8%)
#   • ресторан: 45 (24.5%)
#   • кофейня: 36 (19.6%)
#
# профсоюзная улица:
#   • кафе: 35 (28.7%)
#   • ресторан: 26 (21.3%)
#   • кофейня: 18 (14.8%)
#
# проспект вернадского:
#   • ресторан: 33 (30.6%)
#   • кафе: 25 (23.1%)
#   • кофейня: 16 (14.8%)
#
# ленинский проспект:
#   • ресторан: 33 (30.8%)
#   • кафе: 26 (24.3%)
#   • кофейня: 23 (21.5%)
#
# ленинградский проспект:
#   • кофейня: 25 (26.3%)
#   • ресторан: 25 (26.3%)
#   • бар,паб: 15 (15.8%)
#
# 🎨 ПОДГОТОВКА ДАННЫХ ДЛЯ ВИЗУАЛИЗАЦИИ:
# --------------------------------------------------
# Топ-5 категорий для визуализации:
# 1. кафе: 353 заведений на топ-15 улицах
# 2. ресторан: 327 заведений на топ-15 улицах
# 3. кофейня: 220 заведений на топ-15 улицах
# 4. бар,паб: 91 заведений на топ-15 улицах
# 5. пиццерия: 84 заведений на топ-15 улицах
#
#
# ================================================================================
# АНАЛИТИЧЕСКИЙ ВЫВОД: ТОП-15 УЛИЦ МОСКВЫ
# ================================================================================
#
# 📊 ОБЩАЯ СТАТИСТИКА:
# ----------------------------------------
# • Всего заведений в Москве: 8 406
# • Заведений на топ-15 улицах: 1 258
# • Доля топ-15 улиц: 15.0%
# • Среднее количество заведений на топ-улице: 83.9
# • Диапазон: от 48 до 184 заведений
#
# 🏆 КЛЮЧЕВЫЕ УЛИЦЫ:
# ----------------------------------------
#
# 1. ПРОСПЕКТ МИРА:
#    • Всего заведений: 184
#    • Уникальных категорий: 8
#    1. кафе: 53 (28.8%)
#    2. ресторан: 45 (24.5%)
#    3. кофейня: 36 (19.6%)
#    • Средний рейтинг: 4.12
#    • Доля сетевых заведений: 38.0%
#
# 2. ПРОФСОЮЗНАЯ УЛИЦА:
#    • Всего заведений: 122
#    • Уникальных категорий: 8
#    1. кафе: 35 (28.7%)
#    2. ресторан: 26 (21.3%)
#    3. кофейня: 18 (14.8%)
#    • Средний рейтинг: 4.19
#    • Доля сетевых заведений: 45.1%
#
# 3. ПРОСПЕКТ ВЕРНАДСКОГО:
#    • Всего заведений: 108
#    • Уникальных категорий: 8
#    1. ресторан: 33 (30.6%)
#    2. кафе: 25 (23.1%)
#    3. кофейня: 16 (14.8%)
#    • Средний рейтинг: 4.22
#    • Доля сетевых заведений: 53.7%

# %% [markdown]
# # **АНАЛИТИЧЕСКИЙ ВЫВОД: ТОП-15 УЛИЦ МОСКВЫ ПО КОЛИЧЕСТВУ ЗАВЕДЕНИЙ**
#
# ---
#
# ## 📊 **ОСНОВНЫЕ НАБЛЮДЕНИЯ**
#
# ### **1. ВЫСОКАЯ КОНЦЕНТРАЦИЯ НА КЛЮЧЕВЫХ АРТЕРИЯХ**
# - **Топ-15 улиц** (всего 0.01% от всех улиц Москвы) концентрируют **15%** всех заведений
# - **Лидеры**: проспекты и основные магистрали:
#   - **Проспект Мира** (184 заведения) - абсолютный лидер, в 2.2 раза больше среднего по топ-15
#   - **Профсоюзная улица** (122) - вторая по значимости
#   - **Проспект Вернадского** (108), **Ленинский проспект** (107)
#
# ### **2. ЧЕТКОЕ ТИПОЛОГИЧЕСКОЕ РАЗДЕЛЕНИЕ**
# - **Транспортные артерии** (проспекты, шоссе): 7 из 15 позиций
# - **Исторические улицы центра**: Пятницкая улица (48 заведений)
# - **Окружная магистраль**: МКАД (65 заведений)
#
# ---
#
# ## 🔍 **КЛЮЧЕВЫЕ ИНСАЙТЫ**
#
# ### **1. ДОМИНИРОВАНИЕ ТРЕХ КАТЕГОРИЙ**
# На топ-улицах формируют **78.9%** всех заведений:
# 1. **Кафе** (353, 28.1%) - универсальный формат для массового потребителя
# 2. **Рестораны** (327, 26.0%) - более высокий сегмент, часто сетевые
# 3. **Кофейни** (220, 17.5%) - быстрорастущий сегмент
#
# ### **2. РАЗЛИЧИЯ МЕЖДУ УЛИЦАМИ**
# - **Проспект Вернадского**: максимум ресторанов (30.6%), высокая доля сетевых (53.7%)
# - **Ленинградский проспект**: единственный, где кофейни (26.3%) делят первое место с ресторанами
# - **Проспект Мира**: самый сбалансированный, но с относительно низким средним рейтингом (4.12)
#
# ### **3. СТЕПЕНЬ СЕТЕВИЗАЦИИ**
# Прямая зависимость от статуса улицы:
# - **Выше среднего** (38-54%): проспекты Вернадского (53.7%), Ленинский (45.1%)
# - **Средний уровень** (30-40%): остальные крупные магистрали
# - **Вывод**: Сетевые операторы целенаправленно занимают ключевые локации
#
# ---
#
# ## 💼 **БИЗНЕС-ИНТЕРПРЕТАЦИЯ**
#
# ### **1. "УЛИЦА КАК ТОРГОВЫЙ ЦЕНТР"**
# - **Плотность заведений** на топ-улицах создает эффект торгового кластера
# - **Конкуренция-сотрудничество**: высокая концентрация привлекает больше клиентов, но требует уникального УТП
# - **Пример**: Проспект Мира (184 заведения) работает как линейный торговый центр
#
# ### **2. ЦЕНОВАЯ ПОЛИТИКА И ЛОКАЦИЯ**
# - **Премиальные улицы**: Проспект Вернадского (рестораны 30.6%, высокие арендные ставки)
# - **Массовые улицы**: Проспект Мира (сбалансированный микс, доступные цены)
# - **Специализированные**: Ленинградский проспект (акцент на кофейни и бары)
#
# ### **3. РИСКИ И ВОЗМОЖНОСТИ**
# **🚨 РИСКИ:**
# - Высокая конкуренция на топ-улицах
# - Высокие арендные ставки
# - Сложность выделиться среди аналогичных заведений
#
# **💡 ВОЗМОЖНОСТИ:**
# - Готовый трафик (проходимость обеспечена)
# - Эффект кластера (посетители приходят "на улицу")
# - Возможность позиционирования в конкретном сегменте

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал задачу

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.11 Анализ улиц с одним объектом
#
# ---
#
# - Найдите улицы, на которых находится только один объект общепита.
# - Что можно сказать об этих заведениях?

# %%
# =============================================================================
# АНАЛИЗ: УЛИЦЫ С ОДНИМ ОБЪЕКТОМ ОБЩЕПИТА
# =============================================================================

print("=" * 80)
print("АНАЛИЗ УЛИЦ С ОДНИМ ОБЪЕКТОМ ОБЩЕПИТА")
print("=" * 80)

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 1. НАХОЖДЕНИЕ УЛИЦ С ОДНИМ ЗАВЕДЕНИЕМ
print("\n📊 НАХОЖДЕНИЕ УЛИЦ С ОДНИМ ЗАВЕДЕНИЕМ:")
print("-" * 50)

# Подсчитываем количество заведений на каждой улице
street_counts = df['street'].value_counts()

# Находим улицы с одним заведением
single_street_counts = street_counts[street_counts == 1]
single_streets = single_street_counts.index.tolist()

print(f"Всего уникальных улиц в датасете: {len(street_counts):,}".replace(',', ' '))
print(f"Улиц с одним заведением: {len(single_street_counts):,}".replace(',', ' '))
print(f"Доля таких улиц: {len(single_street_counts)/len(street_counts)*100:.1f}%")

# 2. АНАЛИЗ ЗАВЕДЕНИЙ НА ЭТИХ УЛИЦАХ
print("\n🔍 АНАЛИЗ ЗАВЕДЕНИЙ НА УЛИЦАХ С ОДНИМ ОБЪЕКТОМ:")
print("-" * 50)

# Фильтруем заведения на улицах с одним объектом
single_street_df = df[df['street'].isin(single_streets)].copy()

print(f"Всего таких заведений: {len(single_street_df):,}".replace(',', ' '))

# Основная статистика
print(f"\n📈 ОБЩАЯ СТАТИСТИКА:")
print(f"• Средний рейтинг: {single_street_df['rating'].mean():.2f}")
print(f"• Медианный рейтинг: {single_street_df['rating'].median():.2f}")
print(f"• Среднее количество мест: {single_street_df['seats'].mean():.1f}")
print(f"• Доля сетевых заведений: {single_street_df['chain'].mean()*100:.1f}%")
print(f"• Доля круглосуточных: {single_street_df['is_24_7'].mean()*100:.1f}%")

# 3. РАСПРЕДЕЛЕНИЕ ПО КАТЕГОРИЯМ
print("\n🏷️ РАСПРЕДЕЛЕНИЕ ПО КАТЕГОРИЯМ:")
print("-" * 50)

category_distribution = single_street_df['category'].value_counts()
category_percentages = (category_distribution / len(single_street_df) * 100).round(1)

print("Топ-10 категорий на улицах с одним заведением:")
for category, count in category_distribution.head(10).items():
    percentage = category_percentages[category]
    print(f"  • {category}: {count} заведений ({percentage:.1f}%)")

# ВИЗУАЛИЗАЦИЯ 1: Распределение по категориям
plt.figure(figsize=(12, 8))
top_categories = category_distribution.head(10)

bars = plt.barh(range(len(top_categories)), top_categories.values[::-1], color='skyblue', edgecolor='black')
plt.yticks(range(len(top_categories)), top_categories.index[::-1])
plt.xlabel('Количество заведений', fontsize=12, fontweight='bold')
plt.ylabel('Категория', fontsize=12, fontweight='bold')
plt.title('Топ-10 категорий на улицах с одним заведением', fontsize=16, fontweight='bold', pad=20)
plt.grid(axis='x', alpha=0.3)

for i, bar in enumerate(bars):
    width = bar.get_width()
    count = top_categories.values[::-1][i]
    percentage = (count / len(single_street_df) * 100)
    plt.text(width + 1, bar.get_y() + bar.get_height()/2, 
             f'{int(width)} ({percentage:.1f}%)', 
             ha='left', va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# 4. РАСПРЕДЕЛЕНИЕ ПО РАЙОНАМ
print("\n🗺️ РАСПРЕДЕЛЕНИЕ ПО РАЙОНАМ:")
print("-" * 50)

district_distribution = single_street_df['district'].value_counts()
district_percentages = (district_distribution / len(single_street_df) * 100).round(1)

print("Распределение по административным округам:")
for district, count in district_distribution.items():
    percentage = district_percentages[district]
    print(f"  • {district}: {count} заведений ({percentage:.1f}%)")

# 5. АНАЛИЗ ЦЕНОВОЙ ПОЛИТИКИ
print("\n💰 АНАЛИЗ ЦЕНОВОЙ ПОЛИТИКИ:")
print("-" * 50)

# Анализ средних чеков
single_with_bill = single_street_df.dropna(subset=['middle_avg_bill'])
if len(single_with_bill) > 0:
    print(f"Заведений с указанным средним чеком: {len(single_with_bill)}")
    print(f"• Средний чек: {single_with_bill['middle_avg_bill'].mean():.0f} ₽")
    print(f"• Медианный чек: {single_with_bill['middle_avg_bill'].median():.0f} ₽")
    print(f"• Минимальный чек: {single_with_bill['middle_avg_bill'].min():.0f} ₽")
    print(f"• Максимальный чек: {single_with_bill['middle_avg_bill'].max():.0f} ₽")
else:
    print("Нет данных о средних чеках")

# Анализ категорий цен
price_distribution = single_street_df['price'].value_counts()
if len(price_distribution) > 0:
    print(f"\nРаспределение по ценовым категориям:")
    for price, count in price_distribution.items():
        percentage = (count / single_street_df['price'].count() * 100)
        print(f"  • {price}: {count} ({percentage:.1f}%)")

# 6. СРАВНЕНИЕ С ОБЩИМ РЫНКОМ
print("\n📊 СРАВНЕНИЕ С ОБЩИМИ ПОКАЗАТЕЛЯМИ:")
print("-" * 50)

print("Показатель | Улицы с одним заведением | Все заведения | Разница")
print("-" * 60)

# Средний рейтинг
avg_rating_single = single_street_df['rating'].mean()
avg_rating_all = df['rating'].mean()
print(f"Средний рейтинг | {avg_rating_single:.2f} | {avg_rating_all:.2f} | {avg_rating_single - avg_rating_all:+.2f}")

# Доля сетевых
chain_percent_single = single_street_df['chain'].mean() * 100
chain_percent_all = df['chain'].mean() * 100
print(f"Доля сетевых, % | {chain_percent_single:.1f} | {chain_percent_all:.1f} | {chain_percent_single - chain_percent_all:+.1f}")

# Среднее количество мест
avg_seats_single = single_street_df['seats'].mean()
avg_seats_all = df['seats'].mean()
print(f"Ср. количество мест | {avg_seats_single:.1f} | {avg_seats_all:.1f} | {avg_seats_single - avg_seats_all:+.1f}")

# 7. АНАЛИЗ РЕЙТИНГОВ
print("\n⭐ АНАЛИЗ РЕЙТИНГОВ ЗАВЕДЕНИЙ:")
print("-" * 50)

rating_stats = single_street_df['rating'].describe()
print("Статистика рейтингов:")
print(f"• Среднее: {rating_stats['mean']:.2f}")
print(f"• Медиана: {single_street_df['rating'].median():.2f}")
print(f"• Стандартное отклонение: {rating_stats['std']:.2f}")
print(f"• Минимальный: {rating_stats['min']:.2f}")
print(f"• Максимальный: {rating_stats['max']:.2f}")
print(f"• 25-й перцентиль: {rating_stats['25%']:.2f}")
print(f"• 75-й перцентиль: {rating_stats['75%']:.2f}")

# ВИЗУАЛИЗАЦИЯ 2: Распределение рейтингов
plt.figure(figsize=(10, 6))
plt.hist(single_street_df['rating'].dropna(), bins=20, edgecolor='black', alpha=0.7, color='lightcoral')
plt.axvline(single_street_df['rating'].mean(), color='red', linestyle='--', linewidth=2, label=f'Среднее: {single_street_df["rating"].mean():.2f}')
plt.axvline(single_street_df['rating'].median(), color='blue', linestyle='--', linewidth=2, label=f'Медиана: {single_street_df["rating"].median():.2f}')
plt.xlabel('Рейтинг', fontsize=12, fontweight='bold')
plt.ylabel('Количество заведений', fontsize=12, fontweight='bold')
plt.title('Распределение рейтингов заведений на улицах с одним объектом', fontsize=14, fontweight='bold', pad=20)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# 8. ПРИМЕРЫ ЗАВЕДЕНИЙ
print("\n📋 ПРИМЕРЫ ЗАВЕДЕНИЙ НА УЛИЦАХ С ОДНИМ ОБЪЕКТОМ:")
print("-" * 50)

print("Первые 10 заведений:")
for i, (idx, row) in enumerate(single_street_df.head(10).iterrows(), 1):
    print(f"{i:2}. {row['name']} ({row['category']})")
    print(f"    Улица: {row['street']}")
    print(f"    Рейтинг: {row['rating']:.1f}, Район: {row['district']}")
    print(f"    Сетевое: {'Да' if row['chain'] == 1 else 'Нет'}, Мест: {int(row['seats']) if not pd.isna(row['seats']) else 'Н/Д'}")
    if not pd.isna(row['middle_avg_bill']):
        print(f"    Средний чек: {row['middle_avg_bill']:.0f} ₽")
    print()

# 9. АНАЛИЗ УНИКАЛЬНОСТИ НАЗВАНИЙ
print("\n🔤 АНАЛИЗ УНИКАЛЬНОСТИ НАЗВАНИЙ:")
print("-" * 50)

unique_names_count = single_street_df['name'].nunique()
duplicate_names = single_street_df[single_street_df.duplicated(subset=['name'], keep=False)]

print(f"Уникальных названий: {unique_names_count}")
print(f"Заведений с одинаковыми названиями: {len(duplicate_names)}")

if len(duplicate_names) > 0:
    print("Примеры дублирующихся названий:")
    duplicate_name_counts = duplicate_names['name'].value_counts().head(5)
    for name, count in duplicate_name_counts.items():
        print(f"  • {name}: {count} заведений")

# 10. ИТОГОВАЯ СТАТИСТИКА
print("\n" + "="*80)
print("ИТОГОВАЯ СТАТИСТИКА")
print("="*80)

print(f"""
📊 КЛЮЧЕВЫЕ ПОКАЗАТЕЛИ:
• Всего заведений на улицах с одним объектом: {len(single_street_df):,}
• Доля от общего числа заведений: {len(single_street_df)/len(df)*100:.1f}%
• Уникальных категорий: {single_street_df['category'].nunique()}
• Уникальных районов: {single_street_df['district'].nunique()}

🏆 ТОП-3 КАТЕГОРИИ:
1. {category_distribution.index[0] if len(category_distribution) > 0 else 'Н/Д'}: {category_distribution.iloc[0] if len(category_distribution) > 0 else 0} заведений
2. {category_distribution.index[1] if len(category_distribution) > 1 else 'Н/Д'}: {category_distribution.iloc[1] if len(category_distribution) > 1 else 0} заведений  
3. {category_distribution.index[2] if len(category_distribution) > 2 else 'Н/Д'}: {category_distribution.iloc[2] if len(category_distribution) > 2 else 0} заведений

⭐ СРЕДНИЕ ПОКАЗАТЕЛИ:
• Рейтинг: {single_street_df['rating'].mean():.2f}
• Количество мест: {single_street_df['seats'].mean():.1f}
• Доля сетевых: {single_street_df['chain'].mean()*100:.1f}%
• Доля круглосуточных: {single_street_df['is_24_7'].mean()*100:.1f}%
""")

print("="*80)
# Out:
# ...
# АНАЛИЗ УЛИЦ С ОДНИМ ОБЪЕКТОМ ОБЩЕПИТА
# ...
#
# 📊 НАХОЖДЕНИЕ УЛИЦ С ОДНИМ ЗАВЕДЕНИЕМ:
# --------------------------------------------------
# Всего уникальных улиц в датасете: 1 458
# Улиц с одним заведением: 464
# Доля таких улиц: 31.8%
#
# 🔍 АНАЛИЗ ЗАВЕДЕНИЙ НА УЛИЦАХ С ОДНИМ ОБЪЕКТОМ:
# --------------------------------------------------
# Всего таких заведений: 464
#
# 📈 ОБЩАЯ СТАТИСТИКА:
# • Средний рейтинг: 4.24
# • Медианный рейтинг: 4.30
# • Среднее количество мест: 59.1
# • Доля сетевых заведений: 28.9%
# • Доля круглосуточных: 17.2%
#
# 🏷️ РАСПРЕДЕЛЕНИЕ ПО КАТЕГОРИЯМ:
# --------------------------------------------------
# Топ-10 категорий на улицах с одним заведением:
#   • кафе: 161 заведений (34.7%)
#   • ресторан: 93 заведений (20.0%)
#   • кофейня: 84 заведений (18.1%)
#   • бар,паб: 41 заведений (8.8%)
#   • столовая: 36 заведений (7.8%)
#   • быстрое питание: 24 заведений (5.2%)
#   • пиццерия: 15 заведений (3.2%)
#   • булочная: 10 заведений (2.2%)
# ...

# %% [markdown]
# # **АНАЛИТИЧЕСКИЙ ВЫВОД: УЛИЦЫ С ОДНИМ ОБЪЕКТОМ ОБЩЕПИТА**
#
# ## 🎯 **ОСНОВНЫЕ ВЫВОДЫ О ЗАВЕДЕНИЯХ**
#
# ### **1. МАСШТАБ ЯВЛЕНИЯ: НЕ МАРГИНАЛЬНЫЙ, А ЗНАЧИМЫЙ СЕГМЕНТ**
# - **31.8% улиц Москвы** (464 из 1,458) имеют только одно заведение
# - **5.5% всех заведений** (464 из 8,406) расположены на таких улицах
# - **Это не исключения, а системное явление** - каждый 20-й ресторан/кафе в Москве находится на "улице-одиночке"
#
# ### **2. ПРОФИЛЬ ЗАВЕДЕНИЙ: МАЛЫЙ И СРЕДНИЙ БИЗНЕС**
# **📊 Ключевые характеристики:**
# - **Значительно меньше размером**: в среднем **59 мест** против 108 по рынку (-49 мест, -45%)
# - **Меньше сетевых**: всего **28.9%** против 38.1% (-9.2 пункта)
# - **Но рейтинги на уровне рынка**: 4.24 vs 4.23 (практически идентично)
#
# **💰 Ценовой сегмент:**
# - **Средний чек**: **961 ₽** (медиана - 638 ₽)
# - **Доминирует средний сегмент**: 66.7% заведений
# - **Есть премиум**: 12% - "высокие" цены, максимальный чек до 7,000 ₽
#
# ### **3. КАТЕГОРИЙНОЕ РАСПРЕДЕЛЕНИЕ: ОРИЕНТАЦИЯ НА ЛОКАЛЬНЫЙ СПРОС**
# **Топ-3 категории (72.8% всех заведений):**
# 1. **Кафе (34.7%)** - базовый формат для повседневного посещения
# 2. **Рестораны (20.0%)** - более высокий сегмент, но локальный
# 3. **Кофейни (18.1%)** - растущий тренд даже в удаленных локациях
#
# **Особенность**: Низкая доля пиццерий (3.2%) и фастфуда (5.2%) - форматы, требующие высокого трафика
#
# ### **4. ГЕОГРАФИЧЕСКИЕ ОСОБЕННОСТИ: ЦЕНТР vs ПЕРИФЕРИЯ**
# **🗺️ Концентрация:**
# - **ЦАО доминирует**: 31% всех "одиноких" заведений (144 из 464)
# - **Но равномерное распределение** по остальным округам (8-12% каждый)
#
# **Инсайт**: Даже в центре Москвы есть улицы с единственным заведением - это не только периферийное явление
#
# ## 🔍 **КЛЮЧЕВЫЕ ИНСАЙТЫ ДЛЯ БИЗНЕСА**
#
# ### **1. "ТИХИЕ УЛИЦЫ" КАК НИША ДЛЯ НЕЗАВИСИМЫХ ЗАВЕДЕНИЙ**
# **📈 Преимущества таких локаций:**
# - **Меньшая конкуренция**: монопольное положение на улице
# - **Лояльная локальная аудитория**: стабильный поток "своих" клиентов
# - **Возможность создания уникальной атмосферы**: не нужно конкурировать с сетями
#
# **⚠️ Риски:**
# - **Ограниченный трафик**: зависимость от жителей/работников района
# - **Сложность привлечения новой аудитории**: не проходное место
# - **Высокие требования к качеству**: нет "эффекта кластера"
#
# ### **2. УСПЕШНЫЕ ФОРМАТЫ ДЛЯ "УЛИЦ-ОДИНОЧЕК"**
# **✅ Работающие модели:**
# 1. **Локальное кафе** (161 заведение) - универсальный формат
# 2. **Районный ресторан** (93) - для особых случаев и встреч
# 3. **Уютная кофейня** (84) - тренд даже в удаленных локациях
#
# **❌ Проблемные форматы:**
# - Пиццерии (15) - требуют высокого трафика для доставки
# - Сетевые заведения (28.9% vs 38.1%) - сложно окупить без масштаба
#
# ### **3. ЭКОНОМИЧЕСКАЯ МОДЕЛЬ: МЕНЬШЕ, НО СТАБИЛЬНЕЕ**
# **📊 Экономика "одиноких" заведений:**
# - **Меньшие помещения**: 59 vs 108 мест (-45%)
# - **Ниже операционные расходы**: аренда, персонал, коммуналка
# - **Но выше требования к марже**: меньше оборачиваемость столов
#
# **💡 Ключ к успеху:**
# - **Высокое качество** при ограниченном ассортименте
# - **Персонализированный сервис** для локальной аудитории
# - **Уникальная концепция** вместо ценовой конкуренции
#
# ## 🎯 **РЕКОМЕНДАЦИИ ДЛЯ ИНВЕСТОРОВ**
#
# ### **1. ЕСЛИ РАССМАТРИВАЕТЕ "УЛИЦУ-ОДИНОЧКУ":**
# ```
# ✅ ПОДХОДЯЩИЕ ФОРМАТЫ:
#    • Локальное кафе с домашней кухней
#    • Уютная кофейня с авторским кофе
#    • Тематический бар/паб для районной аудитории
#    • Семейный ресторан для праздников и встреч
#
# ❌ НЕ РЕКОМЕНДУЕТСЯ:
#    • Сетевая пиццерия (требует высокого трафика)
#    • Фастфуд (нуждается в проходимости)
#    • Крупный ресторан (>100 мест)
# ```
#
# ### **2. КРИТИЧЕСКИЕ ФАКТОРЫ УСПЕХА:**
# 1. **Качество превыше всего**: нет потока "случайных" клиентов
# 2. **Лояльность локальной аудитории**: программы для постоянных гостей
# 3. **Уникальное УТП**: нельзя быть "еще одним кафе"
# 4. **Активность в соцсетях**: привлечение клиентов из других районов
#
# ### **3. ОЦЕНКА ПЕРСПЕКТИВНОСТИ ЛОКАЦИИ:**
# **Вопросы для анализа:**
# - Какая аудитория проживает/работает в радиусе 500м?
# - Есть ли поблизости офисные центры, университеты, ЖК?
# - Каков транспортный поток (не проходящий, а целевой)?
# - Какие потребности не закрыты в районе?
#
# ## 📈 **ВЫВОД ДЛЯ ФОНДА "SHUT UP AND TAKE MY MONEY"**
#
# **"Улицы с одним заведением" - это не "второй эшелон", а отдельная бизнес-модель:**
#
# ### **🔹 Для нового проекта:**
# **Рассматривайте такие локации, если:**
# - Готовы создавать уникальную, а не массовую концепцию
# - Цените стабильность выше быстрого роста
# - Имеете опыт работы с локальной аудиторией
# - Можете предложить качество, а не низкие цены
#
# ### **🔹 Конкурентные преимущества:**
# 1. **Монополия на улице** - нет прямой конкуренции
# 2. **Лояльность клиентов** - становятся "своими"
# 3. **Нишевость** - можно создать культовое место
#
# ### **🔹 Итоговый вердикт:**
# **"Улицы-одиночки" подходят для:**
# - Первого проекта с ограниченным бюджетом
# - Нишевых концепций с сильным УТП
# - Предпринимателей, ориентированных на качество, а не масштаб
#
# **Не подходят для:**
# - Сетевой экспансии
# - Форматов, требующих высокого трафика
# - Инвесторов, ожидающих быстрой окупаемости
#
# **Финальный вывод:** Каждая 5-я улица Москвы имеет потенциал для успешного локального заведения - это огромный неосвоенный рынок для качественных нишевых проектов.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.12 Анализ среднего чека
#
# ---
#
# Значения средних чеков заведений хранятся в столбце `middle_avg_bill`. Эти числа показывают примерную стоимость заказа в рублях, которая чаще всего выражена диапазоном.
#
# - Посчитайте медиану этого столбца для каждого района. Используйте это значение в качестве ценового индикатора района.
# 0 Постройте фоновую картограмму (хороплет) с полученными значениями для каждого района.
# - Проанализируйте цены в центральном административном округе и других. Как удалённость от центра влияет на цены в заведениях?

# %%
# =============================================================================
# АНАЛИЗ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ
# =============================================================================

print("=" * 80)
print("АНАЛИЗ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ МОСКВЫ")
print("=" * 80)

import pandas as pd
import numpy as np
import folium
from branca.colormap import linear
import json

# 1. ПОДГОТОВКА ДАННЫХ
print("\n📊 ПОДГОТОВКА ДАННЫХ:")
print("-" * 50)

# Фильтруем данные с указанным средним чеком
bill_df = df.dropna(subset=['middle_avg_bill']).copy()

print(f"Всего заведений в датасете: {len(df):,}".replace(',', ' '))
print(f"Заведений с указанным средним чеком: {len(bill_df):,} ({len(bill_df)/len(df)*100:.1f}%)".replace(',', ' '))

# Проверяем статистику по среднему чеку
print(f"\n📈 ОБЩАЯ СТАТИСТИКА ПО СРЕДНЕМУ ЧЕКУ:")
print(f"• Средний чек по всем заведениям: {bill_df['middle_avg_bill'].mean():.0f} ₽")
print(f"• Медианный чек: {bill_df['middle_avg_bill'].median():.0f} ₽")
print(f"• Минимальный чек: {bill_df['middle_avg_bill'].min():.0f} ₽")
print(f"• Максимальный чек: {bill_df['middle_avg_bill'].max():.0f} ₽")
print(f"• Стандартное отклонение: {bill_df['middle_avg_bill'].std():.0f} ₽")

# 2. РАСЧЕТ МЕДИАНЫ ПО РАЙОНАМ
print("\n💰 РАСЧЕТ МЕДИАНЫ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ:")
print("-" * 50)

# Группируем по районам и считаем медиану
bill_by_district = bill_df.groupby('district')['middle_avg_bill'].agg([
    ('median_bill', 'median'),
    ('mean_bill', 'mean'),
    ('count', 'count'),
    ('std', 'std'),
    ('min', 'min'),
    ('max', 'max'),
    ('q1', lambda x: x.quantile(0.25)),
    ('q3', lambda x: x.quantile(0.75))
]).round(0)

# Сортируем по медиане
bill_by_district_sorted = bill_by_district.sort_values('median_bill', ascending=False)

print("Медиана среднего чека по административным округам:")
print(bill_by_district_sorted[['median_bill', 'mean_bill', 'count']])

# 3. АНАЛИЗ ЗАВИСИМОСТИ ОТ УДАЛЕННОСТИ ОТ ЦЕНТРА
print("\n🗺️ АНАЛИЗ ЗАВИСИМОСТИ ЦЕН ОТ УДАЛЕННОСТИ ОТ ЦЕНТРА:")
print("-" * 50)

# Координаты центра Москвы (Красная площадь)
center_lat, center_lng = 55.7539, 37.6208

# Функция для расчета приблизительного расстояния
def calculate_distance(row):
    lat, lng = row['lat'], row['lng']
    if pd.isna(lat) or pd.isna(lng):
        return None
    # Упрощенный расчет расстояния в километрах
    # Используем формулу гаверсинусов
    from math import radians, sin, cos, sqrt, atan2
    
    R = 6371  # Радиус Земли в км
    
    lat1, lon1 = radians(center_lat), radians(center_lng)
    lat2, lon2 = radians(lat), radians(lng)
    
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    
    return R * c

# Добавляем расстояние до центра
bill_df['distance_to_center_km'] = bill_df.apply(calculate_distance, axis=1)

# Удаляем строки без координат
bill_df_with_dist = bill_df.dropna(subset=['distance_to_center_km'])

print(f"Заведений с координатами для расчета расстояния: {len(bill_df_with_dist):,}".replace(',', ' '))
print(f"\n📏 СТАТИСТИКА ПО РАССТОЯНИЯМ:")
print(f"• Среднее расстояние до центра: {bill_df_with_dist['distance_to_center_km'].mean():.1f} км")
print(f"• Медианное расстояние: {bill_df_with_dist['distance_to_center_km'].median():.1f} км")
print(f"• Минимальное расстояние: {bill_df_with_dist['distance_to_center_km'].min():.1f} км")
print(f"• Максимальное расстояние: {bill_df_with_dist['distance_to_center_km'].max():.1f} км")

# Анализ корреляции
correlation = bill_df_with_dist['distance_to_center_km'].corr(bill_df_with_dist['middle_avg_bill'])
print(f"\n📊 КОРРЕЛЯЦИЯ МЕЖДУ РАССТОЯНИЕМ И СРЕДНИМ ЧЕКОМ:")
print(f"• Коэффициент корреляции Пирсона: {correlation:.3f}")
print(f"• R² (квадрат корреляции): {correlation**2:.3f}")

# Анализ по зонам удаленности
print(f"\n📍 АНАЛИЗ ПО ЗОНАМ УДАЛЕННОСТИ:")

# Определяем зоны удаленности
def get_distance_zone(distance):
    if distance < 5:
        return "0-5 км (центр)"
    elif distance < 10:
        return "5-10 км (ближние районы)"
    elif distance < 15:
        return "10-15 км (средняя удаленность)"
    else:
        return "15+ км (окраины)"

bill_df_with_dist['distance_zone'] = bill_df_with_dist['distance_to_center_km'].apply(get_distance_zone)

# Статистика по зонам
zones_stats = bill_df_with_dist.groupby('distance_zone')['middle_avg_bill'].agg([
    ('median', 'median'),
    ('mean', 'mean'),
    ('count', 'count'),
    ('std', 'std')
]).round(0)

print("\nСтатистика среднего чека по зонам удаленности:")
print(zones_stats)

# 4. ПОДРОБНЫЙ АНАЛИЗ ЦАО
print("\n🏙️ ПОДРОБНЫЙ АНАЛИЗ ЦЕНТРАЛЬНОГО АДМИНИСТРАТИВНОГО ОКРУГА:")
print("-" * 50)

# Фильтруем данные по ЦАО
cao_df = bill_df[bill_df['district'] == 'Центральный административный округ'].copy()

print(f"Заведений в ЦАО с указанным средним чеком: {len(cao_df):,}".replace(',', ' '))

if len(cao_df) > 0:
    print(f"\n📈 СТАТИСТИКА ПО ЦАО:")
    print(f"• Медианный чек: {cao_df['middle_avg_bill'].median():.0f} ₽")
    print(f"• Средний чек: {cao_df['middle_avg_bill'].mean():.0f} ₽")
    print(f"• Минимальный чек: {cao_df['middle_avg_bill'].min():.0f} ₽")
    print(f"• Максимальный чек: {cao_df['middle_avg_bill'].max():.0f} ₽")
    print(f"• Стандартное отклонение: {cao_df['middle_avg_bill'].std():.0f} ₽")
    
    # Анализ по категориям в ЦАО
    print(f"\n🏷️ РАСПРЕДЕЛЕНИЕ ПО КАТЕГОРИЯМ В ЦАО:")
    cao_by_category = cao_df.groupby('category')['middle_avg_bill'].agg([
        ('median', 'median'),
        ('count', 'count')
    ]).round(0).sort_values('median', ascending=False)
    
    print("Топ-5 категорий по медианному чеку в ЦАО:")
    print(cao_by_category.head())
    
    # Сравнение ЦАО с другими округами
    print(f"\n📊 СРАВНЕНИЕ ЦАО С ДРУГИМИ ОКРУГАМИ:")
    cao_median = bill_by_district.loc['Центральный административный округ', 'median_bill']
    other_median = bill_by_district[bill_by_district.index != 'Центральный административный округ']['median_bill'].mean()
    
    print(f"• Медиана ЦАО: {cao_median:.0f} ₽")
    print(f"• Средняя медиана других округов: {other_median:.0f} ₽")
    print(f"• Разница: {cao_median - other_median:.0f} ₽ ({(cao_median/other_median - 1)*100:.1f}%)")

# 5. ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТОГРАММЫ
print("\n🗺️ ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТОГРАММЫ:")
print("-" * 50)

# Создаем словарь для передачи в GeoJSON
district_bill_dict = bill_by_district['median_bill'].to_dict()

print("Данные для картограммы:")
for district, median_bill in district_bill_dict.items():
    print(f"• {district}: {median_bill:.0f} ₽")

# 6. СОЗДАНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ)
print("\n🎨 СОЗДАНИЕ ФОНОВОЙ КАРТОГРАММЫ:")
print("-" * 50)

# Создаем базовую карту
moscow_center = [55.7558, 37.6176]
m = folium.Map(location=moscow_center, zoom_start=10, tiles='CartoDB positron')

# Создаем цветовую шкалу
min_bill = bill_by_district['median_bill'].min()
max_bill = bill_by_district['median_bill'].max()

print(f"Диапазон медианных чеков: {min_bill:.0f} - {max_bill:.0f} ₽")

colormap = linear.YlOrRd_09.scale(min_bill, max_bill)
colormap.caption = 'Медианный средний чек, руб.'

# Добавляем цветовую шкалу на карту
m.add_child(colormap)

# Загружаем GeoJSON с границами районов
try:
    with open('admin_level_geomap.geojson', 'r', encoding='utf-8') as f:
        geojson_data = json.load(f)
    print("✅ GeoJSON файл загружен")
    
    # Функция для стилизации районов
    def style_function(feature):
        district_name = None
        properties = feature.get('properties', {})
        
        # Ищем соответствие названия района
        # Проверяем различные варианты названий
        possible_keys = ['name', 'NAME', 'district', 'DISTRICT', 'административный округ']
        
        for key in possible_keys:
            if key in properties:
                value = properties[key]
                # Ищем соответствие
                for district in district_bill_dict.keys():
                    if district.lower() in str(value).lower() or str(value).lower() in district.lower():
                        district_name = district
                        break
                if district_name:
                    break
        
        if district_name and district_name in district_bill_dict:
            bill_value = district_bill_dict[district_name]
            return {
                'fillColor': colormap(bill_value),
                'color': 'black',
                'weight': 1,
                'fillOpacity': 0.7,
                'dashArray': '5, 5'
            }
        else:
            return {
                'fillColor': '#cccccc',
                'color': 'black',
                'weight': 1,
                'fillOpacity': 0.3
            }
    
    # Функция для всплывающих подсказок
    def highlight_function(feature):
        district_name = None
        properties = feature.get('properties', {})
        
        for key in ['name', 'NAME', 'district', 'DISTRICT', 'административный округ']:
            if key in properties:
                value = properties[key]
                for district in district_bill_dict.keys():
                    if district.lower() in str(value).lower() or str(value).lower() in district.lower():
                        district_name = district
                        break
                if district_name:
                    break
        
        if district_name and district_name in district_bill_dict:
            bill_info = bill_by_district.loc[district_name]
            return f"""
            <b>{district_name}</b><br>
            Медианный чек: {bill_info['median_bill']:.0f} ₽<br>
            Средний чек: {bill_info['mean_bill']:.0f} ₽<br>
            Кол-во заведений: {bill_info['count']}<br>
            Диапазон: {bill_info['min']:.0f} - {bill_info['max']:.0f} ₽
            """
        return "Нет данных"
    
    # Добавляем GeoJSON слой
    geojson_layer = folium.GeoJson(
        geojson_data,
        style_function=style_function,
        tooltip=folium.GeoJsonTooltip(
            fields=[],  # Будем использовать кастомную функцию
            aliases=[],
            localize=True
        )
    )
    
    geojson_layer.add_to(m)
    print("✅ GeoJSON слой добавлен на карту")
    
except FileNotFoundError:
    print("❌ Файл admin_level_geomap.geojson не найден")
    print("Скачайте файл по ссылке: https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson")
    
    # Создаем альтернативную визуализацию - маркеры для районов
    print("Создаю альтернативную визуализацию...")
    
    # Приблизительные координаты центров районов (для демонстрации)
    district_centers = {
        'Центральный административный округ': [55.7558, 37.6176],
        'Северный административный округ': [55.8394, 37.5471],
        'Южный административный округ': [55.6226, 37.6064],
        'Восточный административный округ': [55.7870, 37.7666],
        'Западный административный округ': [55.7273, 37.4710],
        'Северо-Восточный административный округ': [55.8606, 37.6380],
        'Северо-Западный административный округ': [55.8293, 37.4172],
        'Юго-Восточный административный округ': [55.6922, 37.7750],
        'Юго-Западный административный округ': [55.6566, 37.5681]
    }
    
    for district, median_bill in district_bill_dict.items():
        if district in district_centers:
            color = colormap(median_bill)
            
            folium.CircleMarker(
                location=district_centers[district],
                radius=15,
                popup=f"<b>{district}</b><br>Медианный чек: {median_bill:.0f} ₽",
                color=color,
                fill=True,
                fill_color=color,
                fill_opacity=0.7,
                weight=2
            ).add_to(m)
    
    print("✅ Альтернативная визуализация создана")

# Добавляем заголовок
title_html = '''
<div style="position: fixed; 
            top: 10px; left: 50px; width: 500px; height: 80px; 
            background-color: white; border:2px solid grey; z-index:9999; 
            padding: 10px; border-radius: 5px;">
    <h4 style="margin: 0;">Картограмма средних чеков по районам Москвы</h4>
    <p style="margin: 5px 0; font-size: 12px;">Цвет показывает медианный средний чек заведений в административном округе</p>
</div>
'''
m.get_root().html.add_child(folium.Element(title_html))

# Сохраняем карту
output_file = 'moscow_bill_choropleth.html'
m.save(output_file)
print(f"\n✅ Карта сохранена в файл: {output_file}")

# 7. ВИЗУАЛИЗАЦИЯ ЗАВИСИМОСТИ ЦЕН ОТ РАССТОЯНИЯ
print("\n📈 ВИЗУАЛИЗАЦИЯ ЗАВИСИМОСТИ ЦЕН ОТ РАССТОЯНИЯ:")
print("-" * 50)

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

# Точечная диаграмма
plt.scatter(bill_df_with_dist['distance_to_center_km'], 
            bill_df_with_dist['middle_avg_bill'], 
            alpha=0.3, s=20, color='steelblue')

# Линия тренда
z = np.polyfit(bill_df_with_dist['distance_to_center_km'], 
               bill_df_with_dist['middle_avg_bill'], 1)
p = np.poly1d(z)

x_range = np.linspace(bill_df_with_dist['distance_to_center_km'].min(), 
                      bill_df_with_dist['distance_to_center_km'].max(), 100)
plt.plot(x_range, p(x_range), color='red', linewidth=3, 
         label=f'Тренд (R²={correlation**2:.3f})')

plt.xlabel('Расстояние до центра Москвы, км', fontsize=12, fontweight='bold')
plt.ylabel('Средний чек, руб.', fontsize=12, fontweight='bold')
plt.title('Зависимость среднего чека от удаленности от центра Москвы', 
          fontsize=16, fontweight='bold', pad=20)

plt.grid(alpha=0.3)
plt.legend()

# Добавляем аннотации для зон
zone_stats_detailed = bill_df_with_dist.groupby('distance_zone')['middle_avg_bill'].agg(['median', 'count']).round(0)

y_pos = 7000
for zone, row in zone_stats_detailed.iterrows():
    plt.text(2, y_pos, f"{zone}: {row['median']:.0f} ₽ (n={row['count']})", 
             fontsize=10, bbox=dict(facecolor='white', alpha=0.8))
    y_pos -= 500

plt.tight_layout()
plt.show()

# 8. ИТОГОВАЯ СТАТИСТИКА
print("\n" + "="*80)
print("ИТОГОВАЯ СТАТИСТИКА ПО АНАЛИЗУ СРЕДНИХ ЧЕКОВ")
print("="*80)

print(f"\n🏙️ ЦЕНТРАЛЬНЫЙ АДМИНИСТРАТИВНЫЙ ОКРУГ:")
print(f"• Медианный чек: {cao_median:.0f} ₽")
print(f"• Заведений с данными: {len(cao_df):,}".replace(',', ' '))

print(f"\n📏 ВЛИЯНИЕ УДАЛЕННОСТИ ОТ ЦЕНТРА:")
print(f"• Коэффициент корреляции: {correlation:.3f}")
print(f"• При удалении на 1 км чек снижается в среднем на {abs(z[0]):.0f} ₽")

print(f"\n💰 САМЫЕ ДОРОГИЕ РАЙОНЫ (Топ-3):")
for i, (district, row) in enumerate(bill_by_district_sorted.head(3).iterrows(), 1):
    print(f"{i}. {district}: {row['median_bill']:.0f} ₽")

print(f"\n💸 САМЫЕ ДОСТУПНЫЕ РАЙОНЫ (Топ-3):")
for i, (district, row) in enumerate(bill_by_district_sorted.tail(3).iterrows(), 1):
    print(f"{i}. {district}: {row['median_bill']:.0f} ₽")

print(f"\n📊 РАЗБРОС ЦЕН ПО РАЙОНАМ:")
print(f"• Разница между самым дорогим и самым доступным районом: {bill_by_district_sorted.iloc[0]['median_bill'] - bill_by_district_sorted.iloc[-1]['median_bill']:.0f} ₽")
print(f"• Коэффициент вариации: {(bill_by_district['median_bill'].std() / bill_by_district['median_bill'].mean() * 100):.1f}%")
# Out:
# ...
# АНАЛИЗ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ МОСКВЫ
# ...
#
# 📊 ПОДГОТОВКА ДАННЫХ:
# --------------------------------------------------
# Всего заведений в датасете: 8 406
# Заведений с указанным средним чеком: 3 149 (37.5%)
#
# 📈 ОБЩАЯ СТАТИСТИКА ПО СРЕДНЕМУ ЧЕКУ:
# • Средний чек по всем заведениям: 958 ₽
# • Медианный чек: 750 ₽
# • Минимальный чек: 0 ₽
# • Максимальный чек: 35000 ₽
# • Стандартное отклонение: 1010 ₽
#
# 💰 РАСЧЕТ МЕДИАНЫ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ:
# --------------------------------------------------
# Медиана среднего чека по административным округам:
#                                          median_bill  mean_bill  count
# district
# Западный административный округ               1000.0     1053.0    306
# Центральный административный округ            1000.0     1191.0   1060
# Северо-Западный административный округ         700.0      822.0    157
# Северный административный округ                650.0      928.0    322
# ...

# %% [markdown]
# ### ШАГ 3.12: ВИЗУАЛИЗАЦИЯ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ (ИСПРАВЛЕННАЯ ВЕРСИЯ)

# %%
# =============================================================================
# ШАГ 3.12: ВИЗУАЛИЗАЦИЯ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ (ИСПРАВЛЕННАЯ ВЕРСИЯ)
# =============================================================================

print("=" * 80)
print("ВИЗУАЛИЗАЦИЯ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ МОСКВЫ")
print("=" * 80)

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# 1. ПОДГОТОВКА ДАННЫХ
print("\n📊 ПОДГОТОВКА ДАННЫХ:")
print("-" * 50)

# Фильтруем данные с указанным средним чеком
bill_df = df.dropna(subset=['middle_avg_bill']).copy()

# Группируем по районам и считаем медиану
bill_by_district = bill_df.groupby('district')['middle_avg_bill'].agg([
    ('median_bill', 'median'),
    ('mean_bill', 'mean'),
    ('count', 'count'),
    ('std', 'std')
]).round(0).sort_values('median_bill', ascending=True)  # Сортируем по возрастанию для лучшей визуализации

print("Медиана среднего чека по административным округам:")
print(bill_by_district[['median_bill', 'mean_bill', 'count']])

# 2. ВИЗУАЛИЗАЦИЯ 1: ГОРИЗОНТАЛЬНАЯ СТОЛБЧАТАЯ ДИАГРАММА
print("\n📈 ВИЗУАЛИЗАЦИЯ 1: ГОРИЗОНТАЛЬНАЯ СТОЛБЧАТАЯ ДИАГРАММА")
print("-" * 50)

plt.figure(figsize=(14, 8))

# Создаем цветовую градацию на основе значений
norm = plt.Normalize(bill_by_district['median_bill'].min(), bill_by_district['median_bill'].max())
colors = plt.cm.YlOrRd(norm(bill_by_district['median_bill'].values))

# Создаем горизонтальные столбцы
bars = plt.barh(bill_by_district.index, bill_by_district['median_bill'], color=colors, edgecolor='black')

plt.xlabel('Медианный средний чек, руб.', fontsize=12, fontweight='bold')
plt.ylabel('Административный округ', fontsize=12, fontweight='bold')
plt.title('Медианный средний чек заведений по административным округам Москвы', 
          fontsize=16, fontweight='bold', pad=20)

# Добавляем среднее значение по Москве
moscow_median = bill_df['middle_avg_bill'].median()
plt.axvline(x=moscow_median, color='blue', linestyle='--', linewidth=2, 
            label=f'Медиана по Москве: {moscow_median:.0f} ₽')

# Добавляем значения на столбцы
for bar, median_value, count in zip(bars, bill_by_district['median_bill'], bill_by_district['count']):
    width = bar.get_width()
    # Размещаем текст внутри или снаружи столбца в зависимости от ширины
    text_x = width + 20 if width < max(bill_by_district['median_bill']) * 0.8 else width - 40
    text_color = 'black' if width < max(bill_by_district['median_bill']) * 0.8 else 'white'
    text_ha = 'left' if width < max(bill_by_district['median_bill']) * 0.8 else 'right'
    
    plt.text(text_x, bar.get_y() + bar.get_height()/2, 
             f'{int(width)} ₽ (n={count})', 
             ha=text_ha, va='center', fontsize=10, fontweight='bold', color=text_color)

plt.grid(axis='x', alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# 3. ВИЗУАЛИЗАЦИЯ 2: ТАБЛИЦА С ЦВЕТОВОЙ КОДИРОВКОЙ (HEATMAP STYLE)
print("\n🔥 ВИЗУАЛИЗАЦИЯ 2: ТАБЛИЦА С ЦВЕТОВОЙ КОДИРОВКОЙ")
print("-" * 50)

plt.figure(figsize=(14, 6))

# Создаем данные для таблицы
table_data = bill_by_district.sort_values('median_bill', ascending=False)[['median_bill', 'mean_bill', 'count']]

# Создаем таблицу с цветовой кодировкой
fig, ax = plt.subplots(figsize=(12, 4))
ax.axis('tight')
ax.axis('off')

# Создаем таблицу
table = ax.table(cellText=table_data.values,
                 colLabels=['Медианный чек (₽)', 'Средний чек (₽)', 'Кол-во заведений'],
                 rowLabels=table_data.index,
                 cellLoc='center',
                 loc='center')

# Настраиваем стиль таблицы
table.auto_set_font_size(False)
table.set_fontsize(11)
table.scale(1.2, 1.8)

# Добавляем цветовую кодировку для столбца с медианным чеком
for i in range(len(table_data)):
    value = table_data.iloc[i, 0]  # Медианный чек
    color = plt.cm.YlOrRd(norm(value))
    table[(i+1, 0)].set_facecolor(color)
    # Меняем цвет текста для темных ячеек
    if value > bill_by_district['median_bill'].quantile(0.7):
        table[(i+1, 0)].set_text_props(color='white', fontweight='bold')

# Заголовок
plt.title('Средние чеки заведений по административным округам Москвы', 
          fontsize=16, fontweight='bold', pad=20)
plt.tight_layout()
plt.show()

# 4. ВИЗУАЛИЗАЦИЯ 3: СРАВНЕНИЕ МЕДИАНЫ И СРЕДНЕГО
print("\n📊 ВИЗУАЛИЗАЦИЯ 3: СРАВНЕНИЕ МЕДИАНЫ И СРЕДНЕГО ЧЕКА")
print("-" * 50)

plt.figure(figsize=(14, 8))

# Сортируем по медиане для лучшей визуализации
sorted_districts = bill_by_district.sort_values('median_bill', ascending=True).index
x = np.arange(len(sorted_districts))
width = 0.35

# Столбцы для медианы и среднего
bars1 = plt.barh(x - width/2, bill_by_district.loc[sorted_districts, 'median_bill'], 
                 width, label='Медианный чек', color='#FF6B6B', edgecolor='black')
bars2 = plt.barh(x + width/2, bill_by_district.loc[sorted_districts, 'mean_bill'], 
                 width, label='Средний чек', color='#4ECDC4', edgecolor='black')

plt.ylabel('Административный округ', fontsize=12, fontweight='bold')
plt.xlabel('Средний чек, руб.', fontsize=12, fontweight='bold')
plt.title('Сравнение медианного и среднего чека по административным округам Москвы', 
          fontsize=16, fontweight='bold', pad=20)
plt.yticks(x, sorted_districts)

# Добавляем значения
for bars in [bars1, bars2]:
    for bar in bars:
        width = bar.get_width()
        plt.text(width + 20, bar.get_y() + bar.get_height()/2, 
                 f'{int(width)}', ha='left', va='center', fontsize=9)

plt.grid(axis='x', alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# 5. ВИЗУАЛИЗАЦИЯ 4: КРУГОВАЯ ДИАГРАММА С ДОЛЕЙ ЗАВЕДЕНИЙ
print("\n🥧 ВИЗУАЛИЗАЦИЯ 4: РАСПРЕДЕЛЕНИЕ ЗАВЕДЕНИЙ ПО РАЙОНАМ")
print("-" * 50)

plt.figure(figsize=(12, 10))

# Данные для круговой диаграммы
district_counts = bill_by_district['count']
labels = [f'{idx}\n({count} зав.)' for idx, count in zip(district_counts.index, district_counts.values)]

# Создаем круговую диаграмму
wedges, texts, autotexts = plt.pie(district_counts.values, 
                                   labels=labels, 
                                   autopct='%1.1f%%',
                                   startangle=90,
                                   textprops={'fontsize': 10},
                                   wedgeprops={'edgecolor': 'black', 'linewidth': 1})

# Увеличиваем шрифт для процентов
for autotext in autotexts:
    autotext.set_fontsize(10)
    autotext.set_fontweight('bold')

plt.title('Распределение заведений с данными о среднем чеке по административным округам', 
          fontsize=16, fontweight='bold', pad=20)
plt.axis('equal')  # Равные пропорции для круга
plt.tight_layout()
plt.show()

# 6. АНАЛИЗ ЦЕНОВЫХ КАТЕГОРИЙ
print("\n💰 АНАЛИЗ ЦЕНОВЫХ КАТЕГОРИЙ ПО РАЙОНАМ:")
print("-" * 50)

# Создаем категории цен на основе медианных чеков
def categorize_price(median_price):
    if median_price >= 900:
        return 'Высокий (900+ ₽)'
    elif median_price >= 700:
        return 'Выше среднего (700-899 ₽)'
    elif median_price >= 550:
        return 'Средний (550-699 ₽)'
    else:
        return 'Доступный (до 550 ₽)'

bill_by_district['price_category'] = bill_by_district['median_bill'].apply(categorize_price)

print("\nРаспределение районов по ценовым категориям:")
price_category_counts = bill_by_district['price_category'].value_counts()
for category, count in price_category_counts.items():
    percentage = count / len(bill_by_district) * 100
    districts = bill_by_district[bill_by_district['price_category'] == category].index.tolist()
    print(f"• {category}: {count} районов ({percentage:.1f}%)")
    print(f"  Районы: {', '.join(districts)}")

# 7. СВОДНАЯ ИНФОРМАЦИЯ
print("\n" + "="*80)
print("СВОДНАЯ ИНФОРМАЦИЯ ПО СРЕДНИМ ЧЕКАМ")
print("="*80)

print(f"\n📈 ОБЩАЯ СТАТИСТИКА:")
print(f"• Всего заведений с данными о чеке: {len(bill_df):,} ({len(bill_df)/len(df)*100:.1f}%)".replace(',', ' '))
print(f"• Общая медиана по Москве: {moscow_median:.0f} ₽")
print(f"• Средняя медиана по районам: {bill_by_district['median_bill'].mean():.0f} ₽")
print(f"• Разброс между районами: {bill_by_district['median_bill'].max() - bill_by_district['median_bill'].min():.0f} ₽")

print(f"\n🏆 ЛИДЕРЫ ПО ЦЕНАМ:")
top_3 = bill_by_district.nlargest(3, 'median_bill')
for i, (district, row) in enumerate(top_3.iterrows(), 1):
    diff_from_avg = row['median_bill'] - moscow_median
    print(f"{i}. {district}: {row['median_bill']:.0f} ₽ (+{diff_from_avg:.0f} ₽ к медиане Москвы)")

print(f"\n💸 САМЫЕ ДОСТУПНЫЕ РАЙОНЫ:")
bottom_3 = bill_by_district.nsmallest(3, 'median_bill')
for i, (district, row) in enumerate(bottom_3.iterrows(), 1):
    diff_from_avg = moscow_median - row['median_bill']
    print(f"{i}. {district}: {row['median_bill']:.0f} ₽ (-{diff_from_avg:.0f} ₽ к медиане Москвы)")

print(f"\n📊 СТАТИСТИЧЕСКИЕ ПОКАЗАТЕЛИ:")
print(f"• Стандартное отклонение: {bill_by_district['median_bill'].std():.0f} ₽")
print(f"• Коэффициент вариации: {(bill_by_district['median_bill'].std() / bill_by_district['median_bill'].mean() * 100):.1f}%")
print(f"• Интерквартильный размах: {bill_by_district['median_bill'].quantile(0.75) - bill_by_district['median_bill'].quantile(0.25):.0f} ₽")

print(f"\n📍 РАСПРЕДЕЛЕНИЕ ПО ЦЕНОВЫМ КАТЕГОРИЯМ:")
for category in ['Высокий (900+ ₽)', 'Выше среднего (700-899 ₽)', 'Средний (550-699 ₽)', 'Доступный (до 550 ₽)']:
    if category in price_category_counts:
        count = price_category_counts[category]
        percentage = count / len(bill_by_district) * 100
        print(f"• {category}: {count} районов ({percentage:.1f}%)")

print("\n" + "="*80)
print("ВЫВОДЫ ДЛЯ ИНВЕСТОРОВ:")
print("="*80)
print("""
1. ЧЕТКОЕ ЦЕНОВОЕ РАССЛОЕНИЕ: Разница между самым дорогим и самым доступным районом - 550 ₽
2. ЦАО И ЗАО - ПРЕМИУМ СЕГМЕНТ: Медиана 1000 ₽, ориентированы на платежеспособную аудиторию
3. ОПТИМАЛЬНЫЕ РАЙОНЫ ДЛЯ СТАРТА: ЮЗАО, ВАО, СВАО (600-650 ₽) - баланс цены и качества
4. БЮДЖЕТНЫЕ ВАРИАНТЫ: ЮВАО, ЮАО (450-500 ₽) - низкая конкуренция, но специфический спрос
""")
print("="*80)
# Out:
# ...
# ВИЗУАЛИЗАЦИЯ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ МОСКВЫ
# ...
#
# 📊 ПОДГОТОВКА ДАННЫХ:
# --------------------------------------------------
# Медиана среднего чека по административным округам:
#                                          median_bill  mean_bill  count
# district
# Юго-Восточный административный округ           450.0      654.0    194
# Северо-Восточный административный округ        500.0      717.0    301
# Южный административный округ                   500.0      834.0    314
# Восточный административный округ               575.0      821.0    260
# Юго-Западный административный округ            600.0      793.0    235
# Северный административный округ                650.0      928.0    322
# Северо-Западный административный округ         700.0      822.0    157
# Западный административный округ               1000.0     1053.0    306
# Центральный административный округ            1000.0     1191.0   1060
#
# 📈 ВИЗУАЛИЗАЦИЯ 1: ГОРИЗОНТАЛЬНАЯ СТОЛБЧАТАЯ ДИАГРАММА
# ...

# %% [markdown]
# ### ШАГ 3.12: ПОСТРОЕНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ) СРЕДНЕГО ЧЕКА

# %%
# 1. ПОДГОТОВКА ДАННЫХ ДЛЯ КАРТОГРАММЫ
print("\n📊 ПОДГОТОВКА ДАННЫХ:")
print("-" * 50)

# Фильтруем данные с указанным средним чеком
bill_df = df.dropna(subset=['middle_avg_bill']).copy()

# Группируем по районам и считаем медиану
bill_by_district = bill_df.groupby('district')['middle_avg_bill'].agg([
    ('median_bill', 'median'),
    ('mean_bill', 'mean'),
    ('count', 'count'),
    ('std', 'std')
]).round(0).sort_values('median_bill', ascending=False)

print("Медиана среднего чека по административным округам:")
print(bill_by_district[['median_bill', 'mean_bill', 'count']])

# 2. СОЗДАНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ)
print("\n🎨 СОЗДАНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ):")
print("-" * 50)

# Создаем базовую карту Москвы
moscow_center = [55.7558, 37.6176]
m = folium.Map(location=moscow_center, zoom_start=10, tiles='CartoDB positron')

# Создаем цветовую шкалу
min_bill = bill_by_district['median_bill'].min()
max_bill = bill_by_district['median_bill'].max()

print(f"Диапазон медианных чеков: {min_bill:.0f} - {max_bill:.0f} ₽")

colormap = linear.YlOrRd_09.scale(min_bill, max_bill)
colormap.caption = 'Медианный средний чек, руб.'

# Добавляем цветовую шкалу на карту
m.add_child(colormap)

# 3. ЗАГРУЗКА И ОБРАБОТКА GEOJSON-ФАЙЛА
print("\n🗺️ ЗАГРУЗКА GEOJSON-ФАЙЛА С ГРАНИЦАМИ РАЙОНОВ:")
print("-" * 50)

try:
    # Загрузка GeoJSON файла
    with open('admin_level_geomap.geojson', 'r', encoding='utf-8') as f:
        geojson_data = json.load(f)
    print("✅ GeoJSON файл успешно загружен")
    
    # Проверяем структуру данных
    if 'features' in geojson_data:
        print(f"Количество полигонов (районов): {len(geojson_data['features'])}")
        
        # Выводим пример структуры первого полигона
        first_feature = geojson_data['features'][0]
        if 'properties' in first_feature:
            print("Свойства полигонов содержат следующие ключи:")
            print(list(first_feature['properties'].keys())[:5], "...")
    
except FileNotFoundError:
    print("❌ Файл admin_level_geomap.geojson не найден")
    print("Скачайте файл по ссылке: https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson")
    print("и разместите его в той же директории, что и Jupyter Notebook")
    geojson_data = None
except Exception as e:
    print(f"❌ Ошибка при чтении GeoJSON: {e}")
    geojson_data = None

# 4. СОПОСТАВЛЕНИЕ НАЗВАНИЙ РАЙОНОВ
print("\n🔗 СОПОСТАВЛЕНИЕ НАЗВАНИЙ РАЙОНОВ:")
print("-" * 50)

# Названия районов в наших данных
our_districts = list(bill_by_district.index)
print("Районы в наших данных:")
for district in our_districts:
    print(f"  • {district}")

# Если GeoJSON загружен, ищем соответствия
if geojson_data and 'features' in geojson_data:
    # Создаем словарь для сопоставления
    district_mapping = {}
    
    for feature in geojson_data['features']:
        if 'properties' in feature:
            props = feature['properties']
            
            # Ищем возможные ключи с названиями районов
            possible_keys = ['name', 'NAME', 'district', 'DISTRICT', 
                           'административный округ', 'адм_округ']
            
            geo_district_name = None
            for key in possible_keys:
                if key in props:
                    geo_district_name = props[key]
                    break
            
            if geo_district_name:
                # Пытаемся найти соответствие с нашими данными
                for our_district in our_districts:
                    # Упрощенное сопоставление (можно улучшить)
                    our_lower = our_district.lower()
                    geo_lower = str(geo_district_name).lower()
                    
                    # Проверяем разные варианты соответствия
                    if (our_lower in geo_lower or 
                        geo_lower in our_lower or
                        any(word in geo_lower for word in our_lower.split())):
                        
                        district_mapping[our_district] = {
                            'geo_name': geo_district_name,
                            'feature': feature
                        }
                        print(f"  ✅ Сопоставлено: {our_district} → {geo_district_name}")
                        break
    
    print(f"\nУдалось сопоставить {len(district_mapping)} из {len(our_districts)} районов")

# 5. ФУНКЦИЯ ДЛЯ СТИЛИЗАЦИИ КАРТОГРАММЫ
print("\n🎨 НАСТРОЙКА СТИЛЯ КАРТОГРАММЫ:")
print("-" * 50)

def get_district_style(feature_properties, bill_data_dict):
    """
    Возвращает стиль для района на основе медианного чека
    """
    # Пытаемся определить район
    district_name = None
    possible_keys = ['name', 'NAME', 'district', 'DISTRICT', 'административный округ']
    
    for key in possible_keys:
        if key in feature_properties:
            value = feature_properties[key]
            # Ищем соответствие в наших данных
            for our_district, bill_value in bill_data_dict.items():
                our_lower = our_district.lower()
                value_lower = str(value).lower()
                
                if (our_lower in value_lower or 
                    value_lower in our_lower or
                    any(word in value_lower for word in our_lower.split())):
                    district_name = our_district
                    break
            if district_name:
                break
    
    # Если нашли район и есть данные о чеке
    if district_name and district_name in bill_data_dict:
        bill_value = bill_data_dict[district_name]
        return {
            'fillColor': colormap(bill_value),
            'color': 'black',
            'weight': 1,
            'fillOpacity': 0.7,
            'dashArray': '5, 5'
        }
    else:
        # Серый цвет для районов без данных
        return {
            'fillColor': '#cccccc',
            'color': 'black',
            'weight': 1,
            'fillOpacity': 0.3
        }

def get_district_popup(feature_properties, bill_data_dict, bill_stats_df):
    """
    Создает всплывающую подсказку для района
    """
    # Пытаемся определить район
    district_name = None
    possible_keys = ['name', 'NAME', 'district', 'DISTRICT', 'административный округ']
    
    for key in possible_keys:
        if key in feature_properties:
            value = feature_properties[key]
            for our_district in bill_data_dict.keys():
                our_lower = our_district.lower()
                value_lower = str(value).lower()
                
                if (our_lower in value_lower or 
                    value_lower in our_lower or
                    any(word in value_lower for word in our_lower.split())):
                    district_name = our_district
                    break
            if district_name:
                break
    
    # Создаем HTML для всплывающей подсказки
    if district_name and district_name in bill_data_dict:
        bill_value = bill_data_dict[district_name]
        stats = bill_stats_df.loc[district_name]
        
        popup_html = f"""
        <div style="font-family: Arial, sans-serif; min-width: 200px;">
            <h4 style="margin: 0 0 10px 0; color: #333;">{district_name}</h4>
            <hr style="margin: 5px 0;">
            <p style="margin: 5px 0;"><b>Медианный чек:</b> {bill_value:.0f} ₽</p>
            <p style="margin: 5px 0;"><b>Средний чек:</b> {stats['mean_bill']:.0f} ₽</p>
            <p style="margin: 5px 0;"><b>Заведений:</b> {stats['count']}</p>
            <p style="margin: 5px 0;"><b>Разброс:</b> ±{stats['std']:.0f} ₽</p>
            <hr style="margin: 5px 0;">
            <p style="margin: 5px 0; font-size: 11px; color: #666;">
                Кликните для детальной информации
            </p>
        </div>
        """
        return folium.Popup(popup_html, max_width=300)
    else:
        return folium.Popup("Нет данных о средних чеках", max_width=200)

# 6. ДОБАВЛЕНИЕ GEOJSON СЛОЯ НА КАРТУ
print("\n🗺️ ДОБАВЛЕНИЕ КАРТОГРАММЫ НА КАРТУ:")
print("-" * 50)

if geojson_data:
    # Создаем словарь с данными для картограммы
    bill_data_dict = bill_by_district['median_bill'].to_dict()
    
    # Создаем GeoJson слой
    geojson_layer = folium.GeoJson(
        geojson_data,
        style_function=lambda feature: get_district_style(
            feature['properties'], 
            bill_data_dict
        ),
        tooltip=folium.GeoJsonTooltip(
            fields=['name'] if 'name' in geojson_data['features'][0]['properties'] else [],
            aliases=['Район:'],
            localize=True
        )
    )
    
    # Добавляем всплывающие подсказки
    for feature in geojson_layer.data['features']:
        if 'properties' in feature:
            popup = get_district_popup(
                feature['properties'], 
                bill_data_dict,
                bill_by_district
            )
            geojson_layer.add_child(popup)
    
    # Добавляем слой на карту
    geojson_layer.add_to(m)
    print("✅ Картограмма успешно добавлена на карту")
else:
    print("❌ Не удалось загрузить GeoJSON данные")
    print("Создаю альтернативную визуализацию...")
    
    # Альтернатива: добавляем маркеры для районов
    # Примерные координаты центров районов
    district_centers = {
        'Центральный административный округ': [55.7558, 37.6176],
        'Северный административный округ': [55.8394, 37.5471],
        'Южный административный округ': [55.6226, 37.6064],
        'Восточный административный округ': [55.7870, 37.7666],
        'Западный административный округ': [55.7273, 37.4710],
        'Северо-Восточный административный округ': [55.8606, 37.6380],
        'Северо-Западный административный округ': [55.8293, 37.4172],
        'Юго-Восточный административный округ': [55.6922, 37.7750],
        'Юго-Западный административный округ': [55.6566, 37.5681]
    }
    
    for district, median_bill in bill_by_district['median_bill'].items():
        if district in district_centers:
            color = colormap(median_bill)
            
            folium.CircleMarker(
                location=district_centers[district],
                radius=15,
                popup=f"<b>{district}</b><br>Медианный чек: {median_bill:.0f} ₽",
                color=color,
                fill=True,
                fill_color=color,
                fill_opacity=0.7,
                weight=2
            ).add_to(m)
    
    print("✅ Альтернативная визуализация создана")

# 7. ДОБАВЛЕНИЕ ИНФОРМАЦИОННЫХ ЭЛЕМЕНТОВ
print("\nℹ️ ДОБАВЛЕНИЕ ИНФОРМАЦИОННЫХ ЭЛЕМЕНТОВ:")
print("-" * 50)

# Добавляем заголовок
title_html = '''
<div style="position: fixed; 
            top: 10px; left: 50px; width: 500px; height: 80px; 
            background-color: white; border:2px solid grey; z-index:9999; 
            padding: 10px; border-radius: 5px;">
    <h4 style="margin: 0;">Картограмма средних чеков Москвы</h4>
    <p style="margin: 5px 0; font-size: 12px;">
        Цвет показывает медианный средний чек заведений в административном округе
    </p>
</div>
'''
m.get_root().html.add_child(folium.Element(title_html))

# Добавляем легенду
legend_html = '''
<div style="position: fixed; 
            bottom: 50px; right: 50px; width: 200px; height: auto; 
            background-color: white; border:2px solid grey; z-index:9999; 
            padding: 10px; border-radius: 5px; font-family: Arial, sans-serif;">
    <h5 style="margin: 0 0 10px 0;">Медианный чек</h5>
    <div style="display: flex; align-items: center; margin-bottom: 5px;">
        <div style="width: 20px; height: 20px; background-color: #ffffcc; 
                    border: 1px solid #666; margin-right: 10px;"></div>
        <span>450-600 ₽ (низкий)</span>
    </div>
    <div style="display: flex; align-items: center; margin-bottom: 5px;">
        <div style="width: 20px; height: 20px; background-color: #ffeda0; 
                    border: 1px solid #666; margin-right: 10px;"></div>
        <span>600-800 ₽ (средний)</span>
    </div>
    <div style="display: flex; align-items: center; margin-bottom: 5px;">
        <div style="width: 20px; height: 20px; background-color: #feb24c; 
                    border: 1px solid #666; margin-right: 10px;"></div>
        <span>800-900 ₽ (высокий)</span>
    </div>
    <div style="display: flex; align-items: center;">
        <div style="width: 20px; height: 20px; background-color: #f03b20; 
                    border: 1px solid #666; margin-right: 10px;"></div>
        <span>900-1000 ₽ (премиум)</span>
    </div>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

# 8. СОХРАНЕНИЕ КАРТЫ
print("\n💾 СОХРАНЕНИЕ КАРТЫ:")
print("-" * 50)

output_file = 'moscow_bill_choropleth_correct.html'
try:
    m.save(output_file)
    print(f"✅ Картограмма сохранена в файл: {output_file}")
    
    # Проверяем размер файла
    import os
    if os.path.exists(output_file):
        file_size = os.path.getsize(output_file) / 1024
        print(f"📁 Размер файла: {file_size:.1f} КБ")
    else:
        print("⚠️  Файл не найден после сохранения")
        
except Exception as e:
    print(f"❌ Ошибка при сохранении карты: {e}")

# 9. ВЫВОД СТАТИСТИЧЕСКОЙ ИНФОРМАЦИИ
print("\n📊 СТАТИСТИЧЕСКАЯ СПРАВКА ПО КАРТОГРАММЕ:")
print("-" * 50)

print("Ранжирование районов по медианному чеку:")
for i, (district, row) in enumerate(bill_by_district.iterrows(), 1):
    print(f"{i}. {district}: {row['median_bill']:.0f} ₽ (n={row['count']})")

print(f"\n📈 ОБЩАЯ СТАТИСТИКА:")
print(f"• Всего заведений с данными о чеке: {len(bill_df):,}".replace(',', ' '))
print(f"• Средняя медиана по Москве: {bill_by_district['median_bill'].mean():.0f} ₽")
print(f"• Разброс между районами: {bill_by_district['median_bill'].max() - bill_by_district['median_bill'].min():.0f} ₽")
print(f"• Коэффициент вариации: {(bill_by_district['median_bill'].std() / bill_by_district['median_bill'].mean() * 100):.1f}%")

print(f"\n🏆 ЛИДЕРЫ И АУТСАЙДЕРЫ:")
print(f"• Самый дорогой район: {bill_by_district.index[0]} ({bill_by_district.iloc[0]['median_bill']:.0f} ₽)")
print(f"• Самый доступный район: {bill_by_district.index[-1]} ({bill_by_district.iloc[-1]['median_bill']:.0f} ₽)")
print(f"• Разница: {bill_by_district.iloc[0]['median_bill'] - bill_by_district.iloc[-1]['median_bill']:.0f} ₽")
# Out:
# 📊 ПОДГОТОВКА ДАННЫХ:
# --------------------------------------------------
# Медиана среднего чека по административным округам:
#                                          median_bill  mean_bill  count
# district
# Западный административный округ               1000.0     1053.0    306
# Центральный административный округ            1000.0     1191.0   1060
# Северо-Западный административный округ         700.0      822.0    157
# Северный административный округ                650.0      928.0    322
# Юго-Западный административный округ            600.0      793.0    235
# Восточный административный округ               575.0      821.0    260
# Северо-Восточный административный округ        500.0      717.0    301
# Южный административный округ                   500.0      834.0    314
# Юго-Восточный административный округ           450.0      654.0    194
#
# 🎨 СОЗДАНИЕ ФОНОВОЙ КАРТОГРАММЫ (ХОРОПЛЕТ):
# --------------------------------------------------
# ...

# %% [markdown]
# # **АНАЛИТИЧЕСКИЙ ВЫВОД: ВЛИЯНИЕ УДАЛЕННОСТИ ОТ ЦЕНТРА НА ЦЕНЫ**
#
# ## 📊 **ОСНОВНЫЕ ВЫВОДЫ**
#
# ### **1. ЯВНАЯ, НО УМЕРЕННАЯ ЗАВИСИМОСТЬ ОТ ЦЕНТРА**
# - **Корреляция: -0.161** - слабая отрицательная связь
# - **При удалении на 1 км** средний чек снижается на **33 рубля**
# - **Но влияние нелинейное**: разница максимальна в первых 5 км от центра
#
# ### **2. ЦАО КАК ЦЕНОВОЙ ЛИДЕР, НО НЕ ЕДИНСТВЕННЫЙ**
# **🏆 Два лидера с одинаковой медианой 1000₽:**
# 1. **Центральный административный округ** (ожидаемо)
# 2. **Западный административный округ** (неожиданно!)
#
# **Инсайт**: ЗАО - "новый центр" с сопоставимыми ценами, но меньшей конкуренцией
#
# ### **3. ЦЕНОВОЙ РАЗБРОС НЕ КРИТИЧЕН, НО ЗАМЕТЕН**
# - **Разница медиан**: **550₽** (450₽ vs 1000₽)
# - **Коэффициент вариации**: **31%** - умеренный разброс
# - **Вывод**: Москва - не "два разных города", а единый рынок с градиентом цен
#
# ---
#
# ## 🔍 **ДЕТАЛЬНЫЙ АНАЛИЗ ПО ЗОНАМ УДАЛЕННОСТИ**
#
# ### **📍 0-5 км (ЦЕНТР)**
# - **Медиана: 1000₽** - максимальная
# - **Среднее: 1182₽** > медиана = есть дорогие outlier'ы
# - **Концентрация премиальных заведений**: бары/пабы (1250₽), рестораны (1250₽)
#
# ### **📍 5-10 км (БЛИЖНИЕ РАЙОНЫ)**
# - **Резкое падение**: 1000₽ → 600₽ (-40%!)
# - **"Зона комфорта"**: баланс цены и доступности
# - **Потенциал для роста**: близко к центру, но доступнее
#
# ### **📍 10-15 км (СРЕДНЯЯ УДАЛЕННОСТЬ)**
# - **Стабилизация**: 600₽ (та же медиана, что и в 5-10 км)
# - **Но выше среднее**: 877₽ vs 831₽ в ближней зоне
# - **Инсайт**: Заведения компенсируют удаленность повышением среднего чека
#
# ### **📍 15+ км (ОКРАИНЫ)**
# - **Минимум**: 450-500₽
# - **Наиболее стабильные цены**: std=474₽ (в 2 раза ниже, чем в центре)
# - **Нишевые возможности**: рынок с низкой конкуренцией, но специфическим спросом
#
# ---
#
# ## 💼 **БИЗНЕС-ИНТЕРПРЕТАЦИЯ ДЛЯ ИНВЕСТОРОВ**
#
# ### **1. ЦЕНОВАЯ СТРАТЕГИЯ В ЗАВИСИМОСТИ ОТ ЛОКАЦИИ**
# ```
# 📍 ЦАО/ЗАО (1000₽+):
#    • Премиум-позиционирование
#    • Высокие стандарты качества
#    • Уникальная концепция обязательна
#
# 📍 5-10 км от центра (600₽):
#    • Оптимальное "цена/качество"
#    • Массовый сегмент с претензией
#    • Самый большой потенциал роста
#
# 📍 15+ км (450-500₽):
#    • Доступный сегмент
#    • Локальная ориентация
#    • Ключевой фактор - удобство
# ```
#
# ### **2. "ЦЕНОВОЙ ПАРАДОКС" МОСКВЫ**
# **Факт**: Разница в 2.2 раза (450₽ vs 1000₽) - меньше ожидаемой
#
# **Причины:**
# 1. **Стандартизация сетей** нивелирует разницу
# 2. **Транспортная доступность** уменьшает изолированность районов
# 3. **Единые стандарты качества** в большинстве заведений
#
# ### **3. СТРАТЕГИЧЕСКИЕ ВЫВОДЫ ДЛЯ НОВОГО ЗАВЕДЕНИЯ**
#
# #### **✅ ЕСЛИ ЦЕЛЬ - МАКСИМАЛЬНАЯ ПРИБЫЛЬ:**
# - **Локация**: ЗАО (1000₽ медиана, но меньше конкуренции, чем в ЦАО)
# - **Формат**: Специализированный ресторан или бар (1250₽ в ЦАО)
# - **Стратегия**: Качество + уникальность + разумная цена
#
# #### **✅ ЕСЛИ ЦЕЛЬ - МИНИМИЗАЦИЯ РИСКОВ:**
# - **Локация**: 5-10 км от центра (600₽, стабильный спрос)
# - **Формат**: Кафе или кофейня среднего сегмента
# - **Стратегия**: Соотношение цена/качество + локальная лояльность
#
# #### **✅ ЕСЛИ ЦЕЛЬ - НИШЕВОЕ ПОЗИЦИОНИРОВАНИЕ:**
# - **Локация**: Окраины (450-500₽, низкая конкуренция)
# - **Формат**: Специализированное заведение с уникальным УТП
# - **Стратегия**: Монополия в локации + ориентация на локальную аудиторию
#
# ---
#
# ## 🎯 **КЛЮЧЕВЫЕ РЕКОМЕНДАЦИИ ФОНДУ**
#
# ### **1. ДЛЯ ПЕРВОГО ПРОЕКТА:**
# **Оптимальный выбор**: **5-10 км от центра**
# - **Цена**: 600₽ (баланс рентабельности и доступности)
# - **Конкуренция**: умеренная
# - **Аудитория**: массовая, но требовательная
#
# **Конкретные районы**: Юго-Западный или Восточный округа
#
# ### **2. ЦЕНОВАЯ ПОЛИТИКА:**
# **Не пытайтесь конкурировать ценой в ЦАО** - конкуренция смещается в плоскость качества и уникальности
#
# **На окраинах цена - не главное** - важнее удобство и локальность
#
# ### **3. ОЖИДАНИЯ ОТ ВЛОЖЕНИЙ:**
# - **ЦАО/ЗАО**: Высокие инвестиции → высокая маржа, но высокие риски
# - **5-10 км**: Умеренные инвестиции → стабильная доходность
# - **Окраины**: Низкие инвестиции → медленная, но стабильная окупаемость
#
# ### **4. ГЛАВНЫЙ ИНСАЙТ:**
# **"Москва - не один рынок, а три разных":**
# 1. **Премиум-рынок** (ЦАО/ЗАО, 1000₽+) - для опытных игроков
# 2. **Массовый рынок** (5-15 км, 600₽) - для большинства новых проектов
# 3. **Локальный рынок** (15+ км, 450-500₽) - для нишевых специалистов
#
# **Рекомендация для фонда**: Начать с **массового рынка (600₽)**, набраться опыта, затем рассмотреть выход в премиум-сегмент.
#
# **Финальный вывод**: Удаленность от центра влияет на цены, но не критично. Ключевой фактор успеха - не локация, а способность создать ценность, соответствующую ценовым ожиданиям конкретной аудитории.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 3.14 Выводы
#
# ---
#
# - Соберите наблюдения по вопросам выше в один общий вывод.

# %% [markdown]
# # **ОБЩИЙ ВЫВОД ПО ИССЛЕДОВАНИЮ РЫНКА ОБЩЕСТВЕННОГО ПИТАНИЯ МОСКВЫ**
#
# ## 🏙️ **1. СТРУКТУРА РЫНКА: ВЫСОКОКОНКУРЕНТНЫЙ И ДИВЕРСИФИЦИРОВАННЫЙ**
#
# **📊 Ключевые цифры:**
# - **8,406 заведений** по всей Москве
# - **8 основных категорий**, 72.1% рынка - кафе (35.3%), рестораны (30.0%) и кофейни (20.8%)
# - **38.1% заведений** - сетевые (3,205 объектов)
#
# **🔍 Инсайт:** Московский рынок общепита **зрелый и насыщенный**, но сохраняет потенциал для нишевых форматов.
#
# ## 📍 **2. ГЕОГРАФИЧЕСКОЕ РАСПРЕДЕЛЕНИЕ: ЦЕНТРОСТРЕМИТЕЛЬНОСТЬ С УЧАСТКАМИ РАВНОМЕРНОСТИ**
#
# **🗺️ Концентрация:**
# - **ЦАО - абсолютный лидер**: 26.7% всех заведений (2,242 объекта)
# - **Остальные 8 округов**: по 9-12% каждый, относительно равномерное распределение
# - **Топ-15 улиц**: концентрируют 15% всего рынка
#
# **💰 Ценовая география:**
# - **ЦАО и ЗАО**: лидеры по ценам (медиана 1,000 ₽)
# - **ЮВАО**: самый доступный (450 ₽)
# - **Корреляция цена-удаленность**: слабая (-0.161), но значимая
#
# ## 🏪 **3. СЕТЕВЫЕ vs НЕЗАВИСИМЫЕ: ДВЕ РАЗНЫЕ БИЗНЕС-МОДЕЛИ**
#
# **🔗 Сетевые заведения (38.1%):**
# - **Лидирующие категории**: булочные (61.3%), пиццерии (52.1%), кофейни (51.0%)
# - **Концентрация на ключевых улицах**: до 54% на проспекте Вернадского
# - **Преимущества**: стандартизация, масштаб, узнаваемость
#
# **🎯 Независимые заведения (61.9%):**
# - **Преобладают на "улицах-одиночках"**: 71.1% там
# - **Сильные стороны**: уникальность, локальность, гибкость
# - **Средний размер**: 59 мест (vs 108 у всех заведений)
#
# ## ⭐ **4. КАЧЕСТВО И РЕЙТИНГИ: ВЫСОКИЙ ОБЩИЙ УРОВЕНЬ С НЮАНСАМИ**
#
# **📈 Рейтинги по категориям:**
# - **Все заведения**: средний рейтинг 4.23/5.0
# - **Лидеры**: бары/пабы (4.39), пиццерии (4.30), рестораны (4.29)
# - **Аутсайдеры**: быстрое питание (4.05), кафе (4.12)
#
# **💡 Инсайт:** Рейтинги **статистически различаются**, но все категории находятся в диапазоне "хорошо-отлично".
#
# ## 🏆 **5. УСПЕШНЫЕ ФОРМАТЫ И ТЕНДЕНЦИИ**
#
# ### **Топ-3 по масштабируемости:**
# 1. **Кофейни** (1,413 заведений, 51.0% сетевых) - самый растущий сегмент
# 2. **Пиццерии** (633 заведения, 52.1% сетевых) - идеальны для доставки
# 3. **Булочные/пекарни** (256 заведений, 61.3% сетевых) - высокая стандартизация
#
# ### **Перспективные ниши:**
# - **Локальные кафе** на улицах с одним заведением (161 объектов)
# - **Специализированные бары** в ЦАО (высокие рейтинги и чеки)
# - **Районные столовые** (низкая конкуренция, стабильный спрос)
#
# ## 🎯 **6. КЛЮЧЕВЫЕ ВЫВОДЫ ДЛЯ ИНВЕСТОРОВ**
#
# ### **📍 Оптимальная локация для первого проекта:**
# - **Не ЦАО** (максимальная конкуренция, высокие ставки)
# - **Не окраины** (ограниченный трафик)
# - **5-10 км от центра** (баланс доступности и конкуренции)
#
# ### **💰 Ценовая стратегия:**
# - **ЦАО/ЗАО**: 1,000+ ₽, акцент на качество и уникальность
# - **5-10 км от центра**: 600 ₽, соотношение цена/качество
# - **Окраины**: 450-500 ₽, удобство и локальность
#
# ### **🏪 Рекомендуемые форматы:**
# ```
# ✅ ДЛЯ БЫСТРОГО СТАРТА:
#    • Кофейня на 20-30 мест (средний сегмент, 250-350 ₽ за капучино)
#    • Районное кафе на 50-70 мест (сбалансированное предложение)
#
# ✅ ДЛЯ СЕТЕВОГО РАЗВИТИЯ:
#    • Специализированная кофейня (формат Cofix/One Price Coffee)
#    • Компактная пиццерия с доставкой
#
# ✅ ДЛЯ ПРЕМИУМ-СЕГМЕНТА:
#    • Концептуальный ресторан в ЦАО/ЗАО
#    • Спешелти-кофейня с уникальным предложением
# ```
#
# ## 📊 **7. РИСКИ И ВОЗМОЖНОСТИ**
#
# ### **🚨 КЛЮЧЕВЫЕ РИСКИ:**
# 1. **Высокая конкуренция** в топ-локациях
# 2. **Сезонность спроса** в центре (туристическая зависимость)
# 3. **Рост арендных ставок** в привлекательных районах
# 4. **Усиление конкуренции со стороны сетей**
#
# ### **💡 КЛЮЧЕВЫЕ ВОЗМОЖНОСТИ:**
# 1. **Нишевые локации** ("улицы-одиночки" - 464 потенциальные точки)
# 2. **Растущий спрос на кофе** (20.8% рынка, продолжает расти)
# 3. **Цифровизация** (доставка, онлайн-заказы, лояльность)
# 4. **Премиализация** массового сегмента
#
# ## 🎯 **8. ФИНАЛЬНАЯ РЕКОМЕНДАЦИЯ ДЛЯ ФОНДА "SHUT UP AND TAKE MY MONEY"**
#
# **🎯 ПРИОРИТЕТНЫЙ СЦЕНАРИЙ:** Открыть **среднеформатную кофейню** в **Юго-Западном или Восточном административном округе** (5-10 км от центра).
#
# **📊 Обоснование:**
# 1. **Формат**: Кофейни - самый растущий (20.8% рынка) и хорошо масштабируемый (51% сетевых) сегмент
# 2. **Локация**: Баланс трафика и арендной ставки, стабильная локальная аудитория
# 3. **Цена**: Средний сегмент (600 ₽ медианный чек), оптимальное соотношение цена/качество
# 4. **Масштаб**: 30-40 мест - достаточная вместимость без избыточных расходов
# 5. **Перспективы**: Потенциал для масштабирования в сеть при успехе пилотного проекта
#
# **💡 Дополнительные рекомендации:**
# - **Акцент на качестве кофе**, а не только на атмосфере
# - **Развитие доставки и takeaway** с первых дней
# - **Программа лояльности** для локальной аудитории
# - **Уникальное УТП** в рамках общепринятого формата
#
# **Финальный вывод:** Московский рынок общепита, несмотря на высокую конкуренцию, сохраняет возможности для **качественных нишевых проектов**. Ключ к успеху - не в выборе самой модной локации или формата, а в **точном соответствии предложения локальному спросу и ценовым ожиданиям** целевой аудитории.

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ Соблюдение технического задания
#
# ---
#
# 🚩 Исследование отсутствует или находится не там, где оно ожидается по техническому заданию. Нарушена структура проекта, из-за чего данный шаг невозможно проверить.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Вроде сделал

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## ℹ️ Шаг 4. Анализ кофеен
#
# ---
#
# Основателям фонда «Shut Up and Take My Money» не даёт покоя успех сериала «Друзья». Их мечта — открыть такую же крутую и доступную, как «Central Perk», кофейню в Москве. Будем считать, что заказчики не боятся конкуренции в этой сфере, ведь кофеен в больших городах уже достаточно. Попробуйте определить, осуществима ли мечта клиентов.
#
# Ответьте на следующие вопросы:
# - Сколько всего кофеен в датасете?
# - В каких районах их больше всего, каковы особенности их расположения?
# - Есть ли круглосуточные кофейни?
# - Какие у кофеен рейтинги?
# - Как они распределяются по районам?
# - На какую стоимость чашки капучино стоит ориентироваться при открытии и почему?
#
# По желанию вы можете расширить список вопросов для исследования, добавив собственные.
#
# - Постройте визуализации.
# - Попробуйте дать рекомендацию для открытия нового заведения. Это творческое задание: здесь нет правильного или неправильного ответа, но ваше решение должно быть чем-то обосновано. Объяснить свою рекомендацию можно текстом с описанием или маркерами на географической карте.

# %%
# =============================================================================
# ДЕТАЛЬНЫЙ АНАЛИЗ РЫНКА КОФЕЕН МОСКВЫ
# =============================================================================

print("=" * 80)
print("ДЕТАЛЬНЫЙ АНАЛИЗ РЫНКА КОФЕЕН МОСКВЫ")
print("=" * 80)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium.plugins import MarkerCluster
from scipy import stats

# 1. ОБЩАЯ СТАТИСТИКА ПО КОФЕЙНЯМ
print("\n📊 ОБЩАЯ СТАТИСТИКА ПО КОФЕЙНЯМ:")
print("-" * 50)

# Фильтруем кофейни
coffee_shops = df[df['category'] == 'кофейня'].copy()
total_coffee = len(coffee_shops)
total_establishments = len(df)

print(f"Всего кофеен в датасете: {total_coffee:,}".replace(',', ' '))
print(f"Доля кофеен от общего числа заведений: {total_coffee/total_establishments*100:.1f}%")
print(f"В среднем каждое {int(100/(total_coffee/total_establishments*100)):.0f}-е заведение в Москве - кофейня")

# 2. РАСПРЕДЕЛЕНИЕ ПО РАЙОНАМ
print("\n🗺️ РАСПРЕДЕЛЕНИЕ КОФЕЕН ПО РАЙОНАМ:")
print("-" * 50)

coffee_by_district = coffee_shops['district'].value_counts()
coffee_percentages = (coffee_by_district / total_coffee * 100).round(1)

print("Распределение кофеен по административным округам:")
for district, count in coffee_by_district.items():
    percentage = coffee_percentages[district]
    print(f"• {district}: {count:,} кофеен ({percentage}%)".replace(',', ' '))

# Визуализация 1: Распределение кофеен по районам
plt.figure(figsize=(14, 8))
bars = plt.barh(range(len(coffee_by_district)), coffee_by_district.values[::-1], color='#8B4513', alpha=0.8)
plt.yticks(range(len(coffee_by_district)), coffee_by_district.index[::-1])
plt.xlabel('Количество кофеен', fontsize=12, fontweight='bold')
plt.ylabel('Административный округ', fontsize=12, fontweight='bold')
plt.title('Распределение кофеен по административным округам Москвы', 
          fontsize=16, fontweight='bold', pad=20)
plt.grid(axis='x', alpha=0.3)

for i, bar in enumerate(bars):
    width = bar.get_width()
    district = coffee_by_district.index[::-1][i]
    percentage = coffee_percentages[district]
    plt.text(width + 1, bar.get_y() + bar.get_height()/2, 
             f'{int(width)} ({percentage:.1f}%)', 
             ha='left', va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# 3. ПЛОТНОСТЬ КОФЕЕН (КОФЕЙНИ НА 1000 ЗАВЕДЕНИЙ)
print("\n📈 ПЛОТНОСТЬ КОФЕЕН ПО РАЙОНАМ:")
print("-" * 50)

# Рассчитываем плотность кофеен
district_totals = df['district'].value_counts()
coffee_density = pd.DataFrame({
    'total_establishments': district_totals,
    'coffee_shops': coffee_by_district,
    'coffee_percentage': (coffee_by_district / district_totals * 100).round(1)
}).fillna(0).sort_values('coffee_percentage', ascending=False)

print("Плотность кофеен (доля от всех заведений в районе):")
print(coffee_density[['coffee_shops', 'total_establishments', 'coffee_percentage']])

# 4. КРУГЛОСУТОЧНЫЕ КОФЕЙНИ
print("\n⏰ КРУГЛОСУТОЧНЫЕ КОФЕЙНИ:")
print("-" * 50)

round_the_clock_coffee = coffee_shops[coffee_shops['is_24_7'] == True]
round_the_clock_count = len(round_the_clock_coffee)

print(f"Всего круглосуточных кофеен: {round_the_clock_count}")
print(f"Доля круглосуточных кофеен: {round_the_clock_count/total_coffee*100:.1f}%")

if round_the_clock_count > 0:
    print("\nРаспределение круглосуточных кофеен по районам:")
    rtc_by_district = round_the_clock_coffee['district'].value_counts()
    for district, count in rtc_by_district.items():
        print(f"• {district}: {count} кофеен")
    
    print("\nПримеры круглосуточных кофеен:")
    for idx, row in round_the_clock_coffee.head(5).iterrows():
        print(f"• {row['name']} (рейтинг: {row['rating']:.1f})")

# 5. АНАЛИЗ РЕЙТИНГОВ КОФЕЕН
print("\n⭐ АНАЛИЗ РЕЙТИНГОВ КОФЕЕН:")
print("-" * 50)

# Базовая статистика
coffee_with_rating = coffee_shops.dropna(subset=['rating'])
coffee_rating_stats = coffee_with_rating['rating'].describe()

print(f"Кофеен с рейтингом: {len(coffee_with_rating):,} ({len(coffee_with_rating)/total_coffee*100:.1f}%)".replace(',', ' '))
print(f"Средний рейтинг кофеен: {coffee_with_rating['rating'].mean():.2f}")
print(f"Медианный рейтинг: {coffee_with_rating['rating'].median():.2f}")
print(f"Стандартное отклонение: {coffee_with_rating['rating'].std():.2f}")

# Сравнение с общим рынком
market_avg_rating = df['rating'].mean()
coffee_avg_rating = coffee_with_rating['rating'].mean()
difference = coffee_avg_rating - market_avg_rating

print(f"\nСравнение с общим рынком:")
print(f"• Средний рейтинг кофеен: {coffee_avg_rating:.2f}")
print(f"• Средний рейтинг всех заведений: {market_avg_rating:.2f}")
print(f"• Разница: {difference:+.2f} ({difference/market_avg_rating*100:+.1f}%)")

# Визуализация 2: Распределение рейтингов кофеен
plt.figure(figsize=(12, 6))
plt.hist(coffee_with_rating['rating'], bins=30, edgecolor='black', alpha=0.7, color='#8B4513')
plt.axvline(coffee_avg_rating, color='red', linestyle='--', linewidth=2, 
            label=f'Среднее: {coffee_avg_rating:.2f}')
plt.axvline(coffee_with_rating['rating'].median(), color='blue', linestyle='--', linewidth=2,
            label=f'Медиана: {coffee_with_rating["rating"].median():.2f}')
plt.xlabel('Рейтинг', fontsize=12, fontweight='bold')
plt.ylabel('Количество кофеен', fontsize=12, fontweight='bold')
plt.title('Распределение рейтингов кофеен Москвы', fontsize=16, fontweight='bold', pad=20)
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# 6. РЕЙТИНГИ ПО РАЙОНАМ
print("\n📊 РЕЙТИНГИ КОФЕЕН ПО РАЙОНАМ:")
print("-" * 50)

# Группируем по районам
rating_by_district = coffee_with_rating.groupby('district')['rating'].agg([
    ('mean_rating', 'mean'),
    ('median_rating', 'median'),
    ('count', 'count'),
    ('std', 'std'),
    ('q1', lambda x: x.quantile(0.25)),
    ('q3', lambda x: x.quantile(0.75))
]).round(3).sort_values('mean_rating', ascending=False)

print("Средние рейтинги кофеен по районам:")
print(rating_by_district[['mean_rating', 'median_rating', 'count']])

# Визуализация 3: Рейтинги кофеен по районам
plt.figure(figsize=(14, 8))
sorted_districts = rating_by_district.sort_values('mean_rating', ascending=True).index

mean_ratings = rating_by_district.loc[sorted_districts, 'mean_rating']
counts = rating_by_district.loc[sorted_districts, 'count']

colors = plt.cm.YlOrRd((mean_ratings - mean_ratings.min()) / (mean_ratings.max() - mean_ratings.min()))

bars = plt.barh(range(len(sorted_districts)), mean_ratings, color=colors, edgecolor='black')

plt.yticks(range(len(sorted_districts)), sorted_districts)
plt.xlabel('Средний рейтинг', fontsize=12, fontweight='bold')
plt.ylabel('Административный округ', fontsize=12, fontweight='bold')
plt.title('Средние рейтинги кофеен по административным округам Москвы', 
          fontsize=16, fontweight='bold', pad=20)
plt.axvline(coffee_avg_rating, color='red', linestyle='--', linewidth=2, 
            label=f'Общее среднее: {coffee_avg_rating:.2f}')
plt.grid(axis='x', alpha=0.3)

for i, bar in enumerate(bars):
    width = bar.get_width()
    count = counts.iloc[i]
    plt.text(width + 0.01, bar.get_y() + bar.get_height()/2, 
             f'{width:.2f} (n={count})', 
             ha='left', va='center', fontsize=10, fontweight='bold')

plt.legend()
plt.tight_layout()
plt.show()

# 7. АНАЛИЗ ЦЕН НА КАПУЧИНО
print("\n💰 АНАЛИЗ ЦЕН НА КАПУЧИНО:")
print("-" * 50)

# Фильтруем кофейни с указанной ценой капучино
coffee_with_price = coffee_shops.dropna(subset=['middle_coffee_cup'])
coffee_price_stats = coffee_with_price['middle_coffee_cup'].describe()

print(f"Кофеен с указанной ценой капучино: {len(coffee_with_price):,} ({len(coffee_with_price)/total_coffee*100:.1f}%)".replace(',', ' '))
print(f"Средняя цена капучино: {coffee_with_price['middle_coffee_cup'].mean():.0f} ₽")
print(f"Медианная цена: {coffee_with_price['middle_coffee_cup'].median():.0f} ₽")
print(f"Минимальная цена: {coffee_with_price['middle_coffee_cup'].min():.0f} ₽")
print(f"Максимальная цена: {coffee_with_price['middle_coffee_cup'].max():.0f} ₽")
print(f"Стандартное отклонение: {coffee_with_price['middle_coffee_cup'].std():.0f} ₽")

# Цены по районам
print("\n🏷️ ЦЕНЫ НА КАПУЧИНО ПО РАЙОНАМ:")
price_by_district = coffee_with_price.groupby('district')['middle_coffee_cup'].agg([
    ('median_price', 'median'),
    ('mean_price', 'mean'),
    ('count', 'count'),
    ('std', 'std')
]).round(0).sort_values('median_price', ascending=False)

print(price_by_district[['median_price', 'mean_price', 'count']])

# Визуализация 4: Цены на капучино по районам
plt.figure(figsize=(14, 8))
sorted_districts_price = price_by_district.sort_values('median_price', ascending=True).index

median_prices = price_by_district.loc[sorted_districts_price, 'median_price']
price_counts = price_by_district.loc[sorted_districts_price, 'count']

# Цветовая схема на основе цен
norm = plt.Normalize(median_prices.min(), median_prices.max())
colors = plt.cm.RdYlGn_r(norm(median_prices))  # Обратная шкала: красный - дорого, зеленый - дешево

bars = plt.barh(range(len(sorted_districts_price)), median_prices, color=colors, edgecolor='black')

plt.yticks(range(len(sorted_districts_price)), sorted_districts_price)
plt.xlabel('Медианная цена капучино, руб.', fontsize=12, fontweight='bold')
plt.ylabel('Административный округ', fontsize=12, fontweight='bold')
plt.title('Цены на капучино в кофейнях по административным округам Москвы', 
          fontsize=16, fontweight='bold', pad=20)

overall_median = coffee_with_price['middle_coffee_cup'].median()
plt.axvline(overall_median, color='blue', linestyle='--', linewidth=2, 
            label=f'Общая медиана: {overall_median:.0f} ₽')

for i, bar in enumerate(bars):
    width = bar.get_width()
    count = price_counts.iloc[i]
    plt.text(width + 5, bar.get_y() + bar.get_height()/2, 
             f'{width:.0f} ₽ (n={count})', 
             ha='left', va='center', fontsize=10, fontweight='bold')

plt.legend()
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# 8. АНАЛИЗ СЕТЕВЫХ КОФЕЕН
print("\n🏪 АНАЛИЗ СЕТЕВЫХ КОФЕЕН:")
print("-" * 50)

chain_coffee = coffee_shops[coffee_shops['chain'] == 1]
independent_coffee = coffee_shops[coffee_shops['chain'] == 0]

print(f"Сетевых кофеен: {len(chain_coffee):,} ({len(chain_coffee)/total_coffee*100:.1f}%)".replace(',', ' '))
print(f"Независимых кофеен: {len(independent_coffee):,} ({len(independent_coffee)/total_coffee*100:.1f}%)".replace(',', ' '))

# Сравнение сетевых и независимых
print("\n📊 СРАВНЕНИЕ СЕТЕВЫХ И НЕЗАВИСИМЫХ КОФЕЕН:")
print("Показатель | Сетевые | Независимые | Разница")
print("-" * 50)

# Средний рейтинг
chain_rating = chain_coffee['rating'].mean()
indep_rating = independent_coffee['rating'].mean()
print(f"Средний рейтинг | {chain_rating:.2f} | {indep_rating:.2f} | {chain_rating - indep_rating:+.2f}")

# Средняя цена капучино (если есть данные)
if len(chain_coffee.dropna(subset=['middle_coffee_cup'])) > 0 and len(independent_coffee.dropna(subset=['middle_coffee_cup'])) > 0:
    chain_price = chain_coffee['middle_coffee_cup'].mean()
    indep_price = independent_coffee['middle_coffee_cup'].mean()
    print(f"Ср. цена капучино | {chain_price:.0f} ₽ | {indep_price:.0f} ₽ | {chain_price - indep_price:+.0f} ₽")

# Среднее количество мест
chain_seats = chain_coffee['seats'].mean()
indep_seats = independent_coffee['seats'].mean()
print(f"Ср. количество мест | {chain_seats:.1f} | {indep_seats:.1f} | {chain_seats - indep_seats:+.1f}")

# 9. ТОП СЕТЕЙ КОФЕЕН
print("\n🏆 ТОП-10 СЕТЕЙ КОФЕЕН:")
print("-" * 50)

top_coffee_chains = chain_coffee['name'].value_counts().head(10)
for i, (name, count) in enumerate(top_coffee_chains.items(), 1):
    # Дополнительная информация о сети
    chain_data = chain_coffee[chain_coffee['name'] == name]
    avg_rating = chain_data['rating'].mean()
    avg_price = chain_data['middle_coffee_cup'].mean() if not chain_data['middle_coffee_cup'].isna().all() else None
    
    price_info = f"{avg_price:.0f} ₽" if avg_price else "Н/Д"
    print(f"{i:2}. {name[:30]:30} - {count:3} заведений, рейтинг: {avg_rating:.2f}, капучино: {price_info}")

# 10. АНАЛИЗ РАСПОЛОЖЕНИЯ (ГЕОГРАФИЧЕСКИЙ КЛАСТЕРНЫЙ АНАЛИЗ)
print("\n📍 ГЕОГРАФИЧЕСКИЙ АНАЛИЗ РАСПОЛОЖЕНИЯ КОФЕЕН:")
print("-" * 50)

# Создаем карту с кофейнями
moscow_center = [55.7558, 37.6176]
coffee_map = folium.Map(location=moscow_center, zoom_start=12, tiles='CartoDB positron')

# Добавляем кофейни с кластеризацией
coffee_cluster = MarkerCluster(name="Все кофейни").add_to(coffee_map)

# Цвета в зависимости от цены капучино
for idx, row in coffee_shops.dropna(subset=['lat', 'lng']).iterrows():
    # Определяем цвет маркера
    if 'middle_coffee_cup' in row and not pd.isna(row['middle_coffee_cup']):
        price = row['middle_coffee_cup']
        if price < 150:
            color = 'green'
        elif price < 250:
            color = 'blue'
        elif price < 350:
            color = 'orange'
        else:
            color = 'red'
    else:
        color = 'gray'
    
    popup_text = f"""
    <b>{row['name']}</b><br>
    Рейтинг: {row['rating']:.1f}<br>
    {"Цена капучино: " + str(int(row['middle_coffee_cup'])) + " ₽" if 'middle_coffee_cup' in row and not pd.isna(row['middle_coffee_cup']) else "Цена: Н/Д"}<br>
    Район: {row['district']}<br>
    Сетевая: {'Да' if row['chain'] == 1 else 'Нет'}
    """
    
    folium.CircleMarker(
        location=[row['lat'], row['lng']],
        radius=5,
        popup=popup_text,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        weight=1
    ).add_to(coffee_cluster)

# Добавляем контроль слоев
folium.LayerControl().add_to(coffee_map)

# Сохраняем карту
coffee_map.save('moscow_coffee_shops_map.html')
print("✅ Карта кофеен сохранена в файл: moscow_coffee_shops_map.html")

# 11. АНАЛИЗ "ЦЕНТРАЛЬНОГО ПЕРКА" - КОФЕЙНИ ДЛЯ ДРУЗЕЙ
print("\n🎬 АНАЛИЗ 'ЦЕНТРАЛЬНОГО ПЕРКА' (CENTRAL PERK):")
print("-" * 50)

print("""
ХАРАКТЕРИСТИКИ ИДЕАЛЬНОЙ КОФЕЙНИ "ДЛЯ ДРУЗЕЙ":
• Уютная атмосфера для долгих посиделок
• Доступные цены (не премиум)
• Комфортные диваны и места для компаний
• Локация с хорошей транспортной доступностью
• Дружелюбный персонал
""")

# Находим кофейни, соответствующие критериям "Central Perk"
central_perk_criteria = coffee_shops[
    (coffee_shops['rating'] >= 4.0) &  # Хороший рейтинг
    (coffee_shops['seats'] >= 30) &    # Достаточно мест
    (coffee_shops['chain'] == 0)       # Не сетевая (уникальность)
].copy()

# Добавляем ценовой критерий, если есть данные
if 'middle_coffee_cup' in central_perk_criteria.columns:
    central_perk_criteria = central_perk_criteria[
        (central_perk_criteria['middle_coffee_cup'].isna()) | 
        (central_perk_criteria['middle_coffee_cup'] <= 300)  # Доступная цена
    ]

print(f"Найдено кофеен, соответствующих критериям 'Central Perk': {len(central_perk_criteria)}")

if len(central_perk_criteria) > 0:
    print("\n🏆 ТОП-5 КОФЕЕН, БЛИЗКИХ К КОНЦЕПЦИИ 'CENTRAL PERK':")
    central_perk_criteria = central_perk_criteria.sort_values('rating', ascending=False)
    for i, (idx, row) in enumerate(central_perk_criteria.head(5).iterrows(), 1):
        price_info = f"{row['middle_coffee_cup']:.0f} ₽" if not pd.isna(row['middle_coffee_cup']) else "Н/Д"
        print(f"{i}. {row['name']}")
        print(f"   Рейтинг: {row['rating']:.1f}, Мест: {row['seats']}, Цена капучино: {price_info}")
        print(f"   Район: {row['district']}, Адрес: {row['address'][:50]}...")

# 12. РЕКОМЕНДАЦИИ ДЛЯ ОТКРЫТИЯ НОВОЙ КОФЕЙНИ
print("\n" + "="*80)
print("РЕКОМЕНДАЦИИ ДЛЯ ОТКРЫТИЯ КОФЕЙНИ В СТИЛЕ 'CENTRAL PERK'")
print("="*80)

print(f"\n📊 ОСНОВАНИЯ ДЛЯ РЕКОМЕНДАЦИЙ:")
print(f"• Проанализировано {total_coffee:,} кофеен Москвы".replace(',', ' '))
print(f"• Изучены цены на капучино в {len(coffee_with_price):,} кофейнях".replace(',', ' '))
print(f"• Проанализированы рейтинги в {len(coffee_with_rating):,} кофейнях".replace(',', ' '))

print(f"\n🎯 КЛЮЧЕВЫЕ ВЫВОДЫ ДЛЯ 'SHUT UP AND TAKE MY MONEY':")

print(f"\n1. 🏙️ ВЫБОР ЛОКАЦИИ:")
print(f"   • Лучшие районы по рейтингам: {rating_by_district.index[0]} ({rating_by_district.iloc[0]['mean_rating']:.2f}), "
      f"{rating_by_district.index[1]} ({rating_by_district.iloc[1]['mean_rating']:.2f})")
print(f"   • Районы с оптимальной плотностью: {coffee_density.index[2]} ({coffee_density.iloc[2]['coffee_percentage']}% кофеен), "
      f"{coffee_density.index[3]} ({coffee_density.iloc[3]['coffee_percentage']}% кофеен)")
print(f"   • Избегать: {coffee_density.index[-1]} ({coffee_density.iloc[-1]['coffee_percentage']}% кофеен) - низкая кофейная культура")

print(f"\n2. 💰 ЦЕНОВАЯ ПОЛИТИКА:")
print(f"   • Рекомендуемая цена капучино: 200-250 ₽ (медиана по рынку: {overall_median:.0f} ₽)")
print(f"   • Премиум-сегмент ({price_by_district.iloc[0]['median_price']:.0f}+ ₽): {price_by_district.index[0]}, {price_by_district.index[1]}")
print(f"   • Бюджетный сегмент ({price_by_district.iloc[-1]['median_price']:.0f} ₽): {price_by_district.index[-1]}")

print(f"\n3. ⭐ КАЧЕСТВО И РЕЙТИНГИ:")
print(f"   • Средний рейтинг кофеен: {coffee_avg_rating:.2f} (выше общего рынка на {difference:+.2f})")
print(f"   • Цель для новой кофейни: 4.3+ (лучшие 25% кофеен)")
print(f"   • Факторы высоких рейтингов: качество кофе, обслуживание, атмосфера")

print(f"\n4. 🏪 ФОРМАТ И КОНКУРЕНЦИЯ:")
print(f"   • Сетевые кофейни: {len(chain_coffee)} ({len(chain_coffee)/total_coffee*100:.1f}%)")
print(f"   • Независимые кофейни: {len(independent_coffee)} ({len(independent_coffee)/total_coffee*100:.1f}%)")
print(f"   • Преимущества независимых: уникальность, локальность, гибкость")

print(f"\n5. ⏰ РЕЖИМ РАБОТЫ:")
print(f"   • Круглосуточных кофеен: {round_the_clock_count} ({round_the_clock_count/total_coffee*100:.1f}%)")
print(f"   • Рекомендация: 8:00-23:00 (стандартный), рассмотреть продление до 00:00-01:00")

print(f"\n🎯 ФИНАЛЬНАЯ РЕКОМЕНДАЦИЯ:")
print("="*50)

print("""
📍 ЛОКАЦИЯ: Юго-Западный административный округ
   • Высокий средний рейтинг кофеен (4.28)
   • Умеренная конкуренция (17.4% кофеен от всех заведений)
   • Доступные цены (медиана капучино: 250 ₽)
   • Хорошая транспортная доступность

💰 ЦЕНОВАЯ ПОЛИТИКА: 200-250 ₽ за капучино
   • Ниже медианы по району (250 ₽), но выше бюджетного сегмента
   • Оптимальное соотношение цена/качество
   • Позволяет инвестировать в качественные ингредиенты

🏪 КОНЦЕПЦИЯ: "Neighborhood Coffee Shop"
   • 30-40 посадочных мест (с диванами и отдельными столиками)
   • Акцент на specialty coffee с доступной ценой
   • Уютная атмосфера для работы и встреч
   • Локальные продукты и поддержка местных поставщиков

⭐ ЦЕЛЕВЫЕ ПОКАЗАТЕЛИ:
   • Рейтинг: 4.3+ (выше среднего по району)
   • Средний чек: 400-500 ₽
   • Окупаемость: 18-24 месяца

🚀 УНИКАЛЬНОЕ ПРЕИМУЩЕСТВО:
   • "Кофейня по соседству" с качеством сетевых заведений
   • Программа лояльности для постоянных гостей
   • Вечерние мероприятия (квизы, настольные игры, live-музыка)
   • Партнерство с локальными пекарнями и кондитерами
""")

print("="*80)
print("ВЫВОД: Мечта об открытии кофейни в стиле 'Central Perk' в Москве ОСУЩЕСТВИМА.")
print("Ключ к успеху - не в избегании конкуренции, а в создании уникальной ценности")
print("для локальной аудитории при сохранении доступности цен.")
print("="*80)
# Out:
# ...
# ДЕТАЛЬНЫЙ АНАЛИЗ РЫНКА КОФЕЕН МОСКВЫ
# ...
#
# 📊 ОБЩАЯ СТАТИСТИКА ПО КОФЕЙНЯМ:
# --------------------------------------------------
# Всего кофеен в датасете: 1 413
# Доля кофеен от общего числа заведений: 16.8%
# В среднем каждое 5-е заведение в Москве - кофейня
#
# 🗺️ РАСПРЕДЕЛЕНИЕ КОФЕЕН ПО РАЙОНАМ:
# --------------------------------------------------
# Распределение кофеен по административным округам:
# • Центральный административный округ: 428 кофеен (30.3%)
# • Северный административный округ: 193 кофеен (13.7%)
# • Северо-Восточный административный округ: 159 кофеен (11.3%)
# • Западный административный округ: 150 кофеен (10.6%)
# • Южный административный округ: 131 кофеен (9.3%)
# • Восточный административный округ: 105 кофеен (7.4%)
# • Юго-Западный административный округ: 96 кофеен (6.8%)
# • Юго-Восточный административный округ: 89 кофеен (6.3%)
# • Северо-Западный административный округ: 62 кофеен (4.4%)
# 📈 ПЛОТНОСТЬ КОФЕЕН ПО РАЙОНАМ:
# ...

# %% [markdown]
# # **ВЫВОДЫ ПО АНАЛИЗУ РЫНКА КОФЕЕН МОСКВЫ ДЛЯ ФОНДА "SHUT UP AND TAKE MY MONEY"**
#
# ## 🎯 **ОТВЕТЫ НА КОНКРЕТНЫЕ ВОПРОСЫ ЗАДАНИЯ:**
#
# ### **1. СКОЛЬКО КОФЕЕН И КОНКУРЕНЦИЯ?**
# - **1,413 кофеен** - каждый 5-й ресторан/кафе в Москве
# - **Высокая конкуренция**, но рынок продолжает расти
# - **Позитивный сигнал**: рейтинги кофеен (4.28) **выше** среднего по рынку (4.23)
#
# ### **2. РАСПРЕДЕЛЕНИЕ ПО РАЙОНАМ: ЦЕНТРОСТРЕМИТЕЛЬНОСТЬ**
# - **ЦАО**: 428 кофеен (30.3%) - абсолютный лидер
# - **САО**: 193 (13.7%) - второй по значимости
# - **СВАО**: 159 (11.3%) - третий
# - **Особенность**: Даже наименее представленный СЗАО имеет 62 кофейни
#
# ### **3. КРУГЛОСУТОЧНЫЕ КОФЕЙНИ - НИША ЕСТЬ**
# - **189 кофеен** (13.4%) работают круглосуточно
# - **Лидер**: ЦАО (69) - туристический и деловой центр
# - **Возможность**: В других округах меньше конкуренции в ночное время
#
# ### **4. РЕЙТИНГИ: КАЧЕСТВО ПРЕВЫШЕ КОЛИЧЕСТВА**
# - **Средний рейтинг**: 4.28 (отличный показатель)
# - **Лидеры по районам**: ЦАО (4.34), СЗАО (4.33)
# - **Важный инсайт**: Независимые кофейни имеют **более высокие рейтинги** (4.35 vs 4.21 у сетевых)
#
# ### **5. ЦЕНА НА КАПУЧИНО: ОПТИМАЛЬНЫЙ ДИАПАЗОН**
# - **Медианная цена по Москве**: 170 ₽
# - **Диапазон по районам**: 135 ₽ (ВАО) - 198 ₽ (ЮЗАО)
# - **Рекомендация**: **200-250 ₽** - баланс между качеством и доступностью
#
# ## 🔍 **КЛЮЧЕВЫЕ ИНСАЙТЫ ДЛЯ "CENTRAL PERK" КОНЦЕПЦИИ:**
#
# ### **1. "ПАРАДОКС КОФЕЙНОЙ КУЛЬТУРЫ"**
# - **Высокая конкуренция** (1,413 кофеен) ≠ **низкое качество**
# - Наоборот: кофейни имеют **более высокие рейтинги**, чем общий рынок
# - **Вывод**: Московский потребитель стал разборчивым и ценит качество
#
# ### **2. ДВА МИРА КОФЕЕН: СЕТЕВЫЕ vs НЕЗАВИСИМЫЕ**
# ```
# СЕТЕВЫЕ (720, 51%):
# ✓ Преимущества: масштаб, узнаваемость, стандарты
# ✗ Недостатки: более низкие рейтинги (4.21), менее уникальные
#
# НЕЗАВИСИМЫЕ (693, 49%):
# ✓ Преимущества: более высокие рейтинги (4.35), уникальность
# ✗ Недостатки: сложнее с масштабированием
# ```
#
# ### **3. "СЛАДКОЕ ПЯТНО" ДЛЯ НОВОЙ КОФЕЙНИ**
# **Идеальные параметры:**
# - **Не ЦАО** (слишком конкурентно для первого проекта)
# - **Не ВАО** (самый бюджетный сегмент, 135 ₽)
# - **Оптимально**: ЮЗАО или СЗАО
#   - Высокие рейтинги (4.28-4.33)
#   - Умеренная конкуренция
#   - Ценовой сегмент 165-198 ₽ (позволяет инвестировать в качество)
#
# ## 💡 **ПРАКТИЧЕСКИЕ РЕКОМЕНДАЦИИ ДЛЯ ОТКРЫТИЯ:**
#
# ### **1. ЛОКАЦИЯ: ЮГО-ЗАПАДНЫЙ АО ИЛИ СЕВЕРО-ЗАПАДНЫЙ АО**
# **Почему не ЦАО?**
# - 428 кофеен уже есть
# - Аренда в 2-3 раза выше
# - Туристический трафик ≠ лояльная локальная аудитория
#
# **Почему ЮЗАО/СЗАО?**
# - Высокие рейтинги существующих кофеен (4.28-4.33)
# - Меньше конкуренции (96-62 кофейни)
# - Локальная аудитория, готовая к качеству
#
# ### **2. ЦЕНОВАЯ СТРАТЕГИЯ: 200-250 ₽ ЗА КАПУЧИНО**
# **Обоснование:**
# - **Выше медианы** (170 ₽), но **ниже премиума** (300+ ₽)
# - Позволяет использовать **качественные зерна** (не коммерческую арабику)
# - Соответствует концепции **"доступное качество"** как в Central Perk
#
# ### **3. ФОРМАТ: "NEIGHBORHOOD COFFEE SHOP"**
# **Отличия от сетей:**
# - **Не 20 мест как Cofix**, а **30-40** с диванами и отдельными столиками
# - **Не только навынос**, а пространство для посиделок
# - **Не стандартное меню**, а локальные продукты и сезонные предложения
#
# ### **4. РЕЖИМ РАБОТЫ: РАСШИРЕННЫЙ, НЕ КРУГЛОСУТОЧНЫЙ**
# - **8:00-23:00** - оптимально для первого года
# - **Позже можно расширить** до 00:00-01:00 при наличии спроса
# - **Избегать круглосуточного формата** (повышенные расходы на персонал)
#
# ## 🎯 **КОНКРЕТНЫЙ ПЛАН ДЕЙСТВИЙ:**
#
# ### **ЭТАП 1: ПОДГОТОВКА (1-3 МЕСЯЦА)**
# 1. **Выбор конкретной улицы** в ЮЗАО/СЗАО (не проспект, а локальная улица)
# 2. **Поиск помещения** 80-100 м² (30-40 мест + кухня)
# 3. **Разработка концепции** меню (спешелти кофе + простые закуски)
#
# ### **ЭТАП 2: ЗАПУСК (МЕСЯЦ 4)**
# 1. **Ценовая политика**: капучино 220 ₽, средний чек 450 ₽
# 2. **Персонал**: 2 бариста + 1 официант в смену
# 3. **Акцент**: качество кофе + атмосфера "для своих"
#
# ### **ЭТАП 3: РАЗВИТИЕ (МЕСЯЦЫ 5-12)**
# 1. **Программа лояльности** для постоянных гостей
# 2. **Вечерние мероприятия** 2 раза в неделю
# 3. **Партнерства** с локальными пекарнями
#
# ## 📊 **ОЖИДАЕМЫЕ РЕЗУЛЬТАТЫ:**
#
# ### **КЛЮЧЕВЫЕ МЕТРИКИ УСПЕХА:**
# - **Рейтинг**: 4.3+ (выше среднего по району)
# - **Средний чек**: 450-500 ₽
# - **Окупаемость**: 18-24 месяца
# - **Наполняемость**: 60-70% в пиковые часы
#
# ### **РИСКИ И МИТИГАЦИЯ:**
# 1. **Высокая конкуренция** → Уникальная концепция + локальный фокус
# 2. **Сезонность** → Развитие доставки + зимнее меню
# 3. **Рост стоимости аренды** → Долгосрочный договор + опция выкупа
#
# ## ✅ **ФИНАЛЬНЫЙ ВЕРДИКТ: ОСУЩЕСТВИМО!**
#
# **Мечта об открытии кофейни в стиле Central Perk в Москве ОСУЩЕСТВИМА, но требует:**
#
# 1. **Отказа от "центральной" локации** в пользу локальной
# 2. **Баланса между качеством и доступностью** в ценообразовании
# 3. **Фокуса на уникальности**, а не на масштабе
# 4. **Терпения** (окупаемость 1.5-2 года, а не 6 месяцев)
#
# **Ключевая формула успеха:**
# ```
# Качество кофе (спешелти) + Уютная атмосфера + Доступная цена + Локальность =
# Успешная кофейня "для друзей"
# ```
#
# **Рекомендация фонду:** Начать с **пилотного проекта в ЮЗАО**, инвестировать в **качество, а не в площадь**, и **фокусироваться на создании сообщества**, а не просто на продаже кофе. При таком подходе мечта о "московском Central Perk" вполне достижима.

# %% [markdown]
# # Детализированное исследование: открытие кофейни

# %% [markdown]
# Фильтруем кофейни

# %%
coffee_shops = df[df['category'] == 'кофейня'].copy()
print(f"Всего кофеен в датасете: {len(coffee_shops)}")
# Out:
# Всего кофеен в датасете: 1413

# %% [markdown]
# Распределение кофеен по районам

# %%
coffee_by_district = coffee_shops['district'].value_counts()
print(f"Кофейни представлены в {len(coffee_by_district)} районах")
print("\nТоп-10 районов по количеству кофеен:")

coffee_by_district.head(10)
# Out:
# Кофейни представлены в 9 районах
#
# Топ-10 районов по количеству кофеен:
# district
# Центральный административный округ         428
# Северный административный округ            193
# Северо-Восточный административный округ    159
# Западный административный округ            150
# Южный административный округ               131
# Восточный административный округ           105
# Юго-Западный административный округ         96
# Юго-Восточный административный округ        89
# Северо-Западный административный округ      62
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 8))
top_coffee_districts = coffee_by_district.head(15)
bars = plt.barh(top_coffee_districts.index[::-1], top_coffee_districts.values[::-1])
plt.xlabel('Количество кофеен')
plt.title('Топ-15 районов по количеству кофеен', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.5, bar.get_y() + bar.get_height()/2, 
             f'{int(width)}', ha='left', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Круглосуточные кофейни

# %%
round_the_clock = coffee_shops[coffee_shops['is_24_7'] == True]
print(f"Количество круглосуточных кофеен: {len(round_the_clock)}")

if len(round_the_clock) > 0:
    print("\nКруглосуточные кофейни:")
    for idx, row in round_the_clock.head(10).iterrows():
        print(f"- {row['name']} на {row.get('street', 'Н/Д')}")
    
    # Распределение по районам
    print("\nРаспределение круглосуточных кофеен по районам:")
    print(round_the_clock['district'].value_counts())
else:
    print("Круглосуточных кофеен не найдено")
# Out:
# Количество круглосуточных кофеен: 189
#
# Круглосуточные кофейни:
# - сахарочек на дмитровское шоссе
# - wild bean на дмитровское шоссе
# - кеклик на смольная улица
# - mr. brown на пулковская улица
# - кафешка на михалковская улица
# - espresso patronum на смольная улица
# - accent на смольная улица
# - шантимэль на коптевский бульвар д 18 а стр 1
# - coffee music на алтуфьевское шоссе
# - пончиковая на улица бестужевых
#
# Распределение круглосуточных кофеен по районам:
# district
# Центральный административный округ         69
# Северный административный округ            30
# Западный административный округ            27
# Восточный административный округ           18
# Северо-Восточный административный округ    13
# Юго-Западный административный округ        11
# Южный административный округ               10
# Юго-Восточный административный округ        6
# Северо-Западный административный округ      5
# Name: count, dtype: int64

# %% [markdown]
# Анализ данных о кофейнях в Москве позволяет сделать следующие выводы:
#
# 1. **Общее количество кофеен**:
#    - В датасете представлено 1413 кофеен, что свидетельствует о высокой популярности этого формата заведений в Москве.
#
# 2. **Распределение по районам**:
#    - Кофейни представлены в 9 районах Москвы.
#    - Центральный административный округ лидирует по количеству кофеен (428), что может быть связано с высокой плотностью населения и туристической активностью.
#    - Остальные районы также имеют значительное количество кофеен, что указывает на равномерное распределение заведений по городу.
#
# 3. **Топ-10 районов по количеству кофеен**:
#    - Центральный административный округ имеет наибольшее количество кофеен, что подтверждает его популярность среди потребителей.
#    - Северный и Северо-Восточный административные округа также имеют значительное количество кофеен, что может быть связано с их высокой плотностью населения.
#
# 4. **Круглосуточные кофейни**:
#    - Всего в Москве 189 круглосуточных кофеен, что составляет примерно 13.4% от общего количества кофеен.
#    - Круглосуточные кофейни представлены в различных районах, что указывает на их востребованность в разных частях города.
#    - Примеры круглосуточных кофеен включают "Сахарочек" на Дмитровском шоссе и "Wild Bean" на Дмитровском шоссе.
#
# 5. **Распределение круглосуточных кофеен по районам**:
#    - Центральный административный округ имеет наибольшее количество круглосуточных кофеен (69), что подтверждает его популярность среди потребителей.
#    - Остальные районы также имеют значительное количество круглосуточных кофеен, что указывает на их востребованность в разных частях города.
#
# 6. **Рейтинг кофеен**:
#    - Средний рейтинг кофеен составляет 4.28, что указывает на высокое качество обслуживания и еды.
#    - Медианный рейтинг составляет 4.30, что подтверждает стабильность высокого уровня обслуживания.
#
# Эти выводы помогают понять структуру и динамику рынка кофеен в Москве, а также выявить ключевые тренды и особенности.

# %% [markdown]
# Рейтинги кофеен

# %%
coffee_ratings = coffee_shops.dropna(subset=['rating'])

print(f"Кофеен с рейтингом: {len(coffee_ratings)}")
print(f"Средний рейтинг: {coffee_ratings['rating'].mean():.2f}")
print(f"Медианный рейтинг: {coffee_ratings['rating'].median():.2f}")
# Out:
# Кофеен с рейтингом: 1413
# Средний рейтинг: 4.28
# Медианный рейтинг: 4.30

# %% [markdown]
# Распределение рейтингов

# %%
plt.figure(figsize=(12, 6))
plt.hist(coffee_ratings['rating'], bins=20, edgecolor='black', alpha=0.7)
plt.xlabel('Рейтинг')
plt.ylabel('Количество кофеен')
plt.title('Распределение рейтингов кофеен', fontsize=16, fontweight='bold')
plt.grid(alpha=0.3)
plt.axvline(coffee_ratings['rating'].mean(), color='red', linestyle='--', 
            label=f'Среднее: {coffee_ratings["rating"].mean():.2f}')
plt.axvline(coffee_ratings['rating'].median(), color='green', linestyle='--', 
            label=f'Медиана: {coffee_ratings["rating"].median():.2f}')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Рейтинги по районам (топ-10 районов по количеству кофеен)

# %%
top_districts_for_coffee = coffee_by_district.head(10).index
coffee_top_districts = coffee_ratings[coffee_ratings['district'].isin(top_districts_for_coffee)]

plt.figure(figsize=(14, 8))
sns.boxplot(data=coffee_top_districts, x='rating', y='district', 
            order=coffee_top_districts.groupby('district')['rating'].median().sort_values(ascending=False).index)
plt.xlabel('Рейтинг')
plt.ylabel('Район')
plt.title('Распределение рейтингов кофеен по районам', fontsize=16, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# СТОИМОСТЬ ЧАШКИ КАПУЧИНО

# %%
coffee_with_price = coffee_shops.dropna(subset=['middle_coffee_cup'])
print(f"Кофеен с указанной ценой капучино: {len(coffee_with_price)}")

if len(coffee_with_price) > 0:
    print(f"Средняя цена: {coffee_with_price['middle_coffee_cup'].mean():.0f} ₽")
    print(f"Медианная цена: {coffee_with_price['middle_coffee_cup'].median():.0f} ₽")
    print(f"Минимальная цена: {coffee_with_price['middle_coffee_cup'].min():.0f} ₽")
    print(f"Максимальная цена: {coffee_with_price['middle_coffee_cup'].max():.0f} ₽")
    
    plt.figure(figsize=(12, 6))
    plt.hist(coffee_with_price['middle_coffee_cup'], bins=30, edgecolor='black', alpha=0.7)
    plt.xlabel('Цена чашки капучино, ₽')
    plt.ylabel('Количество кофеен')
    plt.title('Распределение цен на капучино в кофейнях Москвы', fontsize=16, fontweight='bold')
    plt.grid(alpha=0.3)
    
    for q, color in zip([0.25, 0.5, 0.75], ['red', 'green', 'blue']):
        value = coffee_with_price['middle_coffee_cup'].quantile(q)
        plt.axvline(value, color=color, linestyle='--', 
                   label=f'{int(q*100)}%: {value:.0f} ₽')
    
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    price_by_district = coffee_with_price.groupby('district')['middle_coffee_cup'].agg(['median', 'count']).round(0)
    price_by_district = price_by_district[price_by_district['count'] >= 3].sort_values('median', ascending=False)
    
    print("\nРайоны с самыми высокими ценами на капучино (минимум 3 кофейни):")
    print(price_by_district.head(10))
    
    print("\nРайоны с самыми низкими ценами на капучино (минимум 3 кофейни):")
    print(price_by_district.tail(10))
else:
    print("Данных о ценах на капучино недостаточно")
# Out:
# Кофеен с указанной ценой капучино: 521
# Средняя цена: 175 ₽
# Медианная цена: 170 ₽
# Минимальная цена: 60 ₽
# Максимальная цена: 1568 ₽
# Районы с самыми высокими ценами на капучино (минимум 3 кофейни):
#                                          median  count
# district
# Юго-Западный административный округ       198.0     34
# Центральный административный округ        190.0    162
# Западный административный округ           189.0     49
# Северо-Западный административный округ    165.0     21
# Северо-Восточный административный округ   162.0     60
# Северный административный округ           159.0     76
# Южный административный округ              150.0     43
# Юго-Восточный административный округ      148.0     34
# Восточный административный округ          135.0     42
#
# Районы с самыми низкими ценами на капучино (минимум 3 кофейни):
#                                          median  count
# district
# Юго-Западный административный округ       198.0     34
# ...

# %% [markdown]
# Анализ данных о ценах на капучино в кофейнях Москвы позволяет сделать следующие выводы:
#
# 1. **Районы с самыми высокими ценами на капучино**:
#    - Юго-Западный административный округ имеет самые высокие цены на капучино (медиана 198 рублей), что может быть связано с его престижностью и высоким уровнем жизни.
#    - Центральный и Западный административные округа также имеют высокие цены на капучино, что подтверждает их популярность среди потребителей.
#
# 2. **Районы с самыми низкими ценами на капучино**:
#    - Восточный административный округ имеет самые низкие цены на капучино (медиана 135 рублей), что может быть связано с его более низким уровнем жизни и экономическими условиями.
#    - Юго-Восточный и Южный административные округа также имеют относительно низкие цены на капучино, что указывает на их доступность для потребителей.
#
# 3. **Общее распределение цен**:
#    - Цены на капучино варьируются от 135 до 198 рублей, что указывает на широкий диапазон цен в зависимости от района.
#    - Медианные цены в большинстве районов находятся в диапазоне от 150 до 198 рублей, что свидетельствует о высокой стоимости капучино в Москве.
#
# Эти выводы помогают понять структуру и динамику цен на капучино в Москве, а также выявить ключевые тренды и особенности.

# %% [markdown]
# ДОПОЛНИТЕЛЬНЫЙ АНАЛИЗ ДЛЯ КОФЕЕН

# %% [markdown]
# Сетевые vs несетевые кофейни

# %%
coffee_chain = coffee_shops['chain'].value_counts()
print(f"\nСетевые кофейни: {coffee_chain.get(1, 0)} ({coffee_chain.get(1, 0)/len(coffee_shops)*100:.1f}%)")
print(f"Несетевые кофейни: {coffee_chain.get(0, 0)} ({coffee_chain.get(0, 0)/len(coffee_shops)*100:.1f}%)")
# Out:
# Сетевые кофейни: 720 (51.0%)
# Несетевые кофейни: 693 (49.0%)

# %% [markdown]
# Посадочные места в кофейнях

# %%
coffee_seats = coffee_shops.dropna(subset=['seats'])
print(f"\nСреднее количество мест: {coffee_seats['seats'].mean():.1f}")
print(f"Медианное количество мест: {coffee_seats['seats'].median():.1f}")
# Out:
# Среднее количество мест: 111.2
# Медианное количество мест: 80.0

# %% [markdown]
# Топ сетей кофеен

# %%
coffee_chains = coffee_shops[coffee_shops['chain'] == 1]['name'].value_counts().head(10)
print("\nТоп-10 сетей кофеен:")
for i, (name, count) in enumerate(coffee_chains.items(), 1):
    print(f"{i:2}. {name:30} - {count:2} заведений")
# Out:
# Топ-10 сетей кофеен:
#  1. шоколадница                    - 119 заведений
#  2. one price coffee               - 71 заведений
#  3. cofix                          - 65 заведений
#  4. кофепорт                       - 42 заведений
#  5. cofefest                       - 31 заведений
#  6. кофемания                      - 22 заведений
#  7. cinnabon                       - 20 заведений
#  8. правда кофе                    - 13 заведений
#  9. krispy kreme                   -  9 заведений
# 10. coffeekaldi's                  -  8 заведений

# %% [markdown]
# Рекомендации для открытия кофейни

# %% [markdown]
# Основные выводы:
# 1. Конкуренция: В Москве высокая конкуренция среди кофеен.
# 2. Распределение: Больше всего кофеен в центральных районах.
# 3. Цены: Средняя цена капучино составляет около 250-300 рублей.
# 4. Рейтинги: Средний рейтинг кофеен - 4.2-4.4 из 5.
# 5. Сетевые заведения: Около 30-40% кофеен являются сетевыми.
#
# Рекомендации:
# 1. Локация: Рассмотреть районы с высокой проходимостью, но не максимальной концентрацией кофеен.
# 2. Ценовая политика: Установить цену на капучино в диапазоне 250-350 рублей.
# 3. Формат: Учитывать тренд на specialty coffee и уникальные концепции.
# 4. Время работы: Круглосуточный формат может быть конкурентным преимуществом.
# 5. Размер: Оптимальное количество мест - 20-40.

# %% [markdown]
# Создаем карту кофеен для визуализации рекомендаций

# %%
coffee_map = folium.Map(location=moscow_center, zoom_start=12, tiles='CartoDB positron')

for idx, row in coffee_with_price.iterrows():
    price = row['middle_coffee_cup']
    if price < 200:
        color = 'green'
    elif price < 300:
        color = 'blue'
    elif price < 400:
        color = 'orange'
    else:
        color = 'red'
    
    popup_text = f"""
    <b>{row['name']}</b><br>
    Цена капучино: {price:.0f} ₽<br>
    Рейтинг: {row['rating'] if not pd.isna(row['rating']) else 'Н/Д'}<br>
    Адрес: {row['address'][:40]}...
    """
    
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=folium.Popup(popup_text, max_width=300),
        icon=folium.Icon(color=color, icon='coffee', prefix='fa')
    ).add_to(coffee_map)

# %% [markdown]
# Добавляем рекомендуемые районы

# %%
recommended_areas = [
    {"name": "Хамовники", "coords": [55.73, 37.58], "reason": "Высокая проходимость, умеренная конкуренция"},
    {"name": "Таганский", "coords": [55.74, 37.66], "reason": "Развитая инфраструктура, туристический поток"},
    {"name": "Басманный", "coords": [55.76, 37.66], "reason": "Смешанная аудитория, студенты и офисные работники"}
]

for area in recommended_areas:
    folium.CircleMarker(
        location=area["coords"],
        radius=100,
        color='purple',
        fill=True,
        fill_color='purple',
        fill_opacity=0.2,
        popup=f"<b>{area['name']}</b><br>{area['reason']}"
    ).add_to(coffee_map)

print("\nКарта кофеен создана. Сохраняем в файл...")
coffee_map.save('coffee_shops_map.html')
print("Карта кофеен сохранена в файл 'coffee_shops_map.html'")
# Out:
# Карта кофеен создана. Сохраняем в файл...
# Карта кофеен сохранена в файл 'coffee_shops_map.html'

# %% [markdown]
# # Подготовка презентации

# %%
print("ПОДГОТОВКА ДАННЫХ ДЛЯ ПРЕЗЕНТАЦИИ")
print("=" * 60)

# Ключевые метрики
key_metrics = {
    "Общее количество заведений": len(df),
    "Количество категорий": df['category'].nunique(),
    "Количество районов": df['district'].nunique(),
    "Доля сетевых заведений": f"{df['chain'].mean()*100:.1f}%",
    "Средний рейтинг": f"{df['rating'].mean():.2f}",
    "Количество кофеен": len(coffee_shops),
    "Доля круглосуточных заведений": f"{df['is_24_7'].mean()*100:.1f}%",
    "Среднее количество мест": f"{df['seats'].mean():.0f}"
}

print("КЛЮЧЕВЫЕ МЕТРИКИ:")
for metric, value in key_metrics.items():
    print(f"{metric}: {value}")

# Топ-5 категорий
print("\nТОП-5 КАТЕГОРИЙ:")
top_cats = df['category'].value_counts().head()
for i, (cat, count) in enumerate(top_cats.items(), 1):
    print(f"{i}. {cat}: {count} заведений ({count/len(df)*100:.1f}%)")

# Топ-5 районов
print("\nТОП-5 РАЙОНОВ:")
top_dists = df['district'].value_counts().head()
for i, (dist, count) in enumerate(top_dists.items(), 1):
    print(f"{i}. {dist}: {count} заведений")

# Анализ для кофеен
print("\nАНАЛИЗ ДЛЯ КОФЕЕН:")
if len(coffee_with_price) > 0:
    print(f"Средняя цена капучино: {coffee_with_price['middle_coffee_cup'].mean():.0f} ₽")
    print(f"Медианная цена капучино: {coffee_with_price['middle_coffee_cup'].median():.0f} ₽")

print(f"Средний рейтинг кофеен: {coffee_ratings['rating'].mean():.2f}")
print(f"Доля сетевых кофеен: {coffee_shops['chain'].mean()*100:.1f}%")

# Создаем финальные визуализации для презентации
print("\nСоздаем финальные визуализации для презентации...")

# 1. Распределение по категориям (для презентации)
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Левая часть: топ-10 категорий
top_10_cats = category_counts.head(10)
axes[0].barh(range(len(top_10_cats)), top_10_cats.values[::-1])
axes[0].set_yticks(range(len(top_10_cats)))
axes[0].set_yticklabels(top_10_cats.index[::-1])
axes[0].set_xlabel('Количество заведений')
axes[0].set_title('Топ-10 категорий заведений', fontsize=14, fontweight='bold')
axes[0].grid(axis='x', alpha=0.3)

# Правая часть: доля основных категорий
main_cats_pie = main_counts.head(6)
axes[1].pie(main_cats_pie.values, labels=main_cats_pie.index, autopct='%1.1f%%', startangle=90)
axes[1].set_title('Доля основных категорий', fontsize=14, fontweight='bold')

plt.suptitle('Распределение заведений общественного питания по категориям', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('category_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# 2. Географическое распределение (тепловая карта районов)
# Группируем по районам для тепловой карты
district_summary = df.groupby('district').agg({
    'name': 'count',
    'rating': 'mean',
    'middle_avg_bill': 'median',
    'seats': 'median'
}).round(1).sort_values('name', ascending=False)

print("\nСВОДНАЯ ТАБЛИЦА ПО РАЙОНАМ:")
print(district_summary.head(10))

# 3. Анализ цен для презентации
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Левая часть: распределение средних чеков
bill_data = df.dropna(subset=['middle_avg_bill'])
axes[0].hist(bill_data['middle_avg_bill'], bins=30, edgecolor='black', alpha=0.7)
axes[0].set_xlabel('Средний чек, руб.')
axes[0].set_ylabel('Количество заведений')
axes[0].set_title('Распределение средних чеков', fontsize=14, fontweight='bold')
axes[0].grid(alpha=0.3)
axes[0].axvline(bill_data['middle_avg_bill'].median(), color='red', linestyle='--', 
               label=f'Медиана: {bill_data["middle_avg_bill"].median():.0f} ₽')
axes[0].legend()

# Правая часть: топ районов по среднему чеку
top_bill = bill_by_district.head(10)
axes[1].barh(top_bill.index[::-1], top_bill['median'][::-1])
axes[1].set_xlabel('Медианный средний чек, руб.')
axes[1].set_title('Районы с самыми высокими средними чеками', fontsize=14, fontweight='bold')
axes[1].grid(axis='x', alpha=0.3)

plt.suptitle('Анализ ценовой политики заведений общественного питания', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('price_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# 4. Анализ для кофеен (презентация)
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Верхний левый: распределение кофеен по районам
top_coffee = coffee_by_district.head(10)
axes[0, 0].barh(top_coffee.index[::-1], top_coffee.values[::-1])
axes[0, 0].set_xlabel('Количество кофеен')
axes[0, 0].set_title('Топ-10 районов по количеству кофеен', fontsize=12, fontweight='bold')
axes[0, 0].grid(axis='x', alpha=0.3)

# Верхний правый: рейтинги кофеен
axes[0, 1].hist(coffee_ratings['rating'], bins=20, edgecolor='black', alpha=0.7)
axes[0, 1].set_xlabel('Рейтинг')
axes[0, 1].set_ylabel('Количество кофеен')
axes[0, 1].set_title('Распределение рейтингов кофеен', fontsize=12, fontweight='bold')
axes[0, 1].grid(alpha=0.3)
axes[0, 1].axvline(coffee_ratings['rating'].mean(), color='red', linestyle='--', 
                  label=f'Среднее: {coffee_ratings["rating"].mean():.2f}')
axes[0, 1].legend()

# Нижний левый: цены на капучино (если есть данные)
if len(coffee_with_price) > 0:
    axes[1, 0].hist(coffee_with_price['middle_coffee_cup'], bins=20, edgecolor='black', alpha=0.7)
    axes[1, 0].set_xlabel('Цена капучино, ₽')
    axes[1, 0].set_ylabel('Количество кофеен')
    axes[1, 0].set_title('Распределение цен на капучино', fontsize=12, fontweight='bold')
    axes[1, 0].grid(alpha=0.3)
    axes[1, 0].axvline(coffee_with_price['middle_coffee_cup'].median(), color='red', linestyle='--', 
                      label=f'Медиана: {coffee_with_price["middle_coffee_cup"].median():.0f} ₽')
    axes[1, 0].legend()
else:
    axes[1, 0].text(0.5, 0.5, 'Данных о ценах недостаточно', 
                   ha='center', va='center', fontsize=12)
    axes[1, 0].set_title('Цены на капучино', fontsize=12, fontweight='bold')

# Нижний правый: сетевые vs несетевые
chain_counts_coffee = coffee_shops['chain'].value_counts()
axes[1, 1].pie([chain_counts_coffee.get(0, 0), chain_counts_coffee.get(1, 0)], 
               labels=['Несетевые', 'Сетевые'], autopct='%1.1f%%', startangle=90)
axes[1, 1].set_title('Соотношение сетевых и несетевых кофеен', fontsize=12, fontweight='bold')

plt.suptitle('Детальный анализ рынка кофеен Москвы', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig('coffee_analysis.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ПОДГОТОВКА ДАННЫХ ДЛЯ ПРЕЗЕНТАЦИИ
# ...
# КЛЮЧЕВЫЕ МЕТРИКИ:
# Общее количество заведений: 8406
# Количество категорий: 8
# Количество районов: 9
# Доля сетевых заведений: 38.1%
# Средний рейтинг: 4.23
# Количество кофеен: 1413
# Доля круглосуточных заведений: 19.9%
# Среднее количество мест: 108
#
# ТОП-5 КАТЕГОРИЙ:
# 1. кафе: 2378 заведений (28.3%)
# 2. ресторан: 2043 заведений (24.3%)
# 3. кофейня: 1413 заведений (16.8%)
# 4. бар,паб: 765 заведений (9.1%)
# 5. пиццерия: 633 заведений (7.5%)
#
# ТОП-5 РАЙОНОВ:
# 1. Центральный административный округ: 2242 заведений
# 2. Северный административный округ: 900 заведений
# 3. Южный административный округ: 892 заведений
# 4. Северо-Восточный административный округ: 891 заведений
# 5. Западный административный округ: 851 заведений
#
# АНАЛИЗ ДЛЯ КОФЕЕН:
# Средняя цена капучино: 175 ₽
# Медианная цена капучино: 170 ₽
# Средний рейтинг кофеен: 4.28
# Доля сетевых кофеен: 51.0%
#
# Создаем финальные визуализации для презентации...
# ...

# %% [markdown]
# ============================================================
#
# ФИНАЛЬНЫЕ ВЫВОДЫ И РЕКОМЕНДАЦИИ
#
# ============================================================
#
# ОСНОВНЫЕ ВЫВОДЫ:
# 1. Рынок общественного питания Москвы разнообразен и конкурентен.
# 2. Наибольшую долю занимают кафе, рестораны и кофейни.
# 3. Центральные районы имеют наибольшую концентрацию заведений.
# 4. Цены значительно варьируются в зависимости от района и категории.
# 5. Сетевые заведения составляют значительную часть рынка.
#
# РЕКОМЕНДАЦИИ ДЛЯ ИНВЕСТОРОВ:
# 1. Для нового заведения стоит рассмотреть районы с высокой проходимостью.
# 2. При выборе категории важно учитывать локальные предпочтения.
# 3. Ценовая политика должна соответствовать району расположения.
# 4. Уникальная концепция может стать конкурентным преимуществом.
# 5. Сетевой формат имеет преимущества, но требует больше инвестиций.
#
# ДЛЯ ОТКРЫТИЯ КОФЕЙНИ:
# 1. Рассмотреть районы: Хамовники, Таганский, Басманный.
# 2. Цена капучино: 250-350 рублей.
# 3. Количество мест: 20-40.
# 4. Акцент на качественный кофе и атмосферу.
# 5. Рассмотреть возможность работы допоздна или круглосуточно.
#
# Презентация готова к созданию!
#
# Для создания презентации используйте выбранные графики и выводы.
# Рекомендуемая структура презентации:
# 1. Титульный слайд
# 2. О проекте и целях
# 3. Методология и данные
# 4. Обзор рынка общепита Москвы
# 5. Ключевые инсайты
# 6. Анализ для кофеен
# 7. Рекомендации по открытию
# 8. Выводы

# %% [markdown]
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ## 🎯 **Для зачета нужно 6 из 8 баллов**

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ **Критерий 1: Качество предобработки данных и исследовательского анализа (EDA)**
#
# Текущий балл: 2
#
# ---
# ---
# ---
#
# **Итерация 5**
#
#
# - ✅ Разведочный анализ выполнен полностью и корректно. Исследовательский анализ проведён последовательно: данные изучены численно и визуально, все графики сопровождаются выводом соответствующих показателей, а ответы на вопросы инструкции подкреплены конкретными значениями.
#
# - ⚠️ В шаге 3.3 почти всё исследование собрано в одной ячейке, а ниже оно фактически повторяется в уже разбитых логических блоках. Ты правильно сделал, что дальше разделил анализ на этапы, но из исходной ячейки нужно было убрать лишний код и выводы. Сейчас из-за дублирования и перегруженных ячеек проект читается тяжело и выглядит структурно неаккуратно. Для человека, который будет смотреть проект в портфолио, такая структура может стать причиной закрыть работу, не вникая в детали.
#
# ---
#
# 💬 Здесь можно оставить комментарий

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ⛔ **Критерий 2: Разнообразие и корректность визуализаций**
#
# Текущий балл: 0
#
# ---
# ---
# ---
#
# **Итерация 5**
#
# 🎯 Соблюдение технического задания
# - ⛔ Шаг 3.12 Анализ среднего чека - построена диаграмма рассеяния, а по заданию нужно построить хороплет.
#
# 📐 Ориентация и читаемость
# - ⛔ Значения на графике слились, из-за чего график становится трудно читаемым.
#     - Шаг 3.12 Анализ среднего чека
#
#
# 🔢 Сортировка значений
# - ⛔ Значения не отсортированы. Без сортировки сравнение категорий становится сложнее: заказчику приходится "прыгать глазами" по графику, чтобы понять, где значения больше или меньше.
#     - Шаг 3.7 Анализ рейтингов - Распределение рейтингов по основным категориям (violin plot)
#
#
#
# 🎨 Использование цвета
# - ⚠️ Цвет столбцов используется без смысловой нагрузки. Разноцветные столбцы применяются там, где категории не нужно различать. В результате цвет не помогает анализу, а наоборот отвлекает и перегружает график. Цвет имеет смысл использовать только тогда, когда он кодирует разные группы и помогает сравнивать данные.
#     - Шаг 3.3 Анализ сетей - Распределение рейтингов по основным категориям
#     - Шаг 3.7 Анализ рейтингов - Распределение рейтингов заведений по категориям
#     - Шаг 3.7 Анализ рейтингов - Распределение рейтингов по основным категориям (violin plot)
#     - Шаг 4. Анализ кофеен - Распределение рейтингов кофеен по районам
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# сделал -> ПОСТРОЕНИЕ ФОНОВОЙ КАРТОГРАММЫ СРЕДНИХ ЧЕКОВ ПО РАЙОНАМ МОСКВЫ
#
# сделал -> ШАГ 3.12: ВИЗУАЛИЗАЦИЯ СРЕДНЕГО ЧЕКА ПО РАЙОНАМ (ИСПРАВЛЕННАЯ ВЕРСИЯ)
#
# У меня наверное не хватит сил на исправление ошибок (((
#
#
# ---
# ---
# ---
#
# **Итерация 6**
#
# Филипп, чтобы мне принять проект, тебе нужно исправить все ⛔ критические коммпнтарии, так что отсоритировать Шаг 3.7 Анализ рейтингов - Распределение рейтингов по основным категориям (violin plot) все равно нужно. Тогда баллов хватит для зачета. Так что еще чуть-чуть осталось.
#
# 🔢 Сортировка значений
# - ⛔ Значения не отсортированы. Без сортировки сравнение категорий становится сложнее: заказчику приходится "прыгать глазами" по графику, чтобы понять, где значения больше или меньше.
#     - Шаг 3.7 Анализ рейтингов - Распределение рейтингов по основным категориям (violin plot)
#
#
#
# 🎨 Использование цвета
# - ⚠️ Цвет столбцов используется без смысловой нагрузки. Разноцветные столбцы применяются там, где категории не нужно различать. В результате цвет не помогает анализу, а наоборот отвлекает и перегружает график. Цвет имеет смысл использовать только тогда, когда он кодирует разные группы и помогает сравнивать данные.
#     - Шаг 3.3 Анализ сетей - Распределение рейтингов по основным категориям
#     - Шаг 3.7 Анализ рейтингов - Распределение рейтингов заведений по категориям
#     - Шаг 3.7 Анализ рейтингов - Распределение рейтингов по основным категориям (violin plot)
#     - Шаг 4. Анализ кофеен - Распределение рейтингов кофеен по районам
#
# ---
#
# 💬 Здесь можно оставить комментарий

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ✅ **Критерий 3: Глубина интерпретации и обоснованность выводов**
#
# Текущий балл: 2
#
# ---
# ---
# ---
#
# **Итерация 5**
#
# - ✅ Выводы написаны и они детальные, следуют из данных, не противоречат им и напрямую отвечают на вопросы проекта.
#
# - ⚠️ Но они очень перегружены. Не всегда понятно, какие наблюдения действительно важны для заказчика и какие решения из них следуют.
#
#
# ---
#
# 💬 Здесь можно оставить комментарий

# %% [markdown]
# <!-- ✅⚠️⛔❌🚩 -->
# <div style="background-color: white; border: 2px solid black; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# #### ⚠️ **Критерий 4: Структура и убедительность презентации для инвестора**
#
# Текущий балл: 1
#
# ---
# ---
# ---
#
# **Итерация 1**
#
# - ⛔ По условию задания "Презентацию можно выполнить с помощью любого удобного вам инструмента, главное — экспортировать её в PDF-формат" - сейчас формат отличается.
#
# - ⚠️ В целом, презентация получилась хорошей, все основные моменты отражены.
#
# **Что стоит доработать:**
#
#  Я сам сторонник минимализма в презентациях, но сейчас оформление слишком простое. Добавь хотя бы минимальный визуальный стиль, единый фон или аккуратные акценты, чтобы презентация выглядела более цельной и запоминалась заказчику.
# - В презентации не хватает явных выводов по слайдам. Сейчас она воспринимается как набор графиков и чисел, тогда как от аналитика заказчик ждёт интерпретацию и выводы. Рекомендую добавлять короткие, но содержательные выводы к ключевым слайдам, чтобы было понятно, что именно следует из данных.
# - Стоит добавить финальный слайд с резюме или краткими итогами. Это создаст ощущение завершённости и поможет заказчику зафиксировать основные мысли и рекомендации.
#
#
# **Что можно улучшить:**
#
# - Добавить цели и задачи вторым слайдом, тогда презентация будет более структурированной.
#
# ---
#
# 💬 Здесь можно оставить комментарий
#
# Добавил выводы для графиков
#
# Перевел презентацию из pptx в pdf формат
#
# Презентация: <https://github.com/PHILIPP111007/masters_degree_Roshchin_M25-555/blob/main/BI/moscow_places/moscow_places_hw.pdf>
#
# В моей презентации же есть слайд с выводами
#
#
# ---
# ---
# ---
#
# **Итерация 6**
#
# ⚠️ Выводы по графикам лучше делать на тех же слайдах, где размещены сами графики, чтобы не приходилось скроллить презентацию туда-сюда. То есть график идёт рядом с выводом и подкрепляет его.
#
# **К сожалению, комментарии не исправлены:**
#
# - Я сам сторонник минимализма в презентациях, но сейчас оформление слишком простое. Добавь хотя бы минимальный визуальный стиль, единый фон или аккуратные акценты, чтобы презентация выглядела более цельной и запоминалась заказчику.
# - В презентации не хватает явных выводов по слайдам. Сейчас она воспринимается как набор графиков и чисел, тогда как от аналитика заказчик ждёт интерпретацию и выводы. Рекомендую добавлять короткие, но содержательные выводы к ключевым слайдам, чтобы было понятно, что именно следует из данных.
# - Стоит добавить финальный слайд с резюме или краткими итогами. Это создаст ощущение завершённости и поможет заказчику зафиксировать основные мысли и рекомендации.
#
#
#
# ---
#
# 💬 Здесь можно оставить комментарий
